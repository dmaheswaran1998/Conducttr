# %%
import csv, json, requests
import streamlit as st
import pandas as pd
import seaborn as sns
import data_config
import re
import numpy as np
from itertools import chain
from collections import defaultdict

# %%
consumer_key = data_config.consumer_key
partition_id = data_config.partition_id

# %%
def get_following(consumer_key,partition_id):
    url = data_config.get_following+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    
    return data["response"]

# %%
def get_permissions(consumer_key,partition_id):
    url = data_config.get_permssions+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    #print(response)
    data = json.loads(response.content)
    data = data["response"]["permissions"]
    return data

# %%
#timeline and type of interaction 
def get_message_data(consumer_key,partition_id):
    url = data_config.get_activity+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    #st.write(data)
    timeline = data["detailed_log"]
    summary = data["summary"]
    return timeline, summary

# %%
#what is positions who can edit, probably not needed 
def get_cloud_personas(consumer_key,partition_id):
    url = data_config.get_personas+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    return data["response"]["personas"]

# %%
#remove duplicates from the list
def remove_duplicates(list, unique_list):
    for item in list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

# %%
def remove_bracket(list):
    list1=[]
    for item in list:
        item2 = item[1:]
        list1.append(item2)
    return list1

# %%
data=get_message_data(consumer_key,partition_id)

# %%
data1=list(data)
keys=data[0].keys()

# %%
dates=[]
for i in keys:
    dates.append(i)

# %%
persona_id=[]
for i in range(0, len(dates)):
    id=dates[i][-5:]
    persona_id.append(id)

# %%
values1=[]
values=data[0].values()
for i in values:
    values1.append(i)

# %%
#split the reponse based on the channel 
channel=[]
interaction=[]
RFI=[]
text=[]
id1=[]
id2=[]

for i in range(0, len(values1)):
    x = values1[i].split("]")
    channel.append(x[0])
    interaction.append(x[1])
    RFI.append(x[2])
    text.append(x[3])
    id1.append(x[4])
    id2.append(x[5])

# %%
interaction=remove_bracket(interaction)
channel=remove_bracket(channel)
RFI=remove_bracket(RFI)
text=remove_bracket(text)
id1=remove_bracket(id1)
id2=remove_bracket(id2)

# %%
#editing the text cell in more detail 
#need to remove the <br / br> 
#also need to remove the //
text2=[]
for item in text:
    edited_text=re.sub("(<br\s*/>)","", item)
    edited_text=re.sub("(<b)","", edited_text)
    edited_text=edited_text.replace("\\","")
    text2.append(edited_text)

# %%
#editing the date:
dates
dates2=[]
for item in dates:
    item1=item[:-6]
    dates2.append(item1)

# %%
df=pd.DataFrame({"date": dates2, "persona_id":persona_id,"channel": channel, "interaction": interaction, 
                 "Text":text2, "From": id1, "To":id2})

# %%
persona=get_cloud_personas(consumer_key,partition_id)

# %%
persona_id
unique_persona_id=[]
for item in persona_id:
    if item not in unique_persona_id:
        unique_persona_id.append(item)

# %%
#linking the ids with the unique persona, need to understand the json document that need sto do thisu

persona_keys=persona.keys()

# %%
name=[]
imageURL=[]
type=[]

for item in unique_persona_id:
    name.append(persona[item]["details"]["name"])
    imageURL.append(persona[item]["details"]["imageUrl"])
    type.append(persona[item]["details"]["type"])

# %%
persona_df=pd.DataFrame({"persona_id":unique_persona_id, "name": name, "image_url":imageURL, "type":type})

# %%
persona_df
# Out:
#   persona_id      name                                          image_url  \
# 0      e5xoX     Marta  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 1      r0Dyx  Player 3              /assets/styles/36178/profiles/you.png
# 2      wpwl4  Player 4              /assets/styles/36178/profiles/you.png
# 3      AyJ1p  Player 5              /assets/styles/36178/profiles/you.png
# 4      AyJQm  Player 6              /assets/styles/36178/profiles/you.png
#
#           type
# 0  participant
# 1  participant
# 2  participant
# 3  participant
# 4  participant

# %%
#removing blank spaces
nospace_id2=list(filter(None, id2))

edited_list2 = [y for x in nospace_id2 for y in x.split(',')]

# %%
#getting a list of unique_ids
all_ids=id1+edited_list2
unique_ids=[]
remove_duplicates(all_ids, unique_ids)
unique_ids
# Out:
# ['e5xoX',
#  'qrykfy4u0hva9',
#  'qrykfy4u0hvnu',
#  'qrykfy4u0hu23',
#  'qrykfy4u0hv4e',
#  'qrykfy4u0hu6w',
#  'qrykfy4u0hv9y',
#  'r0Dyx',
#  'wpwl4',
#  'AyJ1p',
#  'qrykfy4u0hvs',
#  'AyJQm',
#  'qrykfy4u0hu5b',
#  'qrykfy4u0hvmu',
#  'qrykfy4u0hvgl',
#  'qrykfy4u0huqf',
#  'qrykfy4tx2no3',
#  'qrykfy4u0huq8',
#  'qrykfy4u0huag',
#  'qrykfy4u0hu1a',
#  'qrykfy4txm9pm',
#  'qrykfy4txnbl1',
#  'qrykfy4tx4s8u',
#  'qrykfy4u0huk0',
#  'qrykfy4tx8oqr',
#  'qrykfy4u0huqx',
#  'qrykfy4tx7tf7',
#  'qrykfy4tx2bj1',
#  'qrykfy4tx8d43',
#  'qrykfy4tx7kaz',
#  'qrykfy4u0hu2d',
#  'qrykfy4u0hupb',
#  'qrykfy4tx70fn']

# %%
channel_unique=[]
for item in channel:
    if item not in channel_unique:
        channel_unique.append(item)

# %%
channel_unique
# Out:
# ['mail', 'microblog', 'watch', 'mediablog', 'gosocial', 'websites']

# %%
twitter=[]

email=[]

gosocial_name=[]



for item in unique_ids:
    #twitter data
    twitter.append(persona[item]["microblog"]["displayName"])
    #email
    email.append(persona[item]["mail"]["email"])
    
    #GoSocial
    gosocial_name.append(persona[item]["gosocial"]["displayName"])

# %%
channel_dict={}
for channel in channel_unique:
    name=persona[item][channel]["displayName"]
    channel_dict={channel"}

# %%
persona[item]
# Out:
# {'mediablog': {'displayName': 'Jane',
#   'active': 1,
#   'location': '',
#   'messages': [],
#   'followers': 0,
#   'verified': 0,
#   'date': '',
#   'handle': 'jane',
#   'numMessages': 0,
#   'imageCoverUrl': '',
#   'imageProfileUrl': 'https://conducttr-a.akamaihd.net/fa/1907/21/16832/person-6.jpg',
#   'bio': '',
#   'following': 0},
#  'details': {'displayName': 'Jane',
#   'disposition': 0,
#   'birthDate': '',
#   'location': '',
#   'imageUrl': 'https://conducttr-a.akamaihd.net/fa/1907/21/16832/person-6.jpg',
#   'affiliation': '',
#   'name': '',
#   'a3e': '',
#   'lname': '',
#   'bio': '',
#   'gender': '',
#   'goals': [],
#   'type': 'persona'},
#  'microblog': {'displayName': 'Jane',
#   'bio': '',
#   'active': 1,
#   'location': '',
#   'messages': [],
#   'followers': 0,
#   'following': 0,
#   'date': '',
#   'handle': 'jane',
#   'bg': '',
#   'verified': 0,
#   'imageURL': 'https://conducttr-a.akamaihd.net/fa/1907/21/16832/person-6.jpg',
#   'numMessages': 0},
#  'videoblog': {'displayName': 'Jane',
#   'active': 1,
#   'location': '',
#   'messages': [],
#   'followers': 0,
#   'verified': 0,
#   'date': '',
#   'numMessages': 0,
#   'handle': 'jane',
#   'imageCoverUrl': '',
#   'imageProfileUrl': 'https://conducttr-a.akamaihd.net/fa/1907/21/16832/person-6.jpg',
#   'bio': ''},
#  'gosocial': {'displayName': 'Jane',
#   'active': 1,
#   'location': '',
#   'messages': [],
#   'followers': 0,
#   'verified': 0,
#   'date': '',
#   'handle': 'jane',
#   'numMessages': 0,
#   'imageCoverUrl': '',
#   'type': 'user',
#   'imageProfileUrl': 'https://conducttr-a.akamaihd.net/fa/1907/21/16832/person-6.jpg',
#   'bio': ''},
#  'mail': {'email': ''}}

# %%
print(len(unique_ids))
print(len(twitter))
print(len(email))
print(len(gosocial_name))
# Out:
# 33
# 33
# 33
# 33

# %%
#Player_activity_dataset

channel_df=pd.DataFrame({"From":unique_ids, "twitter name":twitter, "email":email, "goSocial name": gosocial_name
    
})

# %%
channel_df.head(20)


##to_merged=channel_df[["To", ]]
# Out:
#              From        twitter name  \
# 0           e5xoX             Marta R
# 1   qrykfy4u0hva9              News24
# 2   qrykfy4u0hvnu         Bloomsburys
# 3   qrykfy4u0hu23              Claire
# 4   qrykfy4u0hv4e             FizzPop
# 5   qrykfy4u0hu6w                Mark
# 6   qrykfy4u0hv9y            BBC News
# 7           r0Dyx           Player 3
# 8           wpwl4           Player 4
# 9           AyJ1p           Player 5
# 10   qrykfy4u0hvs  Food Industry News
# 11          AyJQm           Player 6
# 12  qrykfy4u0hu5b    Ben (Operations)
# 13  qrykfy4u0hvmu      BBC News - old
# 14  qrykfy4u0hvgl         Steve Blake
# 15  qrykfy4u0huqf                Rose
# 16  qrykfy4tx2no3                Alex
# 17  qrykfy4u0huq8                Jill
# 18  qrykfy4u0huag              Martha
# 19  qrykfy4u0hu1a                 Jim
#
#                                        email       goSocial name
# 0                 martaruizperez96@gmail.com           Player 2
# 1                                                         News24
# 2                        ops@bloomsburys.com         Bloomsburys
# 3                        claire@customer.com              Claire
# 4                                                        FizzPop
# 5                          mark@customer.com                Mark
# 6                                                       BBC News
# 7   5fae77dc2da836.86389437@tstoryteller.com           Player 3
# 8   5fae7c475722f7.76670398@tstoryteller.com           Player 4
# 9   5fae7fd2617b53.40010347@tstoryteller.com           Player 5
# 10                                            Food Industry News
# 11  5fae838a742e72.91228671@tstoryteller.com           Player 6
# 12                     ben.moore@fizzpop.com    Ben (Operations)
# 13                                                BBC News - old
# 14                          blake@news24.com         Steve Blake
# 15                         rose@customer.com                Rose
# 16                                                          Alex
# 17                         jill@customer.com                Jill
# 18                       martha@customer.com              Martha
# 19                           jim@fizzpop.com                 Jim

# %%
channel2_df=pd.DataFrame({"To":unique_ids, "From":unique_ids, "twitter name":twitter,
             "email":email, "goSocial name": gosocial_name
    
})

channel2_df['twitter name'] = channel2_df['twitter name'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)

# %%
from_merged=channel2_df[["From", "twitter name", "email", "goSocial name"]]
from_merged.head(20)
#string replacements in the from dataset
# Out:
#              From        twitter name  \
# 0           e5xoX             Marta R
# 1   qrykfy4u0hva9              News24
# 2   qrykfy4u0hvnu         Bloomsburys
# 3   qrykfy4u0hu23              Claire
# 4   qrykfy4u0hv4e             FizzPop
# 5   qrykfy4u0hu6w                Mark
# 6   qrykfy4u0hv9y            BBC News
# 7           r0Dyx           Player 3
# 8           wpwl4           Player 4
# 9           AyJ1p           Player 5
# 10   qrykfy4u0hvs  Food Industry News
# 11          AyJQm           Player 6
# 12  qrykfy4u0hu5b      Ben Operations
# 13  qrykfy4u0hvmu      BBC News - old
# 14  qrykfy4u0hvgl         Steve Blake
# 15  qrykfy4u0huqf                Rose
# 16  qrykfy4tx2no3                Alex
# 17  qrykfy4u0huq8                Jill
# 18  qrykfy4u0huag              Martha
# 19  qrykfy4u0hu1a                 Jim
#
#                                        email       goSocial name
# 0                 martaruizperez96@gmail.com           Player 2
# 1                                                         News24
# 2                        ops@bloomsburys.com         Bloomsburys
# 3                        claire@customer.com              Claire
# 4                                                        FizzPop
# 5                          mark@customer.com                Mark
# 6                                                       BBC News
# 7   5fae77dc2da836.86389437@tstoryteller.com           Player 3
# 8   5fae7c475722f7.76670398@tstoryteller.com           Player 4
# 9   5fae7fd2617b53.40010347@tstoryteller.com           Player 5
# 10                                            Food Industry News
# 11  5fae838a742e72.91228671@tstoryteller.com           Player 6
# 12                     ben.moore@fizzpop.com    Ben (Operations)
# 13                                                BBC News - old
# 14                          blake@news24.com         Steve Blake
# 15                         rose@customer.com                Rose
# 16                                                          Alex
# 17                         jill@customer.com                Jill
# 18                       martha@customer.com              Martha
# 19                           jim@fizzpop.com                 Jim

# %%
to_merged=channel2_df[["To", "twitter name"]]
All=["All"]
All=pd.DataFrame({"To":All, "twitter name":All})
to_merged=to_merged.append(All)

# %%
to_merged.head(50)
#remove emojis from the dataframe
# Out:
#                To          twitter name
# 0           e5xoX               Marta R
# 1   qrykfy4u0hva9                News24
# 2   qrykfy4u0hvnu           Bloomsburys
# 3   qrykfy4u0hu23                Claire
# 4   qrykfy4u0hv4e               FizzPop
# 5   qrykfy4u0hu6w                  Mark
# 6   qrykfy4u0hv9y              BBC News
# 7           r0Dyx             Player 3
# 8           wpwl4             Player 4
# 9           AyJ1p             Player 5
# 10   qrykfy4u0hvs    Food Industry News
# 11          AyJQm             Player 6
# 12  qrykfy4u0hu5b        Ben Operations
# 13  qrykfy4u0hvmu        BBC News - old
# 14  qrykfy4u0hvgl           Steve Blake
# 15  qrykfy4u0huqf                  Rose
# 16  qrykfy4tx2no3                  Alex
# 17  qrykfy4u0huq8                  Jill
# 18  qrykfy4u0huag                Martha
# 19  qrykfy4u0hu1a                   Jim
# 20  qrykfy4txm9pm         Surf Official
# 21  qrykfy4txnbl1          BenjaSniper
# 22  qrykfy4tx4s8u               Jackeee
# 23  qrykfy4u0huk0         James Quality
# 24  qrykfy4tx8oqr         Ventura Today
# 25  qrykfy4u0huqx            Josh Sales
# 26  qrykfy4tx7tf7               Bernard
# 27  qrykfy4tx2bj1                   Mia
# 28  qrykfy4tx8d43           LittleJokes
# 29  qrykfy4tx7kaz              Fernanda
# 30  qrykfy4u0hu2d                 Karen
# 31  qrykfy4u0hupb  Steve Ops Excellence
# 32  qrykfy4tx70fn                  Jane
# 0             All                   All

# %%
#explode the id2 dataframe count:
to_merged["twitter name"].unique()
# Out:
# array(['Marta R', 'News24', 'Bloomsburys', 'Claire', 'FizzPop', 'Mark',
#        'BBC News', 'Player 3 ', 'Player 4 ', 'Player 5 ',
#        'Food Industry News', 'Player 6 ', 'Ben Operations',
#        'BBC News - old', 'Steve Blake', 'Rose', 'Alex', 'Jill', 'Martha',
#        'Jim', 'Surf Official', '\xa0\xa0 BenjaSniper\xa0', 'Jackeee',
#        'James Quality', 'Ventura Today', 'Josh Sales', 'Bernard', 'Mia',
#        'LittleJokes', 'Fernanda', 'Karen', 'Steve Ops Excellence', 'Jane',
#        'All'], dtype=object)

# %%
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# calculate lengths of splits
lens = df['To'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
df2 = pd.DataFrame({'date': np.repeat(df['date'], lens),
                    'persona_id': np.repeat(df['persona_id'], lens),
                    'channel': np.repeat(df['channel'], lens),
                    'interaction': np.repeat(df['interaction'], lens),
                    'Text': np.repeat(df['Text'], lens),
                    'From': np.repeat(df['From'], lens),
                    'To': chainer(df['To'])})

# %%
#data - getting across it and unferstanding it
df2["Frequency"]=1

# %%
df2.head(15)
# Out:
#                    date persona_id    channel interaction  \
# 0   2020-11-13 11:29:42      e5xoX       mail     forward
# 1   2020-11-13 11:30:27      e5xoX  microblog      repost
# 2   2020-11-13 11:30:29      e5xoX  microblog        like
# 3   2020-11-13 11:31:30      e5xoX  microblog      repost
# 4   2020-11-13 11:32:16      e5xoX  microblog         new
# 5   2020-11-13 11:34:01      e5xoX      watch   add_alert
# 6   2020-11-13 11:34:14      e5xoX      watch   add_alert
# 7   2020-11-13 11:34:50      e5xoX  microblog         new
# 8   2020-11-13 11:36:07      e5xoX  mediablog       reply
# 9   2020-11-13 11:36:22      e5xoX  mediablog         new
# 10  2020-11-13 11:37:02      e5xoX  microblog      repost
# 11  2020-11-13 11:37:36      e5xoX  microblog       reply
# 12  2020-11-13 11:37:44      e5xoX  microblog      repost
# 13  2020-11-13 11:38:23      e5xoX  microblog       reply
# 14  2020-11-13 11:39:01      e5xoX  microblog        like
#
#                                                  Text           From  \
# 0                    thank you!    We'll be in touch!          e5xoX
# 1                                                              e5xoX
# 2                                                              e5xoX
# 3                                                              e5xoX
# 4                                   I love this film!          e5xoX
# 5                                             fizzpop          e5xoX
# 6                                                flat          e5xoX
# 7           FizzPop's new agreement with Bloomsburys!  qrykfy4u0hva9
# 8                                       That is great          e5xoX
# 9               Recently played this game, I liked it          e5xoX
# 10                                                             e5xoX
# 11  We are very sorry to hear this. We'll investig...  qrykfy4u0hvnu
# 12                                                             e5xoX
# 13                                           me, too!  qrykfy4u0hu23
# 14                                                             e5xoX
#
#                To  Frequency
# 0   qrykfy4u0hu5b          1
# 1   qrykfy4u0hvmu          1
# 2   qrykfy4u0hv9y          1
# 3   qrykfy4u0hva9          1
# 4                          1
# 5                          1
# 6                          1
# 7                          1
# 8   qrykfy4u0hvgl          1
# 9                          1
# 10  qrykfy4u0huqf          1
# 11  qrykfy4u0huqf          1
# 12  qrykfy4u0hv4e          1
# 13          e5xoX          1
# 14  qrykfy4tx2no3          1

# %%
merged=pd.merge(df2, from_merged, on='From')
merged.head(10)
# Out:
#                   date persona_id    channel interaction  \
# 0  2020-11-13 11:29:42      e5xoX       mail     forward
# 1  2020-11-13 11:30:27      e5xoX  microblog      repost
# 2  2020-11-13 11:30:29      e5xoX  microblog        like
# 3  2020-11-13 11:31:30      e5xoX  microblog      repost
# 4  2020-11-13 11:32:16      e5xoX  microblog         new
# 5  2020-11-13 11:34:01      e5xoX      watch   add_alert
# 6  2020-11-13 11:34:14      e5xoX      watch   add_alert
# 7  2020-11-13 11:36:07      e5xoX  mediablog       reply
# 8  2020-11-13 11:36:22      e5xoX  mediablog         new
# 9  2020-11-13 11:37:02      e5xoX  microblog      repost
#
#                                     Text   From             To  Frequency  \
# 0       thank you!    We'll be in touch!  e5xoX  qrykfy4u0hu5b          1
# 1                                         e5xoX  qrykfy4u0hvmu          1
# 2                                         e5xoX  qrykfy4u0hv9y          1
# 3                                         e5xoX  qrykfy4u0hva9          1
# 4                      I love this film!  e5xoX                         1
# 5                                fizzpop  e5xoX                         1
# 6                                   flat  e5xoX                         1
# 7                          That is great  e5xoX  qrykfy4u0hvgl          1
# 8  Recently played this game, I liked it  e5xoX                         1
# 9                                         e5xoX  qrykfy4u0huqf          1
#
#   twitter name                       email goSocial name
# 0      Marta R  martaruizperez96@gmail.com     Player 2
# 1      Marta R  martaruizperez96@gmail.com     Player 2
# 2      Marta R  martaruizperez96@gmail.com     Player 2
# 3      Marta R  martaruizperez96@gmail.com     Player 2
# 4      Marta R  martaruizperez96@gmail.com     Player 2
# 5      Marta R  martaruizperez96@gmail.com     Player 2
# 6      Marta R  martaruizperez96@gmail.com     Player 2
# 7      Marta R  martaruizperez96@gmail.com     Player 2
# 8      Marta R  martaruizperez96@gmail.com     Player 2
# 9      Marta R  martaruizperez96@gmail.com     Player 2

# %%
merged=merged.rename(columns={"twitter name":"from"})
merged=merged.drop(columns={"From"})

# %%
#fill null values in NA
merged['To'].replace('','Everyone', inplace=True)
merged['email'].replace('','None', inplace=True)
merged['goSocial name'].replace('','None', inplace=True)

# %%
merged_2=pd.merge(merged,to_merged, on='To')

# %%
merged_2.head(5)
# Out:
#                   date persona_id    channel interaction  \
# 0  2020-11-13 11:29:42      e5xoX       mail     forward
# 1  2020-11-13 13:03:03      AyJQm       mail       reply
# 2  2020-11-13 11:30:27      e5xoX  microblog      repost
# 3  2020-11-13 11:30:29      e5xoX  microblog        like
# 4  2020-11-13 12:09:44      e5xoX   gosocial       reply
#
#                                                 Text             To  \
# 0                   thank you!    We'll be in touch!  qrykfy4u0hu5b
# 1  I learned how to manage an incident  How to re...  qrykfy4u0hu5b
# 2                                                     qrykfy4u0hvmu
# 3                                                     qrykfy4u0hv9y
# 4                                     shame on them!  qrykfy4u0hv9y
#
#    Frequency       from                                     email  \
# 0          1    Marta R                martaruizperez96@gmail.com
# 1          1  Player 6   5fae838a742e72.91228671@tstoryteller.com
# 2          1    Marta R                martaruizperez96@gmail.com
# 3          1    Marta R                martaruizperez96@gmail.com
# 4          1    Marta R                martaruizperez96@gmail.com
#
#   goSocial name    twitter name
# 0     Player 2   Ben Operations
# 1     Player 6   Ben Operations
# 2     Player 2   BBC News - old
# 3     Player 2         BBC News
# 4     Player 2         BBC News

# %%
merged_2=merged_2.rename(columns={"twitter name":"to"})

# %%
#merge persona id: 

#merging people
merged_final=pd.merge(merged_2,persona_df, on='persona_id')

# %%
merged_final
# Out:
#                    date persona_id    channel interaction  \
# 0   2020-11-13 11:29:42      e5xoX       mail     forward
# 1   2020-11-13 11:30:27      e5xoX  microblog      repost
# 2   2020-11-13 11:30:29      e5xoX  microblog        like
# 3   2020-11-13 12:09:44      e5xoX   gosocial       reply
# 4   2020-11-13 11:31:30      e5xoX  microblog      repost
# 5   2020-11-13 11:36:07      e5xoX  mediablog       reply
# 6   2020-11-13 12:05:40      e5xoX       mail     forward
# 7   2020-11-13 11:37:02      e5xoX  microblog      repost
# 8   2020-11-13 11:37:36      e5xoX  microblog       reply
# 9   2020-11-13 11:37:44      e5xoX  microblog      repost
# 10  2020-11-13 11:46:42      e5xoX  microblog       reply
# 11  2020-11-13 11:39:01      e5xoX  microblog        like
# 12  2020-11-13 11:42:03      e5xoX   websites       reply
# 13  2020-11-13 11:42:04      e5xoX   websites       reply
# 14  2020-11-13 11:49:20      e5xoX  microblog      repost
# 15  2020-11-13 11:49:45      e5xoX  microblog      repost
# 16  2020-11-13 11:51:32      e5xoX  microblog      repost
# 17  2020-11-13 11:57:10      e5xoX       mail         new
# 18  2020-11-13 11:51:07      e5xoX  microblog       reply
# 19  2020-11-13 11:57:10      e5xoX       mail         new
# 20  2020-11-13 12:05:40      e5xoX       mail     forward
# 21  2020-11-13 11:38:23      e5xoX  microblog       reply
# 22  2020-11-13 11:47:18      e5xoX  microblog       reply
# 23  2020-11-13 11:44:11      e5xoX  microblog       reply
# 24  2020-11-13 12:08:58      e5xoX   gosocial       reply
# 25  2020-11-13 11:40:21      e5xoX   gosocial       reply
# 26  2020-11-13 13:03:03      AyJQm       mail       reply
# 27  2020-11-13 13:11:53      AyJQm  microblog        like
# 28  2020-11-13 13:11:35      AyJQm  microblog      repost
# 29  2020-11-13 12:35:09      wpwl4  microblog        like
# 30  2020-11-13 12:35:28      wpwl4  microblog       reply
# 31  2020-11-13 12:36:31      wpwl4       mail         new
# 32  2020-11-13 12:36:31      wpwl4       mail         new
# 33  2020-11-13 12:35:48      wpwl4  microblog        like
# 34  2020-11-13 12:34:46      wpwl4  microblog        like
# 35  2020-11-13 12:35:04      wpwl4  microblog      repost
# 36  2020-11-13 12:35:33      wpwl4  microblog        like
# 37  2020-11-13 12:35:50      wpwl4  microblog      repost
# 38  2020-11-13 12:32:35      wpwl4  microblog      repost
# 39  2020-11-13 12:28:45      r0Dyx  microblog        like
# 40  2020-11-13 12:20:02      r0Dyx       mail     forward
# 41  2020-11-13 12:22:44      r0Dyx       mail     forward
# 42  2020-11-13 12:17:24      r0Dyx  microblog      repost
# 43  2020-11-13 12:18:23      r0Dyx  microblog      repost
# 44  2020-11-13 12:24:39      r0Dyx  microblog       reply
# 45  2020-11-13 12:16:37      r0Dyx  microblog      repost
# 46  2020-11-13 12:22:44      r0Dyx       mail     forward
# 47  2020-11-13 12:27:11      r0Dyx       mail       reply
# 48  2020-11-13 12:59:18      AyJ1p   gosocial       reply
# 49  2020-11-13 12:48:48      AyJ1p  microblog      repost
# 50  2020-11-13 12:50:40      AyJ1p       mail       reply
# 51  2020-11-13 12:57:04      AyJ1p       mail       reply
#
#                                                  Text             To  \
# 0                    thank you!    We'll be in touch!  qrykfy4u0hu5b
# 1                                                      qrykfy4u0hvmu
# 2                                                      qrykfy4u0hv9y
# 3                                      shame on them!  qrykfy4u0hv9y
# 4                                                      qrykfy4u0hva9
# 5                                       That is great  qrykfy4u0hvgl
# 6              This is awful!    Please, help us to s  qrykfy4u0hvgl
# 7                                                      qrykfy4u0huqf
# 8   We are very sorry to hear this. We'll investig...  qrykfy4u0huqf
# 9                                                      qrykfy4u0hv4e
# 10                          You are so unprofessional  qrykfy4u0hv4e
# 11                                                     qrykfy4tx2no3
# 12                                      It's a shame!   qrykfy4u0hvs
# 13                                      It's a shame!   qrykfy4u0hvs
# 14                                                     qrykfy4u0huq8
# 15                                                     qrykfy4u0huag
# 16                                                     qrykfy4u0hu6w
# 17  I've been watching social media and customers ...  qrykfy4u0hvnu
# 18    Will you at least give money back to customers?  qrykfy4u0hvnu
# 19  I've been watching social media and customers ...  qrykfy4u0hu1a
# 20             This is awful!    Please, help us to s          e5xoX
# 21                                           me, too!          e5xoX
# 22      FizzPop needs to explain, so does Bloomsburys          e5xoX
# 23                 We are investigating what happened          e5xoX
# 24                                                Omg  qrykfy4u0hu23
# 25     We're investigating it. We'll update you soon!  qrykfy4u0hu23
# 26  I learned how to manage an incident  How to re...  qrykfy4u0hu5b
# 27                                                     qrykfy4u0hu6w
# 28                                                     qrykfy4tx70fn
# 29                                                     qrykfy4u0hva9
# 30                                 you are funny mate  qrykfy4u0hva9
# 31                                   what's the plan?  qrykfy4u0hu1a
# 32                                   what's the plan?          e5xoX
# 33                                                     qrykfy4u0hu23
# 34                                                     qrykfy4u0hu23
# 35                                                     qrykfy4tx2bj1
# 36                                                     qrykfy4tx2bj1
# 37                                                     qrykfy4tx8d43
# 38                                                     qrykfy4tx7tf7
# 39                                                     qrykfy4u0hva9
# 40                                         thank you!  qrykfy4u0hvgl
# 41             thank you    We need to follow this in          e5xoX
# 42                                                     qrykfy4txnbl1
# 43                                                     qrykfy4tx4s8u
# 44                       You stole our breaking news!  qrykfy4tx8oqr
# 45                                                     qrykfy4txm9pm
# 46             thank you    We need to follow this in  qrykfy4u0huk0
# 47  Tell them this won't happen again    We take t...  qrykfy4u0huqx
# 48                                                hey  qrykfy4u0hu6w
# 49                                                     qrykfy4tx7kaz
# 50                     It's none of your business tbh  qrykfy4u0hu2d
# 51                               It's okay, thank you  qrykfy4u0hupb
#
#     Frequency         from                                     email  \
# 0           1      Marta R                martaruizperez96@gmail.com
# 1           1      Marta R                martaruizperez96@gmail.com
# 2           1      Marta R                martaruizperez96@gmail.com
# 3           1      Marta R                martaruizperez96@gmail.com
# 4           1      Marta R                martaruizperez96@gmail.com
# 5           1      Marta R                martaruizperez96@gmail.com
# 6           1      Marta R                martaruizperez96@gmail.com
# 7           1      Marta R                martaruizperez96@gmail.com
# 8           1  Bloomsburys                       ops@bloomsburys.com
# 9           1      Marta R                martaruizperez96@gmail.com
# 10          1      Marta R                martaruizperez96@gmail.com
# 11          1      Marta R                martaruizperez96@gmail.com
# 12          1      Marta R                martaruizperez96@gmail.com
# 13          1      Marta R                martaruizperez96@gmail.com
# 14          1      Marta R                martaruizperez96@gmail.com
# 15          1      Marta R                martaruizperez96@gmail.com
# 16          1      Marta R                martaruizperez96@gmail.com
# 17          1      Marta R                martaruizperez96@gmail.com
# 18          1         Mark                         mark@customer.com
# 19          1      Marta R                martaruizperez96@gmail.com
# 20          1      Marta R                martaruizperez96@gmail.com
# 21          1       Claire                       claire@customer.com
# 22          1       Claire                       claire@customer.com
# 23          1      FizzPop                                      None
# 24          1      Marta R                martaruizperez96@gmail.com
# 25          1      FizzPop                                      None
# 26          1    Player 6   5fae838a742e72.91228671@tstoryteller.com
# 27          1         Mark                         mark@customer.com
# 28          1    Player 6   5fae838a742e72.91228671@tstoryteller.com
# 29          1     BBC News                                      None
# 30          1     BBC News                                      None
# 31          1    Player 4   5fae7c475722f7.76670398@tstoryteller.com
# 32          1    Player 4   5fae7c475722f7.76670398@tstoryteller.com
# 33          1     BBC News                                      None
# 34          1    Player 4   5fae7c475722f7.76670398@tstoryteller.com
# 35          1       News24                                      None
# 36          1     BBC News                                      None
# 37          1     BBC News                                      None
# 38          1    Player 4   5fae7c475722f7.76670398@tstoryteller.com
# 39          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 40          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 41          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 42          1       News24                                      None
# 43          1      FizzPop                                      None
# 44          1     BBC News                                      None
# 45          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 46          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 47          1    Player 3   5fae77dc2da836.86389437@tstoryteller.com
# 48          1         Mark                         mark@customer.com
# 49          1       News24                                      None
# 50          1    Player 5   5fae7fd2617b53.40010347@tstoryteller.com
# 51          1    Player 5   5fae7fd2617b53.40010347@tstoryteller.com
#
#    goSocial name                    to      name  \
# 0      Player 2         Ben Operations     Marta
# 1      Player 2         BBC News - old     Marta
# 2      Player 2               BBC News     Marta
# 3      Player 2               BBC News     Marta
# 4      Player 2                 News24     Marta
# 5      Player 2            Steve Blake     Marta
# 6      Player 2            Steve Blake     Marta
# 7      Player 2                   Rose     Marta
# 8    Bloomsburys                  Rose     Marta
# 9      Player 2                FizzPop     Marta
# 10     Player 2                FizzPop     Marta
# 11     Player 2                   Alex     Marta
# 12     Player 2     Food Industry News     Marta
# 13     Player 2     Food Industry News     Marta
# 14     Player 2                   Jill     Marta
# 15     Player 2                 Martha     Marta
# 16     Player 2                   Mark     Marta
# 17     Player 2            Bloomsburys     Marta
# 18          Mark           Bloomsburys     Marta
# 19     Player 2                    Jim     Marta
# 20     Player 2                Marta R     Marta
# 21        Claire               Marta R     Marta
# 22        Claire               Marta R     Marta
# 23       FizzPop               Marta R     Marta
# 24     Player 2                 Claire     Marta
# 25       FizzPop                Claire     Marta
# 26     Player 6         Ben Operations  Player 6
# 27          Mark                  Mark  Player 6
# 28     Player 6                   Jane  Player 6
# 29      BBC News                News24  Player 4
# 30      BBC News                News24  Player 4
# 31     Player 4                    Jim  Player 4
# 32     Player 4                Marta R  Player 4
# 33      BBC News                Claire  Player 4
# 34     Player 4                 Claire  Player 4
# 35        News24                   Mia  Player 4
# 36      BBC News                   Mia  Player 4
# 37      BBC News           LittleJokes  Player 4
# 38     Player 4                Bernard  Player 4
# 39     Player 3                 News24  Player 3
# 40     Player 3            Steve Blake  Player 3
# 41     Player 3                Marta R  Player 3
# 42        News24          BenjaSniper   Player 3
# 43       FizzPop               Jackeee  Player 3
# 44      BBC News         Ventura Today  Player 3
# 45     Player 3          Surf Official  Player 3
# 46     Player 3          James Quality  Player 3
# 47     Player 3             Josh Sales  Player 3
# 48          Mark                  Mark  Player 5
# 49        News24              Fernanda  Player 5
# 50     Player 5                  Karen  Player 5
# 51     Player 5   Steve Ops Excellence  Player 5
#
#                                             image_url         type
# 0   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 1   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 2   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 3   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 4   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 5   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 6   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 7   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 8   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 9   /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 10  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 11  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 12  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 13  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 14  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 15  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 16  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 17  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 18  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 19  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 20  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 21  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 22  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 23  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 24  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 25  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant
# 26              /assets/styles/36178/profiles/you.png  participant
# 27              /assets/styles/36178/profiles/you.png  participant
# 28              /assets/styles/36178/profiles/you.png  participant
# 29              /assets/styles/36178/profiles/you.png  participant
# 30              /assets/styles/36178/profiles/you.png  participant
# 31              /assets/styles/36178/profiles/you.png  participant
# 32              /assets/styles/36178/profiles/you.png  participant
# 33              /assets/styles/36178/profiles/you.png  participant
# 34              /assets/styles/36178/profiles/you.png  participant
# 35              /assets/styles/36178/profiles/you.png  participant
# 36              /assets/styles/36178/profiles/you.png  participant
# 37              /assets/styles/36178/profiles/you.png  participant
# 38              /assets/styles/36178/profiles/you.png  participant
# 39              /assets/styles/36178/profiles/you.png  participant
# 40              /assets/styles/36178/profiles/you.png  participant
# 41              /assets/styles/36178/profiles/you.png  participant
# 42              /assets/styles/36178/profiles/you.png  participant
# 43              /assets/styles/36178/profiles/you.png  participant
# 44              /assets/styles/36178/profiles/you.png  participant
# 45              /assets/styles/36178/profiles/you.png  participant
# 46              /assets/styles/36178/profiles/you.png  participant
# 47              /assets/styles/36178/profiles/you.png  participant
# 48              /assets/styles/36178/profiles/you.png  participant
# 49              /assets/styles/36178/profiles/you.png  participant
# 50              /assets/styles/36178/profiles/you.png  participant
# 51              /assets/styles/36178/profiles/you.png  participant

# %%
merged_final=merged_final[["date","name","channel", "interaction", "Text", "from", "to", "image_url", "type", "Frequency","email"]]

# %%
merged_final
# Out:
#                    date      name    channel interaction  \
# 0   2020-11-13 11:29:42     Marta       mail     forward
# 1   2020-11-13 11:30:27     Marta  microblog      repost
# 2   2020-11-13 11:30:29     Marta  microblog        like
# 3   2020-11-13 12:09:44     Marta   gosocial       reply
# 4   2020-11-13 11:31:30     Marta  microblog      repost
# 5   2020-11-13 11:36:07     Marta  mediablog       reply
# 6   2020-11-13 12:05:40     Marta       mail     forward
# 7   2020-11-13 11:37:02     Marta  microblog      repost
# 8   2020-11-13 11:37:36     Marta  microblog       reply
# 9   2020-11-13 11:37:44     Marta  microblog      repost
# 10  2020-11-13 11:46:42     Marta  microblog       reply
# 11  2020-11-13 11:39:01     Marta  microblog        like
# 12  2020-11-13 11:42:03     Marta   websites       reply
# 13  2020-11-13 11:42:04     Marta   websites       reply
# 14  2020-11-13 11:49:20     Marta  microblog      repost
# 15  2020-11-13 11:49:45     Marta  microblog      repost
# 16  2020-11-13 11:51:32     Marta  microblog      repost
# 17  2020-11-13 11:57:10     Marta       mail         new
# 18  2020-11-13 11:51:07     Marta  microblog       reply
# 19  2020-11-13 11:57:10     Marta       mail         new
# 20  2020-11-13 12:05:40     Marta       mail     forward
# 21  2020-11-13 11:38:23     Marta  microblog       reply
# 22  2020-11-13 11:47:18     Marta  microblog       reply
# 23  2020-11-13 11:44:11     Marta  microblog       reply
# 24  2020-11-13 12:08:58     Marta   gosocial       reply
# 25  2020-11-13 11:40:21     Marta   gosocial       reply
# 26  2020-11-13 13:03:03  Player 6       mail       reply
# 27  2020-11-13 13:11:53  Player 6  microblog        like
# 28  2020-11-13 13:11:35  Player 6  microblog      repost
# 29  2020-11-13 12:35:09  Player 4  microblog        like
# 30  2020-11-13 12:35:28  Player 4  microblog       reply
# 31  2020-11-13 12:36:31  Player 4       mail         new
# 32  2020-11-13 12:36:31  Player 4       mail         new
# 33  2020-11-13 12:35:48  Player 4  microblog        like
# 34  2020-11-13 12:34:46  Player 4  microblog        like
# 35  2020-11-13 12:35:04  Player 4  microblog      repost
# 36  2020-11-13 12:35:33  Player 4  microblog        like
# 37  2020-11-13 12:35:50  Player 4  microblog      repost
# 38  2020-11-13 12:32:35  Player 4  microblog      repost
# 39  2020-11-13 12:28:45  Player 3  microblog        like
# 40  2020-11-13 12:20:02  Player 3       mail     forward
# 41  2020-11-13 12:22:44  Player 3       mail     forward
# 42  2020-11-13 12:17:24  Player 3  microblog      repost
# 43  2020-11-13 12:18:23  Player 3  microblog      repost
# 44  2020-11-13 12:24:39  Player 3  microblog       reply
# 45  2020-11-13 12:16:37  Player 3  microblog      repost
# 46  2020-11-13 12:22:44  Player 3       mail     forward
# 47  2020-11-13 12:27:11  Player 3       mail       reply
# 48  2020-11-13 12:59:18  Player 5   gosocial       reply
# 49  2020-11-13 12:48:48  Player 5  microblog      repost
# 50  2020-11-13 12:50:40  Player 5       mail       reply
# 51  2020-11-13 12:57:04  Player 5       mail       reply
#
#                                                  Text         from  \
# 0                    thank you!    We'll be in touch!      Marta R
# 1                                                          Marta R
# 2                                                          Marta R
# 3                                      shame on them!      Marta R
# 4                                                          Marta R
# 5                                       That is great      Marta R
# 6              This is awful!    Please, help us to s      Marta R
# 7                                                          Marta R
# 8   We are very sorry to hear this. We'll investig...  Bloomsburys
# 9                                                          Marta R
# 10                          You are so unprofessional      Marta R
# 11                                                         Marta R
# 12                                      It's a shame!      Marta R
# 13                                      It's a shame!      Marta R
# 14                                                         Marta R
# 15                                                         Marta R
# 16                                                         Marta R
# 17  I've been watching social media and customers ...      Marta R
# 18    Will you at least give money back to customers?         Mark
# 19  I've been watching social media and customers ...      Marta R
# 20             This is awful!    Please, help us to s      Marta R
# 21                                           me, too!       Claire
# 22      FizzPop needs to explain, so does Bloomsburys       Claire
# 23                 We are investigating what happened      FizzPop
# 24                                                Omg      Marta R
# 25     We're investigating it. We'll update you soon!      FizzPop
# 26  I learned how to manage an incident  How to re...    Player 6
# 27                                                            Mark
# 28                                                       Player 6
# 29                                                        BBC News
# 30                                 you are funny mate     BBC News
# 31                                   what's the plan?    Player 4
# 32                                   what's the plan?    Player 4
# 33                                                        BBC News
# 34                                                       Player 4
# 35                                                          News24
# 36                                                        BBC News
# 37                                                        BBC News
# 38                                                       Player 4
# 39                                                       Player 3
# 40                                         thank you!    Player 3
# 41             thank you    We need to follow this in    Player 3
# 42                                                          News24
# 43                                                         FizzPop
# 44                       You stole our breaking news!     BBC News
# 45                                                       Player 3
# 46             thank you    We need to follow this in    Player 3
# 47  Tell them this won't happen again    We take t...    Player 3
# 48                                                hey         Mark
# 49                                                          News24
# 50                     It's none of your business tbh    Player 5
# 51                               It's okay, thank you    Player 5
#
#                       to                                          image_url  \
# 0         Ben Operations  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 1         BBC News - old  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 2               BBC News  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 3               BBC News  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 4                 News24  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 5            Steve Blake  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 6            Steve Blake  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 7                   Rose  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 8                   Rose  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 9                FizzPop  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 10               FizzPop  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 11                  Alex  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 12    Food Industry News  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 13    Food Industry News  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 14                  Jill  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 15                Martha  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 16                  Mark  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 17           Bloomsburys  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 18           Bloomsburys  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 19                   Jim  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 20               Marta R  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 21               Marta R  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 22               Marta R  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 23               Marta R  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 24                Claire  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 25                Claire  /assets/styles/36178/profiles/profile-e5xoX.jp...
# 26        Ben Operations              /assets/styles/36178/profiles/you.png
# 27                  Mark              /assets/styles/36178/profiles/you.png
# 28                  Jane              /assets/styles/36178/profiles/you.png
# 29                News24              /assets/styles/36178/profiles/you.png
# 30                News24              /assets/styles/36178/profiles/you.png
# 31                   Jim              /assets/styles/36178/profiles/you.png
# 32               Marta R              /assets/styles/36178/profiles/you.png
# 33                Claire              /assets/styles/36178/profiles/you.png
# 34                Claire              /assets/styles/36178/profiles/you.png
# 35                   Mia              /assets/styles/36178/profiles/you.png
# 36                   Mia              /assets/styles/36178/profiles/you.png
# 37           LittleJokes              /assets/styles/36178/profiles/you.png
# 38               Bernard              /assets/styles/36178/profiles/you.png
# 39                News24              /assets/styles/36178/profiles/you.png
# 40           Steve Blake              /assets/styles/36178/profiles/you.png
# 41               Marta R              /assets/styles/36178/profiles/you.png
# 42          BenjaSniper               /assets/styles/36178/profiles/you.png
# 43               Jackeee              /assets/styles/36178/profiles/you.png
# 44         Ventura Today              /assets/styles/36178/profiles/you.png
# 45         Surf Official              /assets/styles/36178/profiles/you.png
# 46         James Quality              /assets/styles/36178/profiles/you.png
# 47            Josh Sales              /assets/styles/36178/profiles/you.png
# 48                  Mark              /assets/styles/36178/profiles/you.png
# 49              Fernanda              /assets/styles/36178/profiles/you.png
# 50                 Karen              /assets/styles/36178/profiles/you.png
# 51  Steve Ops Excellence              /assets/styles/36178/profiles/you.png
#
#            type  Frequency                                     email
# 0   participant          1                martaruizperez96@gmail.com
# 1   participant          1                martaruizperez96@gmail.com
# 2   participant          1                martaruizperez96@gmail.com
# 3   participant          1                martaruizperez96@gmail.com
# 4   participant          1                martaruizperez96@gmail.com
# 5   participant          1                martaruizperez96@gmail.com
# 6   participant          1                martaruizperez96@gmail.com
# 7   participant          1                martaruizperez96@gmail.com
# 8   participant          1                       ops@bloomsburys.com
# 9   participant          1                martaruizperez96@gmail.com
# 10  participant          1                martaruizperez96@gmail.com
# 11  participant          1                martaruizperez96@gmail.com
# 12  participant          1                martaruizperez96@gmail.com
# 13  participant          1                martaruizperez96@gmail.com
# 14  participant          1                martaruizperez96@gmail.com
# 15  participant          1                martaruizperez96@gmail.com
# 16  participant          1                martaruizperez96@gmail.com
# 17  participant          1                martaruizperez96@gmail.com
# 18  participant          1                         mark@customer.com
# 19  participant          1                martaruizperez96@gmail.com
# 20  participant          1                martaruizperez96@gmail.com
# 21  participant          1                       claire@customer.com
# 22  participant          1                       claire@customer.com
# 23  participant          1                                      None
# 24  participant          1                martaruizperez96@gmail.com
# 25  participant          1                                      None
# 26  participant          1  5fae838a742e72.91228671@tstoryteller.com
# 27  participant          1                         mark@customer.com
# 28  participant          1  5fae838a742e72.91228671@tstoryteller.com
# 29  participant          1                                      None
# 30  participant          1                                      None
# 31  participant          1  5fae7c475722f7.76670398@tstoryteller.com
# 32  participant          1  5fae7c475722f7.76670398@tstoryteller.com
# 33  participant          1                                      None
# 34  participant          1  5fae7c475722f7.76670398@tstoryteller.com
# 35  participant          1                                      None
# 36  participant          1                                      None
# 37  participant          1                                      None
# 38  participant          1  5fae7c475722f7.76670398@tstoryteller.com
# 39  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 40  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 41  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 42  participant          1                                      None
# 43  participant          1                                      None
# 44  participant          1                                      None
# 45  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 46  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 47  participant          1  5fae77dc2da836.86389437@tstoryteller.com
# 48  participant          1                         mark@customer.com
# 49  participant          1                                      None
# 50  participant          1  5fae7fd2617b53.40010347@tstoryteller.com
# 51  participant          1  5fae7fd2617b53.40010347@tstoryteller.com

# %%
#total interactions of each (name) and channel 
total_interactions = merged_final.groupby(['name','channel','interaction'])
total_interactions_final=pd.DataFrame(total_interactions["Frequency"].count())
total_interactions_final
# Out:
#                                 Frequency
# name     channel   interaction
# Marta    gosocial  reply                3
#          mail      forward              3
#                    new                  2
#          mediablog reply                1
#          microblog like                 2
#                    reply                6
#                    repost               7
#          websites  reply                2
# Player 3 mail      forward              3
#                    reply                1
#          microblog like                 1
#                    reply                1
#                    repost               3
# Player 4 mail      new                  2
#          microblog like                 4
#                    reply                1
#                    repost               3
# Player 5 gosocial  reply                1
#          mail      reply                2
#          microblog repost               1
# Player 6 mail      reply                1
#          microblog like                 1
#                    repost               1

# %%
#personas each person had as each person (from interactions) 
total_to = merged_final.groupby(['name','to'])
total_to=pd.DataFrame(total_to["Frequency"].count())
total_to.head(50)
# Out:
#                                Frequency
# name     to
# Marta    Alex                          1
#          BBC News                      2
#          BBC News - old                1
#          Ben Operations                1
#          Bloomsburys                   2
#          Claire                        2
#          FizzPop                       2
#          Food Industry News            2
#          Jill                          1
#          Jim                           1
#          Mark                          1
#          Marta R                       4
#          Martha                        1
#          News24                        1
#          Rose                          2
#          Steve Blake                   2
# Player 3 Jackeee                       1
#          James Quality                 1
#          Josh Sales                    1
#          Marta R                       1
#          News24                        1
#          Steve Blake                   1
#          Surf Official                 1
#          Ventura Today                 1
#             BenjaSniper                1
# Player 4 Bernard                       1
#          Claire                        2
#          Jim                           1
#          LittleJokes                   1
#          Marta R                       1
#          Mia                           2
#          News24                        2
# Player 5 Fernanda                      1
#          Karen                         1
#          Mark                          1
#          Steve Ops Excellence          1
# Player 6 Ben Operations                1
#          Jane                          1
#          Mark                          1

# %%
total_from = merged_final.groupby(['name','from'])
total_from=pd.DataFrame(total_from["Frequency"].count())
total_from.head(50)
# Out:
#                       Frequency
# name     from
# Marta    Bloomsburys          1
#          Claire               2
#          FizzPop              2
#          Mark                 1
#          Marta R             20
# Player 3 BBC News             1
#          FizzPop              1
#          News24               1
#          Player 3             6
# Player 4 BBC News             5
#          News24               1
#          Player 4             4
# Player 5 Mark                 1
#          News24               1
#          Player 5             2
# Player 6 Mark                 1
#          Player 6             2

# %%
total_from_channel= merged_final.groupby(['name','from','channel'])
total_from_channel=pd.DataFrame(total_from_channel["Frequency"].count())
total_from_channel.head(50)
# Out:
#                                 Frequency
# name     from        channel
# Marta    Bloomsburys microblog          1
#          Claire      microblog          2
#          FizzPop     gosocial           1
#                      microblog          1
#          Mark        microblog          1
#          Marta R     gosocial           2
#                      mail               5
#                      mediablog          1
#                      microblog         10
#                      websites           2
# Player 3 BBC News    microblog          1
#          FizzPop     microblog          1
#          News24      microblog          1
#          Player 3    mail               4
#                      microblog          2
# Player 4 BBC News    microblog          5
#          News24      microblog          1
#          Player 4    mail               2
#                      microblog          2
# Player 5 Mark        gosocial           1
#          News24      microblog          1
#          Player 5    mail               2
# Player 6 Mark        microblog          1
#          Player 6    mail               1
#                      microblog          1

# %%
#personas most communications- channel and person 
total_group = merged_final.groupby(['name','to', "channel"])
total_to=pd.DataFrame(total_group["Frequency"].count())
total_to.head(50)

merged_final_df=merged_final

# %%
#personas by the different day, interaction (to whom- as tooltip) maybe

#received communication
#receiving time and trying to get those filters to work

# %%
#write out to a json file
results = defaultdict(lambda: defaultdict(dict))

for index, value in total_from.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
json_list=[]
newlist = list()
for i in results.keys():
    newlist.append(i)

# %%
impersonations2={}
for item in newlist:
        impersonations=results[item].keys()
        values=[]
        for i in impersonations:    
            values.append(i)
            impersonations2.update({f'{item}':values})

# %%
impersonations3={"impersonations": impersonations2}

# %%
json_list.append(impersonations3)

# %%
merged_final2=merged_final.copy()

# %%
merged_final2["channel"]="All"

# %%
frames=(merged_final, merged_final2)
merged3=pd.concat(frames)
merged3.head(5)
# Out:
#                   date   name    channel interaction  \
# 0  2020-11-13 11:29:42  Marta       mail     forward
# 1  2020-11-13 11:30:27  Marta  microblog      repost
# 2  2020-11-13 11:30:29  Marta  microblog        like
# 3  2020-11-13 12:09:44  Marta   gosocial       reply
# 4  2020-11-13 11:31:30  Marta  microblog      repost
#
#                                Text     from              to  \
# 0  thank you!    We'll be in touch!  Marta R  Ben Operations
# 1                                    Marta R  BBC News - old
# 2                                    Marta R        BBC News
# 3                    shame on them!  Marta R        BBC News
# 4                                    Marta R          News24
#
#                                            image_url         type  Frequency  \
# 0  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 1  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 2  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 3  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 4  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
#
#                         email
# 0  martaruizperez96@gmail.com
# 1  martaruizperez96@gmail.com
# 2  martaruizperez96@gmail.com
# 3  martaruizperez96@gmail.com
# 4  martaruizperez96@gmail.com

# %%
total_from_channel= merged_final.groupby(['name','from','channel'])
total_from_channel=pd.DataFrame(total_from_channel["Frequency"].count())
total_from_channel.head(50)
# Out:
#                                 Frequency
# name     from        channel
# Marta    Bloomsburys microblog          1
#          Claire      microblog          2
#          FizzPop     gosocial           1
#                      microblog          1
#          Mark        microblog          1
#          Marta R     gosocial           2
#                      mail               5
#                      mediablog          1
#                      microblog         10
#                      websites           2
# Player 3 BBC News    microblog          1
#          FizzPop     microblog          1
#          News24      microblog          1
#          Player 3    mail               4
#                      microblog          2
# Player 4 BBC News    microblog          5
#          News24      microblog          1
#          Player 4    mail               2
#                      microblog          2
# Player 5 Mark        gosocial           1
#          News24      microblog          1
#          Player 5    mail               2
# Player 6 Mark        microblog          1
#          Player 6    mail               1
#                      microblog          1

# %%
results3 = defaultdict(lambda: defaultdict(dict))

for index, value in total_from_channel.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results3[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
results4={"from":results3}
json_list.append(results4)

# %%
results4
# Out:
# {'from': defaultdict(<function __main__.<lambda>()>,
#              {'Marta': defaultdict(dict,
#                           {'Bloomsburys': {'microblog': 1},
#                            'Claire': {'microblog': 2},
#                            'FizzPop': {'gosocial': 1, 'microblog': 1},
#                            'Mark': {'microblog': 1},
#                            'Marta R': {'gosocial': 2,
#                             'mail': 5,
#                             'mediablog': 1,
#                             'microblog': 10,
#                             'websites': 2}}),
#               'Player 3': defaultdict(dict,
#                           {'BBC News': {'microblog': 1},
#                            'FizzPop': {'microblog': 1},
#                            'News24': {'microblog': 1},
#                            'Player 3 ': {'mail': 4, 'microblog': 2}}),
#               'Player 4': defaultdict(dict,
#                           {'BBC News': {'microblog': 5},
#                            'News24': {'microblog': 1},
#                            'Player 4 ': {'mail': 2, 'microblog': 2}}),
#               'Player 5': defaultdict(dict,
#                           {'Mark': {'gosocial': 1},
#                            'News24': {'microblog': 1},
#                            'Player 5 ': {'mail': 2}}),
#               'Player 6': defaultdict(dict,
#                           {'Mark': {'microblog': 1},
#                            'Player 6 ': {'mail': 1, 'microblog': 1}})})}

# %%
#grouping the datetime 
merged3.head()
# Out:
#                   date   name    channel interaction  \
# 0  2020-11-13 11:29:42  Marta       mail     forward
# 1  2020-11-13 11:30:27  Marta  microblog      repost
# 2  2020-11-13 11:30:29  Marta  microblog        like
# 3  2020-11-13 12:09:44  Marta   gosocial       reply
# 4  2020-11-13 11:31:30  Marta  microblog      repost
#
#                                Text     from              to  \
# 0  thank you!    We'll be in touch!  Marta R  Ben Operations
# 1                                    Marta R  BBC News - old
# 2                                    Marta R        BBC News
# 3                    shame on them!  Marta R        BBC News
# 4                                    Marta R          News24
#
#                                            image_url         type  Frequency  \
# 0  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 1  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 2  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 3  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 4  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
#
#                         email
# 0  martaruizperez96@gmail.com
# 1  martaruizperez96@gmail.com
# 2  martaruizperez96@gmail.com
# 3  martaruizperez96@gmail.com
# 4  martaruizperez96@gmail.com

# %%
merged3['date'] = pd.to_datetime(merged3['date'], infer_datetime_format=True)
merged3.head()
# Out:
#                  date   name    channel interaction  \
# 0 2020-11-13 11:29:42  Marta       mail     forward
# 1 2020-11-13 11:30:27  Marta  microblog      repost
# 2 2020-11-13 11:30:29  Marta  microblog        like
# 3 2020-11-13 12:09:44  Marta   gosocial       reply
# 4 2020-11-13 11:31:30  Marta  microblog      repost
#
#                                Text     from              to  \
# 0  thank you!    We'll be in touch!  Marta R  Ben Operations
# 1                                    Marta R  BBC News - old
# 2                                    Marta R        BBC News
# 3                    shame on them!  Marta R        BBC News
# 4                                    Marta R          News24
#
#                                            image_url         type  Frequency  \
# 0  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 1  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 2  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 3  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 4  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
#
#                         email
# 0  martaruizperez96@gmail.com
# 1  martaruizperez96@gmail.com
# 2  martaruizperez96@gmail.com
# 3  martaruizperez96@gmail.com
# 4  martaruizperez96@gmail.com

# %%
#list of unique values and getting a JSON file for frequency of all the players 
person_list=merged3['name'].to_list()

person_list_unique=[]

for item in person_list:
    if item not in person_list_unique:
        person_list_unique.append(item)

# %%
channel_list=merged3["channel"].to_list()
channel_list_unique=[]
for item in channel_list:
    if item not in channel_list_unique:
        channel_list_unique.append(item)

# %%
channel_list_unique
dict2={}

# %%
channel_list_unique
# Out:
# ['mail', 'microblog', 'gosocial', 'mediablog', 'websites', 'All']

# %%
#jsonifying the data 
for person in person_list_unique:
    frames=[]
    for channel in channel_list_unique:
        try:
            channel_1=merged3.loc[(merged3["name"]==f"{person}") &(merged3["channel"]==f'{channel}'), :]
            merged_time_all=channel_1.resample('0.3H', on='date').sum()
            merged_time_all["channel"]=f"{channel}"
            frames.append(merged_time_all)
        except:
            continue
   
    merged=pd.concat(frames)
    merged=merged.reset_index()
    merged['date']=merged['date'].astype(str)
    merged = merged.groupby(['channel', "date"])
    merged1=pd.DataFrame(merged["Frequency"].sum())
    
    results1 = defaultdict(lambda: defaultdict(dict))
    for index, value in merged1.itertuples():
        for i, key in enumerate(index):
            if i == 0:
                nested = results1[key]
            elif i == len(index) - 1:
                nested[key] = value
        else:
            nested = nested[key]
    
    
    dict2.update({f'{person}':results1})

# %%
time=merged3.resample('0.3H', on='date').sum()
time=time.reset_index()
time['date']=time['date'].astype(str)
time_list=time["date"].to_list()
time_list
# Out:
# ['2020-11-13 11:24:00',
#  '2020-11-13 11:42:00',
#  '2020-11-13 12:00:00',
#  '2020-11-13 12:18:00',
#  '2020-11-13 12:36:00',
#  '2020-11-13 12:54:00']

# %%
dict2
# Out:
# {'Marta': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 11,
#                            '2020-11-13 11:42:00': 11,
#                            '2020-11-13 12:00:00': 4}),
#               'gosocial': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 0,
#                            '2020-11-13 12:00:00': 2}),
#               'mail': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 2,
#                            '2020-11-13 12:00:00': 2}),
#               'mediablog': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 8,
#                            '2020-11-13 11:42:00': 7}),
#               'websites': defaultdict(dict, {'2020-11-13 11:42:00': 2})}),
#  'Player 6': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict, {'2020-11-13 12:54:00': 3}),
#               'mail': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'microblog': defaultdict(dict, {'2020-11-13 12:54:00': 2})}),
#  'Player 4': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-11-13 12:18:00': 8,
#                            '2020-11-13 12:36:00': 2}),
#               'mail': defaultdict(dict, {'2020-11-13 12:36:00': 2}),
#               'microblog': defaultdict(dict, {'2020-11-13 12:18:00': 8})}),
#  'Player 3': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-11-13 12:00:00': 2,
#                            '2020-11-13 12:18:00': 7}),
#               'mail': defaultdict(dict, {'2020-11-13 12:18:00': 4}),
#               'microblog': defaultdict(dict,
#                           {'2020-11-13 12:00:00': 2,
#                            '2020-11-13 12:18:00': 3})}),
#  'Player 5': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-11-13 12:36:00': 2,
#                            '2020-11-13 12:54:00': 2}),
#               'gosocial': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'mail': defaultdict(dict,
#                           {'2020-11-13 12:36:00': 1,
#                            '2020-11-13 12:54:00': 1}),
#               'microblog': defaultdict(dict, {'2020-11-13 12:36:00': 1})})}

# %%
merged3.head()
# Out:
#                  date   name    channel interaction  \
# 0 2020-11-13 11:29:42  Marta       mail     forward
# 1 2020-11-13 11:30:27  Marta  microblog      repost
# 2 2020-11-13 11:30:29  Marta  microblog        like
# 3 2020-11-13 12:09:44  Marta   gosocial       reply
# 4 2020-11-13 11:31:30  Marta  microblog      repost
#
#                                Text     from              to  \
# 0  thank you!    We'll be in touch!  Marta R  Ben Operations
# 1                                    Marta R  BBC News - old
# 2                                    Marta R        BBC News
# 3                    shame on them!  Marta R        BBC News
# 4                                    Marta R          News24
#
#                                            image_url         type  Frequency  \
# 0  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 1  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 2  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 3  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
# 4  /assets/styles/36178/profiles/profile-e5xoX.jp...  participant          1
#
#                         email
# 0  martaruizperez96@gmail.com
# 1  martaruizperez96@gmail.com
# 2  martaruizperez96@gmail.com
# 3  martaruizperez96@gmail.com
# 4  martaruizperez96@gmail.com

# %%
#doing a similar analysis but by person - get a list of all from personas:

from_list=merged3["from"].to_list()
from_list_unique=[]
for item in from_list:
    if item not in from_list_unique:
        from_list_unique.append(item)

# %%
from_list_unique
# Out:
# ['Marta R',
#  'Bloomsburys',
#  'Mark',
#  'Claire',
#  'FizzPop',
#  'Player 6 ',
#  'BBC News',
#  'Player 4 ',
#  'News24',
#  'Player 3 ',
#  'Player 5 ']

# %%
merged_final2['date'] = pd.to_datetime(merged_final2['date'], infer_datetime_format=True)

# %%
dict4={}
for person in person_list_unique:
    frames=[]
    for from_p in from_list_unique:
        try:
            channel_1=merged_final2.loc[(merged_final2["name"]==f"{person}") &(merged_final2["from"]==f'{from_p}'), :]
            merged_time_all=channel_1.resample('0.3H', on='date').sum()
            merged_time_all["from"]=f"{from_p}"
            frames.append(merged_time_all)
        except:
            continue
   
    merged=pd.concat(frames)
    merged=merged.reset_index()
    merged['date']=merged['date'].astype(str)
    merged = merged.groupby(['from', "date"])
    merged1=pd.DataFrame(merged["Frequency"].sum())
    
    results1 = defaultdict(lambda: defaultdict(dict))
    for index, value in merged1.itertuples():
        for i, key in enumerate(index):
            if i == 0:
                nested = results1[key]
            elif i == len(index) - 1:
                nested[key] = value
        else:
            nested = nested[key]
    
    
    dict4.update({f'{person}':results1})

# %%
to_list=merged3["to"].to_list()
to_list_unique=[]
for item in to_list:
    if item not in to_list_unique:
        to_list_unique.append(item)

# %%
dict7={}
for person in person_list_unique:
    frames=[]
    for to_p in to_list_unique:
        try:
            channel_1=merged_final2.loc[(merged_final2["name"]==f"{person}") &(merged_final2["to"]==f'{to_p}'), :]
            merged_time_all=channel_1.resample('0.3H', on='date').sum()
            merged_time_all["to"]=f"{to_p}"
            frames.append(merged_time_all)
        except:
            continue
   
    merged=pd.concat(frames)
    merged=merged.reset_index()
    merged['date']=merged['date'].astype(str)
    merged = merged.groupby(['to', "date"])
    merged1=pd.DataFrame(merged["Frequency"].sum())
    
    results4 = defaultdict(lambda: defaultdict(dict))
    for index, value in merged1.itertuples():
        for i, key in enumerate(index):
            if i == 0:
                nested = results4[key]
            elif i == len(index) - 1:
                nested[key] = value
        else:
            nested = nested[key]
    
    
    dict7.update({f'{person}':results4})

# %%
dict7
# Out:
# {'Marta': defaultdict(<function __main__.<lambda>()>,
#              {'Alex': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'BBC News': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 0,
#                            '2020-11-13 12:00:00': 1}),
#               'BBC News - old': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'Ben Operations': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'Bloomsburys': defaultdict(dict, {'2020-11-13 11:42:00': 2}),
#               'Claire': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 0,
#                            '2020-11-13 12:00:00': 1}),
#               'FizzPop': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 1}),
#               'Food Industry News': defaultdict(dict,
#                           {'2020-11-13 11:42:00': 2}),
#               'Jill': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'Jim': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'Mark': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'Marta R': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 2,
#                            '2020-11-13 12:00:00': 1}),
#               'Martha': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'Rose': defaultdict(dict, {'2020-11-13 11:24:00': 2}),
#               'Steve Blake': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 0,
#                            '2020-11-13 12:00:00': 1})}),
#  'Player 6': defaultdict(<function __main__.<lambda>()>,
#              {'Ben Operations': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'Jane': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1})}),
#  'Player 4': defaultdict(<function __main__.<lambda>()>,
#              {'Bernard': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Claire': defaultdict(dict, {'2020-11-13 12:18:00': 2}),
#               'Jim': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'LittleJokes': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Marta R': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'Mia': defaultdict(dict, {'2020-11-13 12:18:00': 2}),
#               'News24': defaultdict(dict, {'2020-11-13 12:18:00': 2})}),
#  'Player 3': defaultdict(<function __main__.<lambda>()>,
#              {'Jackeee': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'James Quality': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Josh Sales': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Marta R': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Steve Blake': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Surf Official': defaultdict(dict, {'2020-11-13 12:00:00': 1}),
#               'Ventura Today': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               '\xa0\xa0 BenjaSniper\xa0': defaultdict(dict,
#                           {'2020-11-13 12:00:00': 1})}),
#  'Player 5': defaultdict(<function __main__.<lambda>()>,
#              {'Fernanda': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'Karen': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'Steve Ops Excellence': defaultdict(dict,
#                           {'2020-11-13 12:54:00': 1})})}

# %%
dict4
# Out:
# {'Marta': defaultdict(<function __main__.<lambda>()>,
#              {'Bloomsburys': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'Claire': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 1}),
#               'FizzPop': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 1}),
#               'Mark': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'Marta R': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 8,
#                            '2020-11-13 11:42:00': 8,
#                            '2020-11-13 12:00:00': 4})}),
#  'Player 6': defaultdict(<function __main__.<lambda>()>,
#              {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'Player 6 ': defaultdict(dict, {'2020-11-13 12:54:00': 2})}),
#  'Player 4': defaultdict(<function __main__.<lambda>()>,
#              {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 5}),
#               'News24': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Player 4 ': defaultdict(dict,
#                           {'2020-11-13 12:18:00': 2,
#                            '2020-11-13 12:36:00': 2})}),
#  'Player 3': defaultdict(<function __main__.<lambda>()>,
#              {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'FizzPop': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 12:00:00': 1}),
#               'Player 3 ': defaultdict(dict,
#                           {'2020-11-13 12:00:00': 1,
#                            '2020-11-13 12:18:00': 5})}),
#  'Player 5': defaultdict(<function __main__.<lambda>()>,
#              {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'Player 5 ': defaultdict(dict,
#                           {'2020-11-13 12:36:00': 1,
#                            '2020-11-13 12:54:00': 1})})}

# %%
person_list_unique
# Out:
# ['Marta', 'Player 6', 'Player 4', 'Player 3', 'Player 5']

# %%
dict4
# Out:
# {'Marta': defaultdict(<function __main__.<lambda>()>,
#              {'Bloomsburys': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#               'Claire': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 1}),
#               'FizzPop': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 1,
#                            '2020-11-13 11:42:00': 1}),
#               'Mark': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#               'Marta R': defaultdict(dict,
#                           {'2020-11-13 11:24:00': 8,
#                            '2020-11-13 11:42:00': 8,
#                            '2020-11-13 12:00:00': 4})}),
#  'Player 6': defaultdict(<function __main__.<lambda>()>,
#              {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'Player 6 ': defaultdict(dict, {'2020-11-13 12:54:00': 2})}),
#  'Player 4': defaultdict(<function __main__.<lambda>()>,
#              {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 5}),
#               'News24': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'Player 4 ': defaultdict(dict,
#                           {'2020-11-13 12:18:00': 2,
#                            '2020-11-13 12:36:00': 2})}),
#  'Player 3': defaultdict(<function __main__.<lambda>()>,
#              {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'FizzPop': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 12:00:00': 1}),
#               'Player 3 ': defaultdict(dict,
#                           {'2020-11-13 12:00:00': 1,
#                            '2020-11-13 12:18:00': 5})}),
#  'Player 5': defaultdict(<function __main__.<lambda>()>,
#              {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#               'News24': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#               'Player 5 ': defaultdict(dict,
#                           {'2020-11-13 12:36:00': 1,
#                            '2020-11-13 12:54:00': 1})})}

# %%
json_list
# Out:
# [{'impersonations': {'Marta': ['Bloomsburys',
#     'Claire',
#     'FizzPop',
#     'Mark',
#     'Marta R'],
#    'Player 3': ['BBC News', 'FizzPop', 'News24', 'Player 3 '],
#    'Player 4': ['BBC News', 'News24', 'Player 4 '],
#    'Player 5': ['Mark', 'News24', 'Player 5 '],
#    'Player 6': ['Mark', 'Player 6 ']}},
#  {'from': defaultdict(<function __main__.<lambda>()>,
#               {'Marta': defaultdict(dict,
#                            {'Bloomsburys': {'microblog': 1},
#                             'Claire': {'microblog': 2},
#                             'FizzPop': {'gosocial': 1, 'microblog': 1},
#                             'Mark': {'microblog': 1},
#                             'Marta R': {'gosocial': 2,
#                              'mail': 5,
#                              'mediablog': 1,
#                              'microblog': 10,
#                              'websites': 2}}),
#                'Player 3': defaultdict(dict,
#                            {'BBC News': {'microblog': 1},
#                             'FizzPop': {'microblog': 1},
#                             'News24': {'microblog': 1},
#                             'Player 3 ': {'mail': 4, 'microblog': 2}}),
#                'Player 4': defaultdict(dict,
#                            {'BBC News': {'microblog': 5},
#                             'News24': {'microblog': 1},
#                             'Player 4 ': {'mail': 2, 'microblog': 2}}),
#                'Player 5': defaultdict(dict,
#                            {'Mark': {'gosocial': 1},
#                             'News24': {'microblog': 1},
#                             'Player 5 ': {'mail': 2}}),
#                'Player 6': defaultdict(dict,
#                            {'Mark': {'microblog': 1},
#                             'Player 6 ': {'mail': 1, 'microblog': 1}})})}]

# %%
total_to_channel= merged_final.groupby(['name','to','channel'])
total_to_channel=pd.DataFrame(total_to_channel["Frequency"].count())
total_to_channel
# Out:
#                                          Frequency
# name     to                   channel
# Marta    Alex                 microblog          1
#          BBC News             gosocial           1
#                               microblog          1
#          BBC News - old       microblog          1
#          Ben Operations       mail               1
#          Bloomsburys          mail               1
#                               microblog          1
#          Claire               gosocial           2
#          FizzPop              microblog          2
#          Food Industry News   websites           2
#          Jill                 microblog          1
#          Jim                  mail               1
#          Mark                 microblog          1
#          Marta R              mail               1
#                               microblog          3
#          Martha               microblog          1
#          News24               microblog          1
#          Rose                 microblog          2
#          Steve Blake          mail               1
#                               mediablog          1
# Player 3 Jackeee              microblog          1
#          James Quality        mail               1
#          Josh Sales           mail               1
#          Marta R              mail               1
#          News24               microblog          1
#          Steve Blake          mail               1
#          Surf Official        microblog          1
#          Ventura Today        microblog          1
#             BenjaSniper       microblog          1
# Player 4 Bernard              microblog          1
#          Claire               microblog          2
#          Jim                  mail               1
#          LittleJokes          microblog          1
#          Marta R              mail               1
#          Mia                  microblog          2
#          News24               microblog          2
# Player 5 Fernanda             microblog          1
#          Karen                mail               1
#          Mark                 gosocial           1
#          Steve Ops Excellence mail               1
# Player 6 Ben Operations       mail               1
#          Jane                 microblog          1
#          Mark                 microblog          1

# %%
results5 = defaultdict(lambda: defaultdict(dict))

for index, value in total_to_channel.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results5[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
results6={"to":results5}
results6
# Out:
# {'to': defaultdict(<function __main__.<lambda>()>,
#              {'Marta': defaultdict(dict,
#                           {'Alex': {'microblog': 1},
#                            'BBC News': {'gosocial': 1, 'microblog': 1},
#                            'BBC News - old': {'microblog': 1},
#                            'Ben Operations': {'mail': 1},
#                            'Bloomsburys': {'mail': 1, 'microblog': 1},
#                            'Claire': {'gosocial': 2},
#                            'FizzPop': {'microblog': 2},
#                            'Food Industry News': {'websites': 2},
#                            'Jill': {'microblog': 1},
#                            'Jim': {'mail': 1},
#                            'Mark': {'microblog': 1},
#                            'Marta R': {'mail': 1, 'microblog': 3},
#                            'Martha': {'microblog': 1},
#                            'News24': {'microblog': 1},
#                            'Rose': {'microblog': 2},
#                            'Steve Blake': {'mail': 1, 'mediablog': 1}}),
#               'Player 3': defaultdict(dict,
#                           {'Jackeee': {'microblog': 1},
#                            'James Quality': {'mail': 1},
#                            'Josh Sales': {'mail': 1},
#                            'Marta R': {'mail': 1},
#                            'News24': {'microblog': 1},
#                            'Steve Blake': {'mail': 1},
#                            'Surf Official': {'microblog': 1},
#                            'Ventura Today': {'microblog': 1},
#                            '\xa0\xa0 BenjaSniper\xa0': {'microblog': 1}}),
#               'Player 4': defaultdict(dict,
#                           {'Bernard': {'microblog': 1},
#                            'Claire': {'microblog': 2},
#                            'Jim': {'mail': 1},
#                            'LittleJokes': {'microblog': 1},
#                            'Marta R': {'mail': 1},
#                            'Mia': {'microblog': 2},
#                            'News24': {'microblog': 2}}),
#               'Player 5': defaultdict(dict,
#                           {'Fernanda': {'microblog': 1},
#                            'Karen': {'mail': 1},
#                            'Mark': {'gosocial': 1},
#                            'Steve Ops Excellence': {'mail': 1}}),
#               'Player 6': defaultdict(dict,
#                           {'Ben Operations': {'mail': 1},
#                            'Jane': {'microblog': 1},
#                            'Mark': {'microblog': 1}})})}

# %%
json_list.append(results6)

# %%
dict5={"time_list": time_list}
json_list.append(dict5)

# %%
json_list.append(dict2)

# %%
json_list.append(dict4)

# %%
json_list.append(dict7)

# %%
json_list
# Out:
# [{'impersonations': {'Marta': ['Bloomsburys',
#     'Claire',
#     'FizzPop',
#     'Mark',
#     'Marta R'],
#    'Player 3': ['BBC News', 'FizzPop', 'News24', 'Player 3 '],
#    'Player 4': ['BBC News', 'News24', 'Player 4 '],
#    'Player 5': ['Mark', 'News24', 'Player 5 '],
#    'Player 6': ['Mark', 'Player 6 ']}},
#  {'from': defaultdict(<function __main__.<lambda>()>,
#               {'Marta': defaultdict(dict,
#                            {'Bloomsburys': {'microblog': 1},
#                             'Claire': {'microblog': 2},
#                             'FizzPop': {'gosocial': 1, 'microblog': 1},
#                             'Mark': {'microblog': 1},
#                             'Marta R': {'gosocial': 2,
#                              'mail': 5,
#                              'mediablog': 1,
#                              'microblog': 10,
#                              'websites': 2}}),
#                'Player 3': defaultdict(dict,
#                            {'BBC News': {'microblog': 1},
#                             'FizzPop': {'microblog': 1},
#                             'News24': {'microblog': 1},
#                             'Player 3 ': {'mail': 4, 'microblog': 2}}),
#                'Player 4': defaultdict(dict,
#                            {'BBC News': {'microblog': 5},
#                             'News24': {'microblog': 1},
#                             'Player 4 ': {'mail': 2, 'microblog': 2}}),
#                'Player 5': defaultdict(dict,
#                            {'Mark': {'gosocial': 1},
#                             'News24': {'microblog': 1},
#                             'Player 5 ': {'mail': 2}}),
#                'Player 6': defaultdict(dict,
#                            {'Mark': {'microblog': 1},
#                             'Player 6 ': {'mail': 1, 'microblog': 1}})})},
#  {'to': defaultdict(<function __main__.<lambda>()>,
#               {'Marta': defaultdict(dict,
#                            {'Alex': {'microblog': 1},
#                             'BBC News': {'gosocial': 1, 'microblog': 1},
#                             'BBC News - old': {'microblog': 1},
#                             'Ben Operations': {'mail': 1},
#                             'Bloomsburys': {'mail': 1, 'microblog': 1},
#                             'Claire': {'gosocial': 2},
#                             'FizzPop': {'microblog': 2},
#                             'Food Industry News': {'websites': 2},
#                             'Jill': {'microblog': 1},
#                             'Jim': {'mail': 1},
#                             'Mark': {'microblog': 1},
#                             'Marta R': {'mail': 1, 'microblog': 3},
#                             'Martha': {'microblog': 1},
#                             'News24': {'microblog': 1},
#                             'Rose': {'microblog': 2},
#                             'Steve Blake': {'mail': 1, 'mediablog': 1}}),
#                'Player 3': defaultdict(dict,
#                            {'Jackeee': {'microblog': 1},
#                             'James Quality': {'mail': 1},
#                             'Josh Sales': {'mail': 1},
#                             'Marta R': {'mail': 1},
#                             'News24': {'microblog': 1},
#                             'Steve Blake': {'mail': 1},
#                             'Surf Official': {'microblog': 1},
#                             'Ventura Today': {'microblog': 1},
#                             '\xa0\xa0 BenjaSniper\xa0': {'microblog': 1}}),
#                'Player 4': defaultdict(dict,
#                            {'Bernard': {'microblog': 1},
#                             'Claire': {'microblog': 2},
#                             'Jim': {'mail': 1},
#                             'LittleJokes': {'microblog': 1},
#                             'Marta R': {'mail': 1},
#                             'Mia': {'microblog': 2},
#                             'News24': {'microblog': 2}}),
#                'Player 5': defaultdict(dict,
#                            {'Fernanda': {'microblog': 1},
#                             'Karen': {'mail': 1},
#                             'Mark': {'gosocial': 1},
#                             'Steve Ops Excellence': {'mail': 1}}),
#                'Player 6': defaultdict(dict,
#                            {'Ben Operations': {'mail': 1},
#                             'Jane': {'microblog': 1},
#                             'Mark': {'microblog': 1}})})},
#  {'time_list': ['2020-11-13 11:24:00',
#    '2020-11-13 11:42:00',
#    '2020-11-13 12:00:00',
#    '2020-11-13 12:18:00',
#    '2020-11-13 12:36:00',
#    '2020-11-13 12:54:00']},
#  {'Marta': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 11,
#                             '2020-11-13 11:42:00': 11,
#                             '2020-11-13 12:00:00': 4}),
#                'gosocial': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 0,
#                             '2020-11-13 12:00:00': 2}),
#                'mail': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 2,
#                             '2020-11-13 12:00:00': 2}),
#                'mediablog': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 8,
#                             '2020-11-13 11:42:00': 7}),
#                'websites': defaultdict(dict, {'2020-11-13 11:42:00': 2})}),
#   'Player 6': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict, {'2020-11-13 12:54:00': 3}),
#                'mail': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'microblog': defaultdict(dict, {'2020-11-13 12:54:00': 2})}),
#   'Player 4': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-11-13 12:18:00': 8,
#                             '2020-11-13 12:36:00': 2}),
#                'mail': defaultdict(dict, {'2020-11-13 12:36:00': 2}),
#                'microblog': defaultdict(dict, {'2020-11-13 12:18:00': 8})}),
#   'Player 3': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-11-13 12:00:00': 2,
#                             '2020-11-13 12:18:00': 7}),
#                'mail': defaultdict(dict, {'2020-11-13 12:18:00': 4}),
#                'microblog': defaultdict(dict,
#                            {'2020-11-13 12:00:00': 2,
#                             '2020-11-13 12:18:00': 3})}),
#   'Player 5': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-11-13 12:36:00': 2,
#                             '2020-11-13 12:54:00': 2}),
#                'gosocial': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'mail': defaultdict(dict,
#                            {'2020-11-13 12:36:00': 1,
#                             '2020-11-13 12:54:00': 1}),
#                'microblog': defaultdict(dict, {'2020-11-13 12:36:00': 1})})},
#  {'Marta': defaultdict(<function __main__.<lambda>()>,
#               {'Bloomsburys': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'Claire': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 1}),
#                'FizzPop': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 1}),
#                'Mark': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#                'Marta R': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 8,
#                             '2020-11-13 11:42:00': 8,
#                             '2020-11-13 12:00:00': 4})}),
#   'Player 6': defaultdict(<function __main__.<lambda>()>,
#               {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'Player 6 ': defaultdict(dict, {'2020-11-13 12:54:00': 2})}),
#   'Player 4': defaultdict(<function __main__.<lambda>()>,
#               {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 5}),
#                'News24': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Player 4 ': defaultdict(dict,
#                            {'2020-11-13 12:18:00': 2,
#                             '2020-11-13 12:36:00': 2})}),
#   'Player 3': defaultdict(<function __main__.<lambda>()>,
#               {'BBC News': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'FizzPop': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'News24': defaultdict(dict, {'2020-11-13 12:00:00': 1}),
#                'Player 3 ': defaultdict(dict,
#                            {'2020-11-13 12:00:00': 1,
#                             '2020-11-13 12:18:00': 5})}),
#   'Player 5': defaultdict(<function __main__.<lambda>()>,
#               {'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'News24': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#                'Player 5 ': defaultdict(dict,
#                            {'2020-11-13 12:36:00': 1,
#                             '2020-11-13 12:54:00': 1})})},
#  {'Marta': defaultdict(<function __main__.<lambda>()>,
#               {'Alex': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'BBC News': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 0,
#                             '2020-11-13 12:00:00': 1}),
#                'BBC News - old': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'Ben Operations': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'Bloomsburys': defaultdict(dict, {'2020-11-13 11:42:00': 2}),
#                'Claire': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 0,
#                             '2020-11-13 12:00:00': 1}),
#                'FizzPop': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 1}),
#                'Food Industry News': defaultdict(dict,
#                            {'2020-11-13 11:42:00': 2}),
#                'Jill': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#                'Jim': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#                'Mark': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#                'Marta R': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 2,
#                             '2020-11-13 12:00:00': 1}),
#                'Martha': defaultdict(dict, {'2020-11-13 11:42:00': 1}),
#                'News24': defaultdict(dict, {'2020-11-13 11:24:00': 1}),
#                'Rose': defaultdict(dict, {'2020-11-13 11:24:00': 2}),
#                'Steve Blake': defaultdict(dict,
#                            {'2020-11-13 11:24:00': 1,
#                             '2020-11-13 11:42:00': 0,
#                             '2020-11-13 12:00:00': 1})}),
#   'Player 6': defaultdict(<function __main__.<lambda>()>,
#               {'Ben Operations': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'Jane': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1})}),
#   'Player 4': defaultdict(<function __main__.<lambda>()>,
#               {'Bernard': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Claire': defaultdict(dict, {'2020-11-13 12:18:00': 2}),
#                'Jim': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#                'LittleJokes': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Marta R': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#                'Mia': defaultdict(dict, {'2020-11-13 12:18:00': 2}),
#                'News24': defaultdict(dict, {'2020-11-13 12:18:00': 2})}),
#   'Player 3': defaultdict(<function __main__.<lambda>()>,
#               {'Jackeee': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'James Quality': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Josh Sales': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Marta R': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'News24': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Steve Blake': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                'Surf Official': defaultdict(dict, {'2020-11-13 12:00:00': 1}),
#                'Ventura Today': defaultdict(dict, {'2020-11-13 12:18:00': 1}),
#                '\xa0\xa0 BenjaSniper\xa0': defaultdict(dict,
#                            {'2020-11-13 12:00:00': 1})}),
#   'Player 5': defaultdict(<function __main__.<lambda>()>,
#               {'Fernanda': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#                'Karen': defaultdict(dict, {'2020-11-13 12:36:00': 1}),
#                'Mark': defaultdict(dict, {'2020-11-13 12:54:00': 1}),
#                'Steve Ops Excellence': defaultdict(dict,
#                            {'2020-11-13 12:54:00': 1})})}]

# %%
with open('player_data.json', 'w') as fp:
    json.dump(json_list, fp)

# %%
with open('dropdown_work/player_data.json', 'w') as fp:
    json.dump(json_list, fp)

# %%
merged_final2=merged_final[["date", "name", "channel", "interaction", "Text", "from", "to"]]

# %%
merged_final2["Text"]=merged_final2["Text"].replace("", "No Text")
# Out:
# /Users/dhanyamaheswaran/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
merged_final2=pd.DataFrame(merged_final2)
merged_final2
# Out:
#                    date      name    channel interaction  \
# 0   2020-11-13 11:29:42     Marta       mail     forward
# 1   2020-11-13 11:30:27     Marta  microblog      repost
# 2   2020-11-13 11:30:29     Marta  microblog        like
# 3   2020-11-13 12:09:44     Marta   gosocial       reply
# 4   2020-11-13 11:31:30     Marta  microblog      repost
# 5   2020-11-13 11:36:07     Marta  mediablog       reply
# 6   2020-11-13 12:05:40     Marta       mail     forward
# 7   2020-11-13 11:37:02     Marta  microblog      repost
# 8   2020-11-13 11:37:36     Marta  microblog       reply
# 9   2020-11-13 11:37:44     Marta  microblog      repost
# 10  2020-11-13 11:46:42     Marta  microblog       reply
# 11  2020-11-13 11:39:01     Marta  microblog        like
# 12  2020-11-13 11:42:03     Marta   websites       reply
# 13  2020-11-13 11:42:04     Marta   websites       reply
# 14  2020-11-13 11:49:20     Marta  microblog      repost
# 15  2020-11-13 11:49:45     Marta  microblog      repost
# 16  2020-11-13 11:51:32     Marta  microblog      repost
# 17  2020-11-13 11:57:10     Marta       mail         new
# 18  2020-11-13 11:51:07     Marta  microblog       reply
# 19  2020-11-13 11:57:10     Marta       mail         new
# 20  2020-11-13 12:05:40     Marta       mail     forward
# 21  2020-11-13 11:38:23     Marta  microblog       reply
# 22  2020-11-13 11:47:18     Marta  microblog       reply
# 23  2020-11-13 11:44:11     Marta  microblog       reply
# 24  2020-11-13 12:08:58     Marta   gosocial       reply
# 25  2020-11-13 11:40:21     Marta   gosocial       reply
# 26  2020-11-13 13:03:03  Player 6       mail       reply
# 27  2020-11-13 13:11:53  Player 6  microblog        like
# 28  2020-11-13 13:11:35  Player 6  microblog      repost
# 29  2020-11-13 12:35:09  Player 4  microblog        like
# 30  2020-11-13 12:35:28  Player 4  microblog       reply
# 31  2020-11-13 12:36:31  Player 4       mail         new
# 32  2020-11-13 12:36:31  Player 4       mail         new
# 33  2020-11-13 12:35:48  Player 4  microblog        like
# 34  2020-11-13 12:34:46  Player 4  microblog        like
# 35  2020-11-13 12:35:04  Player 4  microblog      repost
# 36  2020-11-13 12:35:33  Player 4  microblog        like
# 37  2020-11-13 12:35:50  Player 4  microblog      repost
# 38  2020-11-13 12:32:35  Player 4  microblog      repost
# 39  2020-11-13 12:28:45  Player 3  microblog        like
# 40  2020-11-13 12:20:02  Player 3       mail     forward
# 41  2020-11-13 12:22:44  Player 3       mail     forward
# 42  2020-11-13 12:17:24  Player 3  microblog      repost
# 43  2020-11-13 12:18:23  Player 3  microblog      repost
# 44  2020-11-13 12:24:39  Player 3  microblog       reply
# 45  2020-11-13 12:16:37  Player 3  microblog      repost
# 46  2020-11-13 12:22:44  Player 3       mail     forward
# 47  2020-11-13 12:27:11  Player 3       mail       reply
# 48  2020-11-13 12:59:18  Player 5   gosocial       reply
# 49  2020-11-13 12:48:48  Player 5  microblog      repost
# 50  2020-11-13 12:50:40  Player 5       mail       reply
# 51  2020-11-13 12:57:04  Player 5       mail       reply
#
#                                                  Text         from  \
# 0                    thank you!    We'll be in touch!      Marta R
# 1                                             No Text      Marta R
# 2                                             No Text      Marta R
# 3                                      shame on them!      Marta R
# 4                                             No Text      Marta R
# 5                                       That is great      Marta R
# 6              This is awful!    Please, help us to s      Marta R
# 7                                             No Text      Marta R
# 8   We are very sorry to hear this. We'll investig...  Bloomsburys
# 9                                             No Text      Marta R
# 10                          You are so unprofessional      Marta R
# 11                                            No Text      Marta R
# 12                                      It's a shame!      Marta R
# 13                                      It's a shame!      Marta R
# 14                                            No Text      Marta R
# 15                                            No Text      Marta R
# 16                                            No Text      Marta R
# 17  I've been watching social media and customers ...      Marta R
# 18    Will you at least give money back to customers?         Mark
# 19  I've been watching social media and customers ...      Marta R
# 20             This is awful!    Please, help us to s      Marta R
# 21                                           me, too!       Claire
# 22      FizzPop needs to explain, so does Bloomsburys       Claire
# 23                 We are investigating what happened      FizzPop
# 24                                                Omg      Marta R
# 25     We're investigating it. We'll update you soon!      FizzPop
# 26  I learned how to manage an incident  How to re...    Player 6
# 27                                            No Text         Mark
# 28                                            No Text    Player 6
# 29                                            No Text     BBC News
# 30                                 you are funny mate     BBC News
# 31                                   what's the plan?    Player 4
# 32                                   what's the plan?    Player 4
# 33                                            No Text     BBC News
# 34                                            No Text    Player 4
# 35                                            No Text       News24
# 36                                            No Text     BBC News
# 37                                            No Text     BBC News
# 38                                            No Text    Player 4
# 39                                            No Text    Player 3
# 40                                         thank you!    Player 3
# 41             thank you    We need to follow this in    Player 3
# 42                                            No Text       News24
# 43                                            No Text      FizzPop
# 44                       You stole our breaking news!     BBC News
# 45                                            No Text    Player 3
# 46             thank you    We need to follow this in    Player 3
# 47  Tell them this won't happen again    We take t...    Player 3
# 48                                                hey         Mark
# 49                                            No Text       News24
# 50                     It's none of your business tbh    Player 5
# 51                               It's okay, thank you    Player 5
#
#                       to
# 0         Ben Operations
# 1         BBC News - old
# 2               BBC News
# 3               BBC News
# 4                 News24
# 5            Steve Blake
# 6            Steve Blake
# 7                   Rose
# 8                   Rose
# 9                FizzPop
# 10               FizzPop
# 11                  Alex
# 12    Food Industry News
# 13    Food Industry News
# 14                  Jill
# 15                Martha
# 16                  Mark
# 17           Bloomsburys
# 18           Bloomsburys
# 19                   Jim
# 20               Marta R
# 21               Marta R
# 22               Marta R
# 23               Marta R
# 24                Claire
# 25                Claire
# 26        Ben Operations
# 27                  Mark
# 28                  Jane
# 29                News24
# 30                News24
# 31                   Jim
# 32               Marta R
# 33                Claire
# 34                Claire
# 35                   Mia
# 36                   Mia
# 37           LittleJokes
# 38               Bernard
# 39                News24
# 40           Steve Blake
# 41               Marta R
# 42          BenjaSniper
# 43               Jackeee
# 44         Ventura Today
# 45         Surf Official
# 46         James Quality
# 47            Josh Sales
# 48                  Mark
# 49              Fernanda
# 50                 Karen
# 51  Steve Ops Excellence

# %%
#iterating through mandas and making it a dictionary 
data_list=[]

date=merged_final2['date'].to_list()
name=merged_final2["name"].to_list()
channel=merged_final2["channel"].to_list()
interaction=merged_final2["interaction"].to_list()
text=merged_final2["Text"].to_list()
from_list=merged_final2["from"].to_list()
to_list=merged_final2["to"].to_list()


for i in range(0, len(date)):
    dict2={"Name":name[i], "Date":date[i], "Channel":channel[i], "Interaction":interaction[i], 
           "Text":text[i], "From":from_list[i], "To":to_list[i]}
    data_list.append(dict2)

# %%
data_list
# Out:
# [{'Name': 'Marta',
#   'Date': '2020-11-13 11:29:42',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': "thank you!    We'll be in touch!",
#   'From': 'Marta R',
#   'To': 'Ben Operations'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:30:27',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'BBC News - old'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:30:29',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'BBC News'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 12:09:44',
#   'Channel': 'gosocial',
#   'Interaction': 'reply',
#   'Text': 'shame on them!',
#   'From': 'Marta R',
#   'To': 'BBC News'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:31:30',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'News24'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:36:07',
#   'Channel': 'mediablog',
#   'Interaction': 'reply',
#   'Text': 'That is great',
#   'From': 'Marta R',
#   'To': 'Steve Blake'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 12:05:40',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': 'This is awful!    Please, help us to s',
#   'From': 'Marta R',
#   'To': 'Steve Blake'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:37:02',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'Rose'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:37:36',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': "We are very sorry to hear this. We'll investigate what happened and send you some update soon.",
#   'From': 'Bloomsburys',
#   'To': 'Rose'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:37:44',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'FizzPop'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:46:42',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'You are so unprofessional',
#   'From': 'Marta R',
#   'To': 'FizzPop'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:39:01',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'Alex'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:42:03',
#   'Channel': 'websites',
#   'Interaction': 'reply',
#   'Text': "It's a shame!",
#   'From': 'Marta R',
#   'To': 'Food Industry News'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:42:04',
#   'Channel': 'websites',
#   'Interaction': 'reply',
#   'Text': "It's a shame!",
#   'From': 'Marta R',
#   'To': 'Food Industry News'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:49:20',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'Jill'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:49:45',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'Martha'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:51:32',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Marta R',
#   'To': 'Mark'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:57:10',
#   'Channel': 'mail',
#   'Interaction': 'new',
#   'Text': "I've been watching social media and customers are very angry about this incident?    What's your plan?  We need to act as soon as possible.    Are you giving money back to customers? If you don't pay back, that will make of both of your companies' reputation a huge crisis.    We need to respond professionally to this matter    I expect no less from you  Please, don't let me down on this    Regards,  marta",
#   'From': 'Marta R',
#   'To': 'Bloomsburys'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:51:07',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'Will you at least give money back to customers?',
#   'From': 'Mark',
#   'To': 'Bloomsburys'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:57:10',
#   'Channel': 'mail',
#   'Interaction': 'new',
#   'Text': "I've been watching social media and customers are very angry about this incident?    What's your plan?  We need to act as soon as possible.    Are you giving money back to customers? If you don't pay back, that will make of both of your companies' reputation a huge crisis.    We need to respond professionally to this matter    I expect no less from you  Please, don't let me down on this    Regards,  marta",
#   'From': 'Marta R',
#   'To': 'Jim'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 12:05:40',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': 'This is awful!    Please, help us to s',
#   'From': 'Marta R',
#   'To': 'Marta R'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:38:23',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'me, too!',
#   'From': 'Claire',
#   'To': 'Marta R'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:47:18',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'FizzPop needs to explain, so does Bloomsburys',
#   'From': 'Claire',
#   'To': 'Marta R'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:44:11',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'We are investigating what happened',
#   'From': 'FizzPop',
#   'To': 'Marta R'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 12:08:58',
#   'Channel': 'gosocial',
#   'Interaction': 'reply',
#   'Text': 'Omg',
#   'From': 'Marta R',
#   'To': 'Claire'},
#  {'Name': 'Marta',
#   'Date': '2020-11-13 11:40:21',
#   'Channel': 'gosocial',
#   'Interaction': 'reply',
#   'Text': "We're investigating it. We'll update you soon!",
#   'From': 'FizzPop',
#   'To': 'Claire'},
#  {'Name': 'Player 6',
#   'Date': '2020-11-13 13:03:03',
#   'Channel': 'mail',
#   'Interaction': 'reply',
#   'Text': "I learned how to manage an incident  How to respond    I'll be prepared to confront this kind of issues from now on",
#   'From': 'Player 6 ',
#   'To': 'Ben Operations'},
#  {'Name': 'Player 6',
#   'Date': '2020-11-13 13:11:53',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'Mark',
#   'To': 'Mark'},
#  {'Name': 'Player 6',
#   'Date': '2020-11-13 13:11:35',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Player 6 ',
#   'To': 'Jane'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:09',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'BBC News',
#   'To': 'News24'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:28',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'you are funny mate',
#   'From': 'BBC News',
#   'To': 'News24'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:36:31',
#   'Channel': 'mail',
#   'Interaction': 'new',
#   'Text': "what's the plan?",
#   'From': 'Player 4 ',
#   'To': 'Jim'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:36:31',
#   'Channel': 'mail',
#   'Interaction': 'new',
#   'Text': "what's the plan?",
#   'From': 'Player 4 ',
#   'To': 'Marta R'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:48',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'BBC News',
#   'To': 'Claire'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:34:46',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'Player 4 ',
#   'To': 'Claire'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:04',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'News24',
#   'To': 'Mia'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:33',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'BBC News',
#   'To': 'Mia'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:35:50',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'BBC News',
#   'To': 'LittleJokes'},
#  {'Name': 'Player 4',
#   'Date': '2020-11-13 12:32:35',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Player 4 ',
#   'To': 'Bernard'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:28:45',
#   'Channel': 'microblog',
#   'Interaction': 'like',
#   'Text': 'No Text',
#   'From': 'Player 3 ',
#   'To': 'News24'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:20:02',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': 'thank you!',
#   'From': 'Player 3 ',
#   'To': 'Steve Blake'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:22:44',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': 'thank you    We need to follow this in',
#   'From': 'Player 3 ',
#   'To': 'Marta R'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:17:24',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'News24',
#   'To': '\xa0\xa0 BenjaSniper\xa0'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:18:23',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'FizzPop',
#   'To': 'Jackeee'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:24:39',
#   'Channel': 'microblog',
#   'Interaction': 'reply',
#   'Text': 'You stole our breaking news!',
#   'From': 'BBC News',
#   'To': 'Ventura Today'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:16:37',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'Player 3 ',
#   'To': 'Surf Official'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:22:44',
#   'Channel': 'mail',
#   'Interaction': 'forward',
#   'Text': 'thank you    We need to follow this in',
#   'From': 'Player 3 ',
#   'To': 'James Quality'},
#  {'Name': 'Player 3',
#   'Date': '2020-11-13 12:27:11',
#   'Channel': 'mail',
#   'Interaction': 'reply',
#   'Text': "Tell them this won't happen again    We take this issue very seriously and will ensure this does not affect our customers ever again. We are of course very glad that our customers understood the circumstances.    ",
#   'From': 'Player 3 ',
#   'To': 'Josh Sales'},
#  {'Name': 'Player 5',
#   'Date': '2020-11-13 12:59:18',
#   'Channel': 'gosocial',
#   'Interaction': 'reply',
#   'Text': 'hey',
#   'From': 'Mark',
#   'To': 'Mark'},
#  {'Name': 'Player 5',
#   'Date': '2020-11-13 12:48:48',
#   'Channel': 'microblog',
#   'Interaction': 'repost',
#   'Text': 'No Text',
#   'From': 'News24',
#   'To': 'Fernanda'},
#  {'Name': 'Player 5',
#   'Date': '2020-11-13 12:50:40',
#   'Channel': 'mail',
#   'Interaction': 'reply',
#   'Text': "It's none of your business tbh",
#   'From': 'Player 5 ',
#   'To': 'Karen'},
#  {'Name': 'Player 5',
#   'Date': '2020-11-13 12:57:04',
#   'Channel': 'mail',
#   'Interaction': 'reply',
#   'Text': "It's okay, thank you",
#   'From': 'Player 5 ',
#   'To': 'Steve Ops Excellence'}]

# %%
with open('player_csv.json', 'w') as fp:
    json.dump(data_list, fp)
