# %%
import csv, json, requests
import streamlit as st
import pandas as pd
import seaborn as sns
import data_config
import re
import numpy as np
from itertools import chain
from collections import defaultdict

# %%
consumer_key = data_config.consumer_key
partition_id = data_config.partition_id

# %%
def get_following(consumer_key,partition_id):
    url = data_config.get_following+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    
    return data["response"]

# %%
def get_permissions(consumer_key,partition_id):
    url = data_config.get_permssions+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    #print(response)
    data = json.loads(response.content)
    data = data["response"]["permissions"]
    return data

# %%
#timeline and type of interaction 
def get_message_data(consumer_key,partition_id):
    url = data_config.get_activity+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    #st.write(data)
    timeline = data["detailed_log"]
    summary = data["summary"]
    return timeline, summary

# %%
#what is positions who can edit, probably not needed 
def get_cloud_personas(consumer_key,partition_id):
    url = data_config.get_personas+partition_id
    headers = {"Authorization":"Bearer "+consumer_key}
    response = requests.get(url, headers=headers)
    data = json.loads(response.content)
    return data["response"]["personas"]

# %%
#remove duplicates from the list
def remove_duplicates(list, unique_list):
    for item in list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

# %%
def remove_bracket(list):
    list1=[]
    for item in list:
        item2 = item[1:]
        list1.append(item2)
    return list1

# %%
data=get_message_data(consumer_key,partition_id)

# %%
data1=list(data)
keys=data[0].keys()

# %%
dates=[]
for i in keys:
    dates.append(i)

# %%
persona_id=[]
for i in range(0, len(dates)):
    id=dates[i][-5:]
    persona_id.append(id)

# %%
values1=[]
values=data[0].values()
for i in values:
    values1.append(i)

# %%
#split the reponse based on the channel 
channel=[]
interaction=[]
RFI=[]
text=[]
id1=[]
id2=[]

for i in range(0, len(values1)):
    x = values1[i].split("]")
    channel.append(x[0])
    interaction.append(x[1])
    RFI.append(x[2])
    text.append(x[3])
    id1.append(x[4])
    id2.append(x[5])

# %%
interaction=remove_bracket(interaction)
channel=remove_bracket(channel)
RFI=remove_bracket(RFI)
text=remove_bracket(text)
id1=remove_bracket(id1)
id2=remove_bracket(id2)

# %%
#editing the text cell in more detail 
#need to remove the <br / br> 
#also need to remove the //
text2=[]
for item in text:
    edited_text=re.sub("(<br\s*/>)","", item)
    edited_text=re.sub("(<b)","", edited_text)
    edited_text=edited_text.replace("\\","")
    text2.append(edited_text)

# %%
#editing the date:
dates
dates2=[]
for item in dates:
    item1=item[:-6]
    dates2.append(item1)

# %%
df=pd.DataFrame({"date": dates2, "persona_id":persona_id,"channel": channel, "interaction": interaction, 
                 "Text":text2, "From": id1, "To":id2})

df.head()
# Out:
#                   date persona_id    channel interaction  \
# 0  2020-07-13 08:45:36      wKoOd  microblog      repost
# 1  2020-07-13 09:00:51      wKoOd  microblog       reply
# 2  2020-07-13 09:04:40      XAOv7  microblog         new
# 3  2020-07-13 09:10:53      XAOv7  microblog         new
# 4  2020-07-13 09:10:56      PBOK7       mail         new
#
#                                                 Text           From  \
# 0                                                     ozak9mvjiecmn
# 1  The Government is in bed with the oil companie...  ozak9mvjiecmn
# 2  Good morning my lovely people! Let's hope toda...  kwskaxz7hpack
# 3  The Bonni people are proud people, don't forge...  kwskaxz7hpack
# 4             Chaps,    To follow my original email.  p4jkb0gax73nd
#
#                                                   To
# 0                                      ozak9wtk2p49b
# 1                                      ozak9wtk2p49b
# 2
# 3
# 4  p4jkbz6kkxype,p4jkbz6wkiokx,p4jkbz6wkiom8,p4jk...

# %%
persona=get_cloud_personas(consumer_key,partition_id)

# %%
persona_id
unique_persona_id=[]
for item in persona_id:
    if item not in unique_persona_id:
        unique_persona_id.append(item)

# %%
#linking the ids with the unique persona, need to understand the json document that need sto do thisu

persona_keys=persona.keys()

# %%
name=[]
imageURL=[]
type=[]

for item in unique_persona_id:
    name.append(persona[item]["details"]["name"])
    imageURL.append(persona[item]["details"]["imageUrl"])
    type.append(persona[item]["details"]["type"])

# %%
persona_df=pd.DataFrame({"persona_id":unique_persona_id, "name": name, "image_url":imageURL, "type":type})

# %%
persona_df
# Out:
#    persona_id                                  name  \
# 0       wKoOd                       Guardian Hamani
# 1       XAOv7                         Dolly Dkwueme
# 2       PBOK7  Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)
# 3       jGgXp                        Chinwe Jelanee
# 4       JB7DW                              Blue One
# 5       7y7OM                       Benjamin Pepple
# 6       1jr5l                            Adaego Eze
# 7       p0oOg                      Telegraph Hamani
# 8       AB7aQ                           Hamani Heat
# 9       gPOzL                              Blue Two
# 10      d5wza                            Blue Three
# 11      aLOKB                             Blue Four
# 12      rAogO                             Blue Five
# 13      oaog6                            Debare Oni
# 14      k1wgl                             Joy Okoye
# 15      nvogp                              Blue Six
#
#                                 image_url        type
# 0   /assets/styles/32563/profiles/you.png  rolePlayer
# 1   /assets/styles/32563/profiles/you.png  rolePlayer
# 2   /assets/styles/32563/profiles/you.png  rolePlayer
# 3   /assets/styles/32563/profiles/you.png  rolePlayer
# 4   /assets/styles/32563/profiles/you.png  rolePlayer
# 5   /assets/styles/32563/profiles/you.png  rolePlayer
# 6   /assets/styles/32563/profiles/you.png  rolePlayer
# 7   /assets/styles/32563/profiles/you.png  rolePlayer
# 8   /assets/styles/32563/profiles/you.png  rolePlayer
# 9   /assets/styles/32563/profiles/you.png  rolePlayer
# 10  /assets/styles/32563/profiles/you.png  rolePlayer
# 11  /assets/styles/32563/profiles/you.png  rolePlayer
# 12  /assets/styles/32563/profiles/you.png  rolePlayer
# 13  /assets/styles/32563/profiles/you.png  rolePlayer
# 14  /assets/styles/32563/profiles/you.png  rolePlayer
# 15  /assets/styles/32563/profiles/you.png  rolePlayer

# %%
#removing blank spaces
nospace_id2=list(filter(None, id2))

edited_list2 = [y for x in nospace_id2 for y in x.split(',')]

# %%
#getting a list of unique_ids
all_ids=id1+edited_list2
unique_ids=[]
remove_duplicates(all_ids, unique_ids)
unique_ids
# Out:
# ['ozak9mvjiecmn',
#  'kwskaxz7hpack',
#  'p4jkb0gax73nd',
#  'p7vkaz5il80cd',
#  'p4jkbz6kkxype',
#  'p4jkb2nkm9f91',
#  'kwskazf32n63z',
#  'kwskaxux9vx1e',
#  'kwskazfmgo8ax',
#  'p7vkaz52tvvfb',
#  'ozak9wrvu3bdm',
#  'p4jkbz6wkiom8',
#  'p4jkbz6wkio1c',
#  'p4jkbz6wkiokx',
#  'p4jkbz6wkio3v',
#  'okdk9z8265eb4',
#  'ozak9my2e0ydc',
#  'okdk9z8mbqvk1',
#  'ozak9my5nj6av',
#  'okdk9mw8wh06e',
#  'kwskay3lhjh5i',
#  'p7vkb26y081r1',
#  'ozak9mxxbpofl',
#  'ozak9mywukuoz',
#  'p4jkbz6wkio6a',
#  'p7vkb0hvklj6h',
#  'p4jkbhu9ulcb4',
#  'kwskazfp12mqb',
#  'ozak9wtk2p49b',
#  'kwskazeey2w8m',
#  'gvgkbj2vji6l6',
#  'p4jkats3l3257',
#  'p7vkb26yz7j33',
#  'p7vkazij4vimn',
#  'p7vkazihxagc3',
#  'p4jkb2n1tz11d',
#  'p7vkb0jrqsr7k',
#  'ozak9wtkjo7al',
#  'p7vkbakejnydw',
#  'p4jkbj1bmky37',
#  'p7vkazijiyyqb',
#  'okdkb5g65t53k',
#  'p4jkbj1bmhh9o',
#  'gvgkbg8t4n14u',
#  'p4jkbj1bmqpmc',
#  'p7vkazijbz95a',
#  'gvgkbj5pu3jew',
#  'okdkb5f1cngbs',
#  'p1gkbkfrwyh5s',
#  'gvgkbj4uw00ee',
#  'gvgkbj5rvwg2k',
#  'gvgkbj5qzy158',
#  'p1gkbki7b10ob',
#  'p1gkbkfr7juow',
#  'okdkb5f04i2lo',
#  'gvgkbj5rmb9bd',
#  'p1gkbki6xfday',
#  'p1gkbki6qcxcx',
#  'p1gkbki571zaa',
#  'gvgkbj5rh9lb9',
#  'kwskbgedbs0fb',
#  'p1gkbki5rdk8s',
#  'p1gkbki48uu3c',
#  'p1gkbki50blfe',
#  'p4jkbi53k3fe3',
#  'p4jkbi53kbpkx',
#  'kwskbghih4ue1',
#  'p4jkbi53k5e86',
#  'okdkb5g2lsr3s',
#  'p4jkbi53kcdg4',
#  'p4jkbi53kg8eb',
#  'p4jkbi53k8fdz',
#  'p4jkbi53kgxrj',
#  'p4jkbi53kun60',
#  'p4jkbi53k44hc',
#  'p4jkbi53k5wif',
#  'p7vkazij8l3rh']

# %%
twitter=[]
twitter_number=[]
twitter_followers=[]
twitter_following=[]
email=[]

gosocial_name=[]
gosocial_number=[]
gosocial_followers=[]


for item in unique_ids:
    #twitter data
    twitter.append(persona[item]["microblog"]["displayName"])
    twitter_number.append(persona[item]["microblog"]["numMessages"])
    twitter_followers.append(persona[item]["microblog"]["followers"])
    twitter_following.append(persona[item]["microblog"]["following"])
    
    #email
    email.append(persona[item]["mail"]["email"])
    
    #GoSocial
    gosocial_name.append(persona[item]["gosocial"]["displayName"])
    gosocial_number.append(persona[item]["gosocial"]["numMessages"])
    gosocial_followers.append(persona[item]["gosocial"]["followers"])

# %%
#Player_activity_dataset

channel_df=pd.DataFrame({"From":unique_ids, "twitter name":twitter, "twitter messages":twitter_number,
             "twitter followers":twitter_followers, "twitter_following":twitter_following,
             "email":email, "goSocial name": gosocial_name, "goSocial messages": gosocial_number, "goSocial Followers":gosocial_followers
    
})

# %%
channel_df.head(20)


##to_merged=channel_df[["To", ]]
# Out:
#              From                           twitter name  twitter messages  \
# 0   ozak9mvjiecmn                        Guardian Hamani               709
# 1   kwskaxz7hpack                          Dolly Dkwueme                56
# 2   p4jkb0gax73nd  Write, Tom Lt Col (SJFHQ-JFHQ-J6-SO1)                 0
# 3   p7vkaz5il80cd                         Chinwe Jelanee                 0
# 4   p4jkbz6kkxype                               Blue One                 0
# 5   p4jkb2nkm9f91                         Stanley Ojukwu              6543
# 6   kwskazf32n63z                        Benjamin Pepple                 8
# 7   kwskaxux9vx1e                             Adaego Eze                 0
# 8   kwskazfmgo8ax                                    PDP              7865
# 9   p7vkaz52tvvfb                            Hamani Heat                 0
# 10  ozak9wrvu3bdm                           British Army                 0
# 11  p4jkbz6wkiom8                       Police Reform HA                 0
# 12  p4jkbz6wkio1c                                Olajide                 0
# 13  p4jkbz6wkiokx                              Big Kwame                 0
# 14  p4jkbz6wkio3v                         Ussain Thunder                 0
# 15  okdk9z8265eb4                                   FEND               588
# 16  ozak9my2e0ydc                       Telegraph Hamani              3220
# 17  okdk9z8mbqvk1                           Ralph lfegwu              8122
# 18  ozak9my5nj6av                           Ikemba Alani                56
# 19  okdk9mw8wh06e                             Laika News              8765
#
#     twitter followers  twitter_following                            email  \
# 0             9725827                917               editor@guardian.ha
# 1                1263                541            dollydkwueme@yahoo.ha
# 2                   0                  0          write.tom812@mod.gov.uk
# 3               19348                625          chinwe.jelanee@yahoo.ha
# 4                   0                  0              blue1@conducttr.com
# 5               12433              11233
# 6                 739                145  benjaminpepple@abiastate.gov.ha
# 7                 266                105             adaego.eze@unhcr.org
# 8               23444                345                      info@pdp.ha
# 9              700000                818                gossip@heatmag.ha
# 10             296900                876
# 11                  0                  0              blue3@conducttr.com
# 12                  0                  0              blue4@conducttr.com
# 13                  0                  0              blue2@conducttr.com
# 14                  0                  0              blue5@conducttr.com
# 15               3421              34551
# 16             827384                917              editor@telegraph.ha
# 17              23099                543            ralph.ifegwu@yahoo.ha
# 18               1235               3212             ikemba@police.gov.ha
# 19            3000000                567
#
#       goSocial name  goSocial messages  goSocial Followers
# 0       GuardianHam                  0              797533
# 1                                    0                1874
# 2              None                  0                   0
# 3    ChinweCongress                  0               15927
# 4              None                  0                   0
# 5    Stanley Ojukwu                  2                  25
# 6   Benjamin Pepple                  0                 654
# 7        Adaego Eze                235                3235
# 8              None                  0                   0
# 9        hamaniHeat               2321              910000
# 10             None                  0                   0
# 11             None                  0                   0
# 12             None                  0                   0
# 13             None                  0                   0
# 14             None                  0                   0
# 15             None                  0                   0
# 16     TelegraphHam               9328               82493
# 17             None                  0                   0
# 18             None                  0                   0
# 19             None                  0                   0

# %%
channel2_df=pd.DataFrame({"To":unique_ids, "From":unique_ids, "twitter name":twitter, "twitter messages":twitter_number,
             "twitter followers":twitter_followers, "twitter_following":twitter_following,
             "email":email, "goSocial name": gosocial_name, "goSocial messages": gosocial_number, "goSocial Followers":gosocial_followers
    
})

channel2_df['twitter name'] = channel2_df['twitter name'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)

# %%
from_merged=channel2_df[["From", "twitter name", "email", "goSocial name"]]
from_merged.head(20)
#string replacements in the from dataset
# Out:
#              From                         twitter name  \
# 0   ozak9mvjiecmn                      Guardian Hamani
# 1   kwskaxz7hpack                        Dolly Dkwueme
# 2   p4jkb0gax73nd  Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1
# 3   p7vkaz5il80cd                       Chinwe Jelanee
# 4   p4jkbz6kkxype                             Blue One
# 5   p4jkb2nkm9f91                       Stanley Ojukwu
# 6   kwskazf32n63z                      Benjamin Pepple
# 7   kwskaxux9vx1e                           Adaego Eze
# 8   kwskazfmgo8ax                                  PDP
# 9   p7vkaz52tvvfb                          Hamani Heat
# 10  ozak9wrvu3bdm                         British Army
# 11  p4jkbz6wkiom8                     Police Reform HA
# 12  p4jkbz6wkio1c                              Olajide
# 13  p4jkbz6wkiokx                            Big Kwame
# 14  p4jkbz6wkio3v                       Ussain Thunder
# 15  okdk9z8265eb4                                 FEND
# 16  ozak9my2e0ydc                     Telegraph Hamani
# 17  okdk9z8mbqvk1                         Ralph lfegwu
# 18  ozak9my5nj6av                         Ikemba Alani
# 19  okdk9mw8wh06e                           Laika News
#
#                               email    goSocial name
# 0                editor@guardian.ha      GuardianHam
# 1             dollydkwueme@yahoo.ha
# 2           write.tom812@mod.gov.uk             None
# 3           chinwe.jelanee@yahoo.ha   ChinweCongress
# 4               blue1@conducttr.com             None
# 5                                     Stanley Ojukwu
# 6   benjaminpepple@abiastate.gov.ha  Benjamin Pepple
# 7              adaego.eze@unhcr.org       Adaego Eze
# 8                       info@pdp.ha             None
# 9                 gossip@heatmag.ha       hamaniHeat
# 10                                              None
# 11              blue3@conducttr.com             None
# 12              blue4@conducttr.com             None
# 13              blue2@conducttr.com             None
# 14              blue5@conducttr.com             None
# 15                                              None
# 16              editor@telegraph.ha     TelegraphHam
# 17            ralph.ifegwu@yahoo.ha             None
# 18             ikemba@police.gov.ha             None
# 19                                              None

# %%
to_merged=channel2_df[["To", "twitter name"]]
All=["All"]
All=pd.DataFrame({"To":All, "twitter name":All})
to_merged=to_merged.append(All)

# %%
to_merged.head(50)
#remove emojis from the dataframe
# Out:
#                To                         twitter name
# 0   ozak9mvjiecmn                      Guardian Hamani
# 1   kwskaxz7hpack                        Dolly Dkwueme
# 2   p4jkb0gax73nd  Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1
# 3   p7vkaz5il80cd                       Chinwe Jelanee
# 4   p4jkbz6kkxype                             Blue One
# 5   p4jkb2nkm9f91                       Stanley Ojukwu
# 6   kwskazf32n63z                      Benjamin Pepple
# 7   kwskaxux9vx1e                           Adaego Eze
# 8   kwskazfmgo8ax                                  PDP
# 9   p7vkaz52tvvfb                          Hamani Heat
# 10  ozak9wrvu3bdm                         British Army
# 11  p4jkbz6wkiom8                     Police Reform HA
# 12  p4jkbz6wkio1c                              Olajide
# 13  p4jkbz6wkiokx                            Big Kwame
# 14  p4jkbz6wkio3v                       Ussain Thunder
# 15  okdk9z8265eb4                                 FEND
# 16  ozak9my2e0ydc                     Telegraph Hamani
# 17  okdk9z8mbqvk1                         Ralph lfegwu
# 18  ozak9my5nj6av                         Ikemba Alani
# 19  okdk9mw8wh06e                           Laika News
# 20  kwskay3lhjh5i                         Paul Atuegbu
# 21  p7vkb26y081r1                          Dayo Isreal
# 22  ozak9mxxbpofl                           Debare Oni
# 23  ozak9mywukuoz                             BBC News
# 24  p4jkbz6wkio6a                             PoliceHA
# 25  p7vkb0hvklj6h                           Isioma Agu
# 26  p4jkbhu9ulcb4                             Checkawa
# 27  kwskazfp12mqb                                 APGA
# 28  ozak9wtk2p49b                           Aretta Obi
# 29  kwskazeey2w8m                            Alika Oni
# 30  gvgkbj2vji6l6   Wendy  ABOLISH POLICE, ICE,  DHS B
# 31  p4jkats3l3257                            Joy Okoye
# 32  p7vkb26yz7j33                         Yewande Ogun
# 33  p7vkazij4vimn                        Ogechi Obasea
# 34  p7vkazihxagc3                      Onyeka Chononso
# 35  p4jkb2n1tz11d              St. John Baptist Church
# 36  p7vkb0jrqsr7k                          Orisa Kazah
# 37  ozak9wtkjo7al                        Adaeze Chioma
# 38  p7vkbakejnydw                            Dara Umar
# 39  p4jkbj1bmky37                        Eshe Uchechey
# 40  p7vkazijiyyqb                        Koofrey Uchea
# 41  okdkb5g65t53k                       Ultrascan MENA
# 42  p4jkbj1bmhh9o                         Chidi Jelany
# 43  gvgkbg8t4n14u                        Olisa Okparro
# 44  p4jkbj1bmqpmc                             Udo Mazi
# 45  p7vkazijbz95a                        Amara Chibuzo
# 46  gvgkbj5pu3jew                                   4
# 47  okdkb5f1cngbs                          malia obama
# 48  p1gkbkfrwyh5s                          Iamgarfield
# 49  gvgkbj4uw00ee                    Angel Nduka-Nwosu

# %%
#explode the id2 dataframe count:
to_merged["twitter name"].unique()
# Out:
# array(['Guardian Hamani', 'Dolly Dkwueme',
#        'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1', 'Chinwe Jelanee',
#        'Blue One', 'Stanley Ojukwu', 'Benjamin Pepple', 'Adaego Eze',
#        'PDP', 'Hamani Heat', 'British Army', 'Police Reform HA',
#        'Olajide', 'Big Kwame', 'Ussain Thunder', 'FEND',
#        'Telegraph Hamani', 'Ralph lfegwu', 'Ikemba Alani', 'Laika News',
#        'Paul Atuegbu', 'Dayo Isreal', 'Debare Oni', 'BBC News',
#        'PoliceHA', 'Isioma Agu', 'Checkawa', 'APGA', 'Aretta Obi',
#        'Alika Oni', 'Wendy  ABOLISH POLICE, ICE,  DHS B', 'Joy Okoye',
#        'Yewande Ogun', 'Ogechi Obasea', 'Onyeka Chononso',
#        'St. John Baptist Church', 'Orisa Kazah', 'Adaeze Chioma',
#        'Dara Umar', 'Eshe Uchechey', 'Koofrey Uchea', 'Ultrascan MENA',
#        'Chidi Jelany', 'Olisa Okparro', 'Udo Mazi', 'Amara Chibuzo', '4 ',
#        'malia obama', 'Iamgarfield', 'Angel Nduka-Nwosu', 'Neo Pitso',
#        'Daily Times Hamani', 'Ambi', 'Chancellor Exchequer',
#        'CrimeFighters', 'RAT BLOOD RIZZY', 'Tamara', 'Lorietha Causey',
#        'Gary', 'UPTown Hamani', 'Uturu Today', 'The Wanted Emcees',
#        'Shake and Bake', 'Diane Post-Lester', 'HumAngle_', 'TheNewsGuru',
#        'ThisNews', 'Dotun Oladipo', 'Independent Hamani', 'Santech Ha',
#        'OrderPaper', 'The White Helmets', 'Musbau rasak', 'Madu Onuorah',
#        'HamaniInfoAbuja', 'The Eagle Online', 'Ifama Chyke', 'All'],
#       dtype=object)

# %%
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# calculate lengths of splits
lens = df['To'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
df2 = pd.DataFrame({'date': np.repeat(df['date'], lens),
                    'persona_id': np.repeat(df['persona_id'], lens),
                    'channel': np.repeat(df['channel'], lens),
                    'interaction': np.repeat(df['interaction'], lens),
                    'Text': np.repeat(df['Text'], lens),
                    'From': np.repeat(df['From'], lens),
                    'To': chainer(df['To'])})

# %%
#data - getting across it and unferstanding it
df2["Frequency"]=1

# %%
df2.head(15)
# Out:
#                    date persona_id    channel interaction  \
# 0   2020-07-13 08:45:36      wKoOd  microblog      repost
# 1   2020-07-13 09:00:51      wKoOd  microblog       reply
# 2   2020-07-13 09:04:40      XAOv7  microblog         new
# 3   2020-07-13 09:10:53      XAOv7  microblog         new
# 4   2020-07-13 09:10:56      PBOK7       mail         new
# 4   2020-07-13 09:10:56      PBOK7       mail         new
# 4   2020-07-13 09:10:56      PBOK7       mail         new
# 4   2020-07-13 09:10:56      PBOK7       mail         new
# 4   2020-07-13 09:10:56      PBOK7       mail         new
# 5   2020-07-13 09:11:55      XAOv7  microblog         new
# 6   2020-07-13 09:14:24      wKoOd  microblog       reply
# 7   2020-07-13 09:19:43      XAOv7  microblog         new
# 8   2020-07-13 09:27:34      XAOv7  microblog       reply
# 9   2020-07-13 09:30:25      jGgXp  microblog         new
# 10  2020-07-13 09:31:15      JB7DW       mail       reply
#
#                                                  Text           From  \
# 0                                                      ozak9mvjiecmn
# 1   The Government is in bed with the oil companie...  ozak9mvjiecmn
# 2   Good morning my lovely people! Let's hope toda...  kwskaxz7hpack
# 3   The Bonni people are proud people, don't forge...  kwskaxz7hpack
# 4              Chaps,    To follow my original email.  p4jkb0gax73nd
# 4              Chaps,    To follow my original email.  p4jkb0gax73nd
# 4              Chaps,    To follow my original email.  p4jkb0gax73nd
# 4              Chaps,    To follow my original email.  p4jkb0gax73nd
# 4              Chaps,    To follow my original email.  p4jkb0gax73nd
# 5   Remember to hit like, and subscribe my stuff, ...  kwskaxz7hpack
# 6   The camp is the safest place for your family w...  p7vkaz5il80cd
# 7   British Colonialists back in the country again...  kwskaxz7hpack
# 8   Are these the people that are coming to kill m...  kwskaxz7hpack
# 9   British imperialism regimes have no pace here!...  kwskaxz7hpack
# 10             Good Morning Benjamin    With regards   p4jkbz6kkxype
#
#                To  Frequency
# 0   ozak9wtk2p49b          1
# 1   ozak9wtk2p49b          1
# 2                          1
# 3                          1
# 4   p4jkbz6kkxype          1
# 4   p4jkbz6wkiokx          1
# 4   p4jkbz6wkiom8          1
# 4   p4jkbz6wkio1c          1
# 4   p4jkbz6wkio3v          1
# 5                          1
# 6   kwskazeey2w8m          1
# 7                          1
# 8   ozak9wrvu3bdm          1
# 9                          1
# 10  kwskazf32n63z          1

# %%
merged=pd.merge(df2, from_merged, on='From')
merged.head(10)
# Out:
#                   date persona_id    channel interaction  \
# 0  2020-07-13 08:45:36      wKoOd  microblog      repost
# 1  2020-07-13 09:00:51      wKoOd  microblog       reply
# 2  2020-07-13 09:34:47      wKoOd  microblog        like
# 3  2020-07-13 09:59:41      p0oOg  microblog         new
# 4  2020-07-13 10:01:09      p0oOg  microblog         new
# 5  2020-07-13 10:18:06      wKoOd  microblog       reply
# 6  2020-07-13 10:40:03      wKoOd  microblog       reply
# 7  2020-07-13 10:41:54      wKoOd  microblog       reply
# 8  2020-07-13 10:45:45      wKoOd  microblog       reply
# 9  2020-07-13 10:51:33      wKoOd  microblog       reply
#
#                                                 Text           From  \
# 0                                                     ozak9mvjiecmn
# 1  The Government is in bed with the oil companie...  ozak9mvjiecmn
# 2                                                     ozak9mvjiecmn
# 3  This is what the Failing Government has brough...  ozak9mvjiecmn
# 4  This is what the Failing Government has brough...  ozak9mvjiecmn
# 5  Voting is crucial for change, please help our ...  ozak9mvjiecmn
# 6  The British army recruits anyone that is willi...  ozak9mvjiecmn
# 7  Just grab a rifle and uniform and demonstrate ...  ozak9mvjiecmn
# 8  We thank you for your aid and support in these...  ozak9mvjiecmn
# 9  IDP camps are vital to protect our families an...  ozak9mvjiecmn
#
#               To  Frequency     twitter name               email goSocial name
# 0  ozak9wtk2p49b          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 1  ozak9wtk2p49b          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 2  p7vkb26y081r1          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 3                         1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 4                         1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 5  kwskazfp12mqb          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 6  ozak9wrvu3bdm          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 7  p4jkbz6wkiokx          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 8  kwskazfp12mqb          1  Guardian Hamani  editor@guardian.ha   GuardianHam
# 9  kwskazfp12mqb          1  Guardian Hamani  editor@guardian.ha   GuardianHam

# %%
merged=merged.rename(columns={"twitter name":"from"})
merged=merged.drop(columns={"From"})

# %%
#fill null values in NA
merged['To'].replace('','Everyone', inplace=True)
merged['email'].replace('','None', inplace=True)
merged['goSocial name'].replace('','None', inplace=True)

# %%
merged_2=pd.merge(merged,to_merged, on='To')

# %%
merged_2.head(5)
# Out:
#                   date persona_id    channel interaction  \
# 0  2020-07-13 08:45:36      wKoOd  microblog      repost
# 1  2020-07-13 09:00:51      wKoOd  microblog       reply
# 2  2020-07-13 09:34:47      wKoOd  microblog        like
# 3  2020-07-13 11:14:42      wKoOd  microblog       reply
# 4  2020-07-13 14:31:14      p0oOg  microblog      repost
#
#                                                 Text             To  \
# 0                                                     ozak9wtk2p49b
# 1  The Government is in bed with the oil companie...  ozak9wtk2p49b
# 2                                                     p7vkb26y081r1
# 3  The Government is corrupt and will never admit...  p7vkb26y081r1
# 4                                                     p7vkb26y081r1
#
#    Frequency             from                    email   goSocial name  \
# 0          1  Guardian Hamani       editor@guardian.ha     GuardianHam
# 1          1  Guardian Hamani       editor@guardian.ha     GuardianHam
# 2          1  Guardian Hamani       editor@guardian.ha     GuardianHam
# 3          1   Chinwe Jelanee  chinwe.jelanee@yahoo.ha  ChinweCongress
# 4          1             FEND                     None            None
#
#   twitter name
# 0   Aretta Obi
# 1   Aretta Obi
# 2  Dayo Isreal
# 3  Dayo Isreal
# 4  Dayo Isreal

# %%
merged_2=merged_2.rename(columns={"twitter name":"to"})

# %%
#merge persona id: 

#merging people
merged_final=pd.merge(merged_2,persona_df, on='persona_id')

# %%
merged_final
# Out:
#                     date persona_id    channel interaction  \
# 0    2020-07-13 08:45:36      wKoOd  microblog      repost
# 1    2020-07-13 09:00:51      wKoOd  microblog       reply
# 2    2020-07-13 09:34:47      wKoOd  microblog        like
# 3    2020-07-13 11:14:42      wKoOd  microblog       reply
# 4    2020-07-13 10:18:06      wKoOd  microblog       reply
# ..                   ...        ...        ...         ...
# 311  2020-07-13 10:02:10      7y7OM       mail         new
# 312  2020-07-13 13:07:18      7y7OM       mail         new
# 313  2020-07-13 09:41:17      7y7OM       mail     forward
# 314  2020-07-13 09:53:18      1jr5l       mail         new
# 315  2020-07-13 09:41:24      1jr5l       mail     forward
#
#                                                   Text             To  \
# 0                                                       ozak9wtk2p49b
# 1    The Government is in bed with the oil companie...  ozak9wtk2p49b
# 2                                                       p7vkb26y081r1
# 3    The Government is corrupt and will never admit...  p7vkb26y081r1
# 4    Voting is crucial for change, please help our ...  kwskazfp12mqb
# ..                                                 ...            ...
# 311             Good morning,    Please find the reply  p4jkbz6kkxype
# 312             Afternoon,    Please find attached the  p4jkbz6kkxype
# 313                                                     p4jkats3l3257
# 314             Good morning,    Thank you for your qu  p4jkbz6kkxype
# 315                                                     p4jkats3l3257
#
#      Frequency             from                            email  \
# 0            1  Guardian Hamani               editor@guardian.ha
# 1            1  Guardian Hamani               editor@guardian.ha
# 2            1  Guardian Hamani               editor@guardian.ha
# 3            1   Chinwe Jelanee          chinwe.jelanee@yahoo.ha
# 4            1  Guardian Hamani               editor@guardian.ha
# ..         ...              ...                              ...
# 311          1  Benjamin Pepple  benjaminpepple@abiastate.gov.ha
# 312          1  Benjamin Pepple  benjaminpepple@abiastate.gov.ha
# 313          1  Benjamin Pepple  benjaminpepple@abiastate.gov.ha
# 314          1       Adaego Eze             adaego.eze@unhcr.org
# 315          1       Adaego Eze             adaego.eze@unhcr.org
#
#        goSocial name           to             name  \
# 0        GuardianHam   Aretta Obi  Guardian Hamani
# 1        GuardianHam   Aretta Obi  Guardian Hamani
# 2        GuardianHam  Dayo Isreal  Guardian Hamani
# 3     ChinweCongress  Dayo Isreal  Guardian Hamani
# 4        GuardianHam         APGA  Guardian Hamani
# ..               ...          ...              ...
# 311  Benjamin Pepple     Blue One  Benjamin Pepple
# 312  Benjamin Pepple     Blue One  Benjamin Pepple
# 313  Benjamin Pepple    Joy Okoye  Benjamin Pepple
# 314       Adaego Eze     Blue One       Adaego Eze
# 315       Adaego Eze    Joy Okoye       Adaego Eze
#
#                                  image_url        type
# 0    /assets/styles/32563/profiles/you.png  rolePlayer
# 1    /assets/styles/32563/profiles/you.png  rolePlayer
# 2    /assets/styles/32563/profiles/you.png  rolePlayer
# 3    /assets/styles/32563/profiles/you.png  rolePlayer
# 4    /assets/styles/32563/profiles/you.png  rolePlayer
# ..                                     ...         ...
# 311  /assets/styles/32563/profiles/you.png  rolePlayer
# 312  /assets/styles/32563/profiles/you.png  rolePlayer
# 313  /assets/styles/32563/profiles/you.png  rolePlayer
# 314  /assets/styles/32563/profiles/you.png  rolePlayer
# 315  /assets/styles/32563/profiles/you.png  rolePlayer
#
# [316 rows x 14 columns]

# %%
merged_final=merged_final[["date","name","channel", "interaction", "Text", "from", "to", "image_url", "type", "Frequency","email"]]

# %%
merged_final
# Out:
#                     date             name    channel interaction  \
# 0    2020-07-13 08:45:36  Guardian Hamani  microblog      repost
# 1    2020-07-13 09:00:51  Guardian Hamani  microblog       reply
# 2    2020-07-13 09:34:47  Guardian Hamani  microblog        like
# 3    2020-07-13 11:14:42  Guardian Hamani  microblog       reply
# 4    2020-07-13 10:18:06  Guardian Hamani  microblog       reply
# ..                   ...              ...        ...         ...
# 311  2020-07-13 10:02:10  Benjamin Pepple       mail         new
# 312  2020-07-13 13:07:18  Benjamin Pepple       mail         new
# 313  2020-07-13 09:41:17  Benjamin Pepple       mail     forward
# 314  2020-07-13 09:53:18       Adaego Eze       mail         new
# 315  2020-07-13 09:41:24       Adaego Eze       mail     forward
#
#                                                   Text             from  \
# 0                                                       Guardian Hamani
# 1    The Government is in bed with the oil companie...  Guardian Hamani
# 2                                                       Guardian Hamani
# 3    The Government is corrupt and will never admit...   Chinwe Jelanee
# 4    Voting is crucial for change, please help our ...  Guardian Hamani
# ..                                                 ...              ...
# 311             Good morning,    Please find the reply  Benjamin Pepple
# 312             Afternoon,    Please find attached the  Benjamin Pepple
# 313                                                     Benjamin Pepple
# 314             Good morning,    Thank you for your qu       Adaego Eze
# 315                                                          Adaego Eze
#
#               to                              image_url        type  \
# 0     Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer
# 1     Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer
# 2    Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer
# 3    Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer
# 4           APGA  /assets/styles/32563/profiles/you.png  rolePlayer
# ..           ...                                    ...         ...
# 311     Blue One  /assets/styles/32563/profiles/you.png  rolePlayer
# 312     Blue One  /assets/styles/32563/profiles/you.png  rolePlayer
# 313    Joy Okoye  /assets/styles/32563/profiles/you.png  rolePlayer
# 314     Blue One  /assets/styles/32563/profiles/you.png  rolePlayer
# 315    Joy Okoye  /assets/styles/32563/profiles/you.png  rolePlayer
#
#      Frequency                            email
# 0            1               editor@guardian.ha
# 1            1               editor@guardian.ha
# 2            1               editor@guardian.ha
# 3            1          chinwe.jelanee@yahoo.ha
# 4            1               editor@guardian.ha
# ..         ...                              ...
# 311          1  benjaminpepple@abiastate.gov.ha
# 312          1  benjaminpepple@abiastate.gov.ha
# 313          1  benjaminpepple@abiastate.gov.ha
# 314          1             adaego.eze@unhcr.org
# 315          1             adaego.eze@unhcr.org
#
# [316 rows x 11 columns]

# %%
#total interactions of each (name) and channel 
total_interactions = merged_final.groupby(['name','channel','interaction'])
total_interactions_final=pd.DataFrame(total_interactions["Frequency"].count())
total_interactions_final
# Out:
#                                                             Frequency
# name                                 channel   interaction
# Adaego Eze                           mail      forward              1
#                                                new                  1
# Benjamin Pepple                      mail      forward              1
#                                                new                  2
# Blue Five                            microblog like                27
#                                                reply               11
#                                                repost              25
# Blue Four                            microblog like                27
#                                                reply                3
#                                                repost              11
# Blue One                             mail      new                  3
#                                                reply                8
#                                      microblog like                 1
# Blue Six                             microblog reply                3
# Blue Three                           microblog like                16
#                                                reply               12
#                                                repost              12
# Blue Two                             microblog like                 2
#                                                reply                1
#                                                repost               3
# Chinwe Jelanee                       microblog like                 3
#                                                reply                2
#                                                repost               4
# Debare Oni                           microblog like                 1
#                                                reply                1
#                                                repost               1
# Dolly Dkwueme                        microblog like                20
#                                                reply                5
#                                                repost              12
#                                      websites  reply                2
# Guardian Hamani                      microblog like                 2
#                                                reply               26
#                                                repost               2
# Hamani Heat                          gosocial  reply                1
#                                      microblog like                 3
#                                                repost               2
# Joy Okoye                            microblog repost               1
# Telegraph Hamani                     microblog like                 1
#                                                reply                8
#                                                repost              32
# Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1) mail      forward              5
#                                                new                 10
#                                                reply                2

# %%
#personas each person had as each person (from interactions) 
total_to = merged_final.groupby(['name','to'])
total_to=pd.DataFrame(total_to["Frequency"].count())
total_to.head(50)
# Out:
#                                                      Frequency
# name            to
# Adaego Eze      Blue One                                     1
#                 Joy Okoye                                    1
# Benjamin Pepple Blue One                                     2
#                 Joy Okoye                                    1
# Blue Five       British Army                                 7
#                 Checkawa                                     6
#                 Gary                                         1
#                 HamaniInfoAbuja                              1
#                 HumAngle_                                    1
#                 Ifama Chyke                                  1
#                 Independent Hamani                           1
#                 Laika News                                   1
#                 Olajide                                      4
#                 OrderPaper                                   2
#                 Police Reform HA                            32
#                 The Eagle Online                             1
#                 The Wanted Emcees                            1
#                 ThisNews                                     2
#                 Ussain Thunder                               2
# Blue Four       Adaeze Chioma                                2
#                 Ambi                                         1
#                 BBC News                                     1
#                 British Army                                 6
#                 Checkawa                                     5
#                 Chinwe Jelanee                               2
#                 CrimeFighters                                1
#                 Dolly Dkwueme                                1
#                 Hamani Heat                                  1
#                 Laika News                                   1
#                 Olajide                                      1
#                 Orisa Kazah                                  2
#                 Police Reform HA                            12
#                 The Wanted Emcees                            1
#                 Ussain Thunder                               2
#                 malia obama                                  2
# Blue One        Adaego Eze                                   2
#                 Amara Chibuzo                                1
#                 Benjamin Pepple                              3
#                 Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1          6
# Blue Six        Chidi Jelany                                 1
#                 Udo Mazi                                     1
#                 malia obama                                  1
# Blue Three      Ambi                                         3
#                 BBC News                                     2
#                 Big Kwame                                    1
#                 British Army                                 7
#                 Chancellor Exchequer                         1
#                 Checkawa                                     4
#                 Chidi Jelany                                 1
#                 Dolly Dkwueme                                3

# %%
total_from = merged_final.groupby(['name','from'])
total_from=pd.DataFrame(total_from["Frequency"].count())
total_from.head(50)
# Out:
#                                                                           Frequency
# name                                 from
# Adaego Eze                           Adaego Eze                                   2
# Benjamin Pepple                      Benjamin Pepple                              3
# Blue Five                            Ussain Thunder                              63
# Blue Four                            Checkawa                                     1
#                                      Olajide                                     40
# Blue One                             Blue One                                    12
# Blue Six                             PoliceHA                                     3
# Blue Three                           Police Reform HA                            40
# Blue Two                             Big Kwame                                    3
#                                      British Army                                 3
# Chinwe Jelanee                       Chinwe Jelanee                               6
#                                      Dolly Dkwueme                                3
# Debare Oni                           Debare Oni                                   3
# Dolly Dkwueme                        Dolly Dkwueme                               39
# Guardian Hamani                      Chinwe Jelanee                               2
#                                      Guardian Hamani                             21
#                                      Ikemba Alani                                 1
#                                      PDP                                          1
#                                      Paul Atuegbu                                 1
#                                      Ralph lfegwu                                 2
#                                      Stanley Ojukwu                               2
# Hamani Heat                          Hamani Heat                                  6
# Joy Okoye                            BBC News                                     1
# Telegraph Hamani                     APGA                                         1
#                                      Chinwe Jelanee                               4
#                                      Dayo Isreal                                  4
#                                      Dolly Dkwueme                                5
#                                      FEND                                         3
#                                      Hamani Heat                                  2
#                                      Laika News                                   6
#                                      PDP                                         10
#                                      Telegraph Hamani                             6
# Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1) Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1         17

# %%
total_from_channel= merged_final.groupby(['name','from','channel'])
total_from_channel=pd.DataFrame(total_from_channel["Frequency"].count())
total_from_channel.head(50)
# Out:
#                                                                                     Frequency
# name                                 from                                channel
# Adaego Eze                           Adaego Eze                          mail               2
# Benjamin Pepple                      Benjamin Pepple                     mail               3
# Blue Five                            Ussain Thunder                      microblog         63
# Blue Four                            Checkawa                            microblog          1
#                                      Olajide                             microblog         40
# Blue One                             Blue One                            mail              11
#                                                                          microblog          1
# Blue Six                             PoliceHA                            microblog          3
# Blue Three                           Police Reform HA                    microblog         40
# Blue Two                             Big Kwame                           microblog          3
#                                      British Army                        microblog          3
# Chinwe Jelanee                       Chinwe Jelanee                      microblog          6
#                                      Dolly Dkwueme                       microblog          3
# Debare Oni                           Debare Oni                          microblog          3
# Dolly Dkwueme                        Dolly Dkwueme                       microblog         37
#                                                                          websites           2
# Guardian Hamani                      Chinwe Jelanee                      microblog          2
#                                      Guardian Hamani                     microblog         21
#                                      Ikemba Alani                        microblog          1
#                                      PDP                                 microblog          1
#                                      Paul Atuegbu                        microblog          1
#                                      Ralph lfegwu                        microblog          2
#                                      Stanley Ojukwu                      microblog          2
# Hamani Heat                          Hamani Heat                         gosocial           1
#                                                                          microblog          5
# Joy Okoye                            BBC News                            microblog          1
# Telegraph Hamani                     APGA                                microblog          1
#                                      Chinwe Jelanee                      microblog          4
#                                      Dayo Isreal                         microblog          4
#                                      Dolly Dkwueme                       microblog          5
#                                      FEND                                microblog          3
#                                      Hamani Heat                         microblog          2
#                                      Laika News                          microblog          6
#                                      PDP                                 microblog         10
#                                      Telegraph Hamani                    microblog          6
# Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1) Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1 mail              17

# %%
#personas most communications- channel and person 
total_group = merged_final.groupby(['name','to', "channel"])
total_to=pd.DataFrame(total_group["Frequency"].count())
total_to.head(50)

merged_final_df=merged_final

# %%
#personas by the different day, interaction (to whom- as tooltip) maybe

#received communication
#receiving time and trying to get those filters to work

# %%
#write out to a json file
results = defaultdict(lambda: defaultdict(dict))

for index, value in total_from.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
json_list=[]
newlist = list()
for i in results.keys():
    newlist.append(i)

# %%
impersonations2={}
for item in newlist:
        impersonations=results[item].keys()
        values=[]
        for i in impersonations:    
            values.append(i)
            impersonations2.update({f'{item}':values})

# %%
impersonations3={"impersonations": impersonations2}

# %%
json_list.append(impersonations3)

# %%
merged_final2=merged_final.copy()

# %%
merged_final2["channel"]="All"

# %%
frames=(merged_final, merged_final2)
merged3=pd.concat(frames)
merged3.head(5)
# Out:
#                   date             name    channel interaction  \
# 0  2020-07-13 08:45:36  Guardian Hamani  microblog      repost
# 1  2020-07-13 09:00:51  Guardian Hamani  microblog       reply
# 2  2020-07-13 09:34:47  Guardian Hamani  microblog        like
# 3  2020-07-13 11:14:42  Guardian Hamani  microblog       reply
# 4  2020-07-13 10:18:06  Guardian Hamani  microblog       reply
#
#                                                 Text             from  \
# 0                                                     Guardian Hamani
# 1  The Government is in bed with the oil companie...  Guardian Hamani
# 2                                                     Guardian Hamani
# 3  The Government is corrupt and will never admit...   Chinwe Jelanee
# 4  Voting is crucial for change, please help our ...  Guardian Hamani
#
#             to                              image_url        type  Frequency  \
# 0   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 1   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 2  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 3  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 4         APGA  /assets/styles/32563/profiles/you.png  rolePlayer          1
#
#                      email
# 0       editor@guardian.ha
# 1       editor@guardian.ha
# 2       editor@guardian.ha
# 3  chinwe.jelanee@yahoo.ha
# 4       editor@guardian.ha

# %%
total_from_channel= merged3.groupby(['name','from','channel'])
total_from_channel=pd.DataFrame(total_from_channel["Frequency"].count())
total_from_channel.head(50)
# Out:
#                                              Frequency
# name             from             channel
# Adaego Eze       Adaego Eze       All                2
#                                   mail               2
# Benjamin Pepple  Benjamin Pepple  All                3
#                                   mail               3
# Blue Five        Ussain Thunder   All               63
#                                   microblog         63
# Blue Four        Checkawa         All                1
#                                   microblog          1
#                  Olajide          All               40
#                                   microblog         40
# Blue One         Blue One         All               12
#                                   mail              11
#                                   microblog          1
# Blue Six         PoliceHA         All                3
#                                   microblog          3
# Blue Three       Police Reform HA All               40
#                                   microblog         40
# Blue Two         Big Kwame        All                3
#                                   microblog          3
#                  British Army     All                3
#                                   microblog          3
# Chinwe Jelanee   Chinwe Jelanee   All                6
#                                   microblog          6
#                  Dolly Dkwueme    All                3
#                                   microblog          3
# Debare Oni       Debare Oni       All                3
#                                   microblog          3
# Dolly Dkwueme    Dolly Dkwueme    All               39
#                                   microblog         37
#                                   websites           2
# Guardian Hamani  Chinwe Jelanee   All                2
#                                   microblog          2
#                  Guardian Hamani  All               21
#                                   microblog         21
#                  Ikemba Alani     All                1
#                                   microblog          1
#                  PDP              All                1
#                                   microblog          1
#                  Paul Atuegbu     All                1
#                                   microblog          1
#                  Ralph lfegwu     All                2
#                                   microblog          2
#                  Stanley Ojukwu   All                2
#                                   microblog          2
# Hamani Heat      Hamani Heat      All                6
#                                   gosocial           1
#                                   microblog          5
# Joy Okoye        BBC News         All                1
#                                   microblog          1
# Telegraph Hamani APGA             All                1

# %%
results3 = defaultdict(lambda: defaultdict(dict))

for index, value in total_from_channel.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results3[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
results4={"from":results3}
json_list.append(results4)

# %%
results4
# Out:
# {'from': defaultdict(<function __main__.<lambda>()>,
#              {'Adaego Eze': defaultdict(dict,
#                           {'Adaego Eze': {'All': 2, 'mail': 2}}),
#               'Benjamin Pepple': defaultdict(dict,
#                           {'Benjamin Pepple': {'All': 3, 'mail': 3}}),
#               'Blue Five': defaultdict(dict,
#                           {'Ussain Thunder': {'All': 63, 'microblog': 63}}),
#               'Blue Four': defaultdict(dict,
#                           {'Checkawa': {'All': 1, 'microblog': 1},
#                            'Olajide': {'All': 40, 'microblog': 40}}),
#               'Blue One': defaultdict(dict,
#                           {'Blue One': {'All': 12,
#                             'mail': 11,
#                             'microblog': 1}}),
#               'Blue Six': defaultdict(dict,
#                           {'PoliceHA': {'All': 3, 'microblog': 3}}),
#               'Blue Three': defaultdict(dict,
#                           {'Police Reform HA': {'All': 40, 'microblog': 40}}),
#               'Blue Two': defaultdict(dict,
#                           {'Big Kwame': {'All': 3, 'microblog': 3},
#                            'British Army': {'All': 3, 'microblog': 3}}),
#               'Chinwe Jelanee': defaultdict(dict,
#                           {'Chinwe Jelanee': {'All': 6, 'microblog': 6},
#                            'Dolly Dkwueme': {'All': 3, 'microblog': 3}}),
#               'Debare Oni': defaultdict(dict,
#                           {'Debare Oni': {'All': 3, 'microblog': 3}}),
#               'Dolly Dkwueme': defaultdict(dict,
#                           {'Dolly Dkwueme': {'All': 39,
#                             'microblog': 37,
#                             'websites': 2}}),
#               'Guardian Hamani': defaultdict(dict,
#                           {'Chinwe Jelanee': {'All': 2, 'microblog': 2},
#                            'Guardian Hamani': {'All': 21, 'microblog': 21},
#                            'Ikemba Alani': {'All': 1, 'microblog': 1},
#                            'PDP': {'All': 1, 'microblog': 1},
#                            'Paul Atuegbu': {'All': 1, 'microblog': 1},
#                            'Ralph lfegwu': {'All': 2, 'microblog': 2},
#                            'Stanley Ojukwu': {'All': 2, 'microblog': 2}}),
#               'Hamani Heat': defaultdict(dict,
#                           {'Hamani Heat': {'All': 6,
#                             'gosocial': 1,
#                             'microblog': 5}}),
#               'Joy Okoye': defaultdict(dict,
#                           {'BBC News': {'All': 1, 'microblog': 1}}),
#               'Telegraph Hamani': defaultdict(dict,
#                           {'APGA': {'All': 1, 'microblog': 1},
#                            'Chinwe Jelanee': {'All': 4, 'microblog': 4},
#                            'Dayo Isreal': {'All': 4, 'microblog': 4},
#                            'Dolly Dkwueme': {'All': 5, 'microblog': 5},
#                            'FEND': {'All': 3, 'microblog': 3},
#                            'Hamani Heat': {'All': 2, 'microblog': 2},
#                            'Laika News': {'All': 6, 'microblog': 6},
#                            'PDP': {'All': 10, 'microblog': 10},
#                            'Telegraph Hamani': {'All': 6, 'microblog': 6}}),
#               'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(dict,
#                           {'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': {'All': 17,
#                             'mail': 17}})})}

# %%
#grouping the datetime 
merged3.head()
# Out:
#                   date             name    channel interaction  \
# 0  2020-07-13 08:45:36  Guardian Hamani  microblog      repost
# 1  2020-07-13 09:00:51  Guardian Hamani  microblog       reply
# 2  2020-07-13 09:34:47  Guardian Hamani  microblog        like
# 3  2020-07-13 11:14:42  Guardian Hamani  microblog       reply
# 4  2020-07-13 10:18:06  Guardian Hamani  microblog       reply
#
#                                                 Text             from  \
# 0                                                     Guardian Hamani
# 1  The Government is in bed with the oil companie...  Guardian Hamani
# 2                                                     Guardian Hamani
# 3  The Government is corrupt and will never admit...   Chinwe Jelanee
# 4  Voting is crucial for change, please help our ...  Guardian Hamani
#
#             to                              image_url        type  Frequency  \
# 0   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 1   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 2  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 3  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 4         APGA  /assets/styles/32563/profiles/you.png  rolePlayer          1
#
#                      email
# 0       editor@guardian.ha
# 1       editor@guardian.ha
# 2       editor@guardian.ha
# 3  chinwe.jelanee@yahoo.ha
# 4       editor@guardian.ha

# %%
merged3['date'] = pd.to_datetime(merged3['date'], infer_datetime_format=True)
merged3.head()
# Out:
#                  date             name    channel interaction  \
# 0 2020-07-13 08:45:36  Guardian Hamani  microblog      repost
# 1 2020-07-13 09:00:51  Guardian Hamani  microblog       reply
# 2 2020-07-13 09:34:47  Guardian Hamani  microblog        like
# 3 2020-07-13 11:14:42  Guardian Hamani  microblog       reply
# 4 2020-07-13 10:18:06  Guardian Hamani  microblog       reply
#
#                                                 Text             from  \
# 0                                                     Guardian Hamani
# 1  The Government is in bed with the oil companie...  Guardian Hamani
# 2                                                     Guardian Hamani
# 3  The Government is corrupt and will never admit...   Chinwe Jelanee
# 4  Voting is crucial for change, please help our ...  Guardian Hamani
#
#             to                              image_url        type  Frequency  \
# 0   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 1   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 2  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 3  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 4         APGA  /assets/styles/32563/profiles/you.png  rolePlayer          1
#
#                      email
# 0       editor@guardian.ha
# 1       editor@guardian.ha
# 2       editor@guardian.ha
# 3  chinwe.jelanee@yahoo.ha
# 4       editor@guardian.ha

# %%
#list of unique values and getting a JSON file for frequency of all the players 
person_list=merged3['name'].to_list()

person_list_unique=[]

for item in person_list:
    if item not in person_list_unique:
        person_list_unique.append(item)

# %%
channel_list=merged3["channel"].to_list()
channel_list_unique=[]
for item in channel_list:
    if item not in channel_list_unique:
        channel_list_unique.append(item)

# %%
channel_list_unique
dict2={}

# %%
channel_list_unique
# Out:
# ['microblog', 'websites', 'mail', 'gosocial', 'All']

# %%
#jsonifying the data 
for person in person_list_unique:
    frames=[]
    for channel in channel_list_unique:
        try:
            channel_1=merged3.loc[(merged3["name"]==f"{person}") &(merged3["channel"]==f'{channel}'), :]
            merged_time_all=channel_1.resample('0.3H', on='date').sum()
            merged_time_all["channel"]=f"{channel}"
            frames.append(merged_time_all)
        except:
            continue
   
    merged=pd.concat(frames)
    merged=merged.reset_index()
    merged['date']=merged['date'].astype(str)
    merged = merged.groupby(['channel', "date"])
    merged1=pd.DataFrame(merged["Frequency"].sum())
    
    results1 = defaultdict(lambda: defaultdict(dict))
    for index, value in merged1.itertuples():
        for i, key in enumerate(index):
            if i == 0:
                nested = results1[key]
            elif i == len(index) - 1:
                nested[key] = value
        else:
            nested = nested[key]
    
    
    dict2.update({f'{person}':results1})

# %%
time=merged3.resample('0.3H', on='date').sum()
time=time.reset_index()
time['date']=time['date'].astype(str)
time_list=time["date"].to_list()
time_list
# Out:
# ['2020-07-13 08:42:00',
#  '2020-07-13 09:00:00',
#  '2020-07-13 09:18:00',
#  '2020-07-13 09:36:00',
#  '2020-07-13 09:54:00',
#  '2020-07-13 10:12:00',
#  '2020-07-13 10:30:00',
#  '2020-07-13 10:48:00',
#  '2020-07-13 11:06:00',
#  '2020-07-13 11:24:00',
#  '2020-07-13 11:42:00',
#  '2020-07-13 12:00:00',
#  '2020-07-13 12:18:00',
#  '2020-07-13 12:36:00',
#  '2020-07-13 12:54:00',
#  '2020-07-13 13:12:00',
#  '2020-07-13 13:30:00',
#  '2020-07-13 13:48:00',
#  '2020-07-13 14:06:00',
#  '2020-07-13 14:24:00',
#  '2020-07-13 14:42:00']

# %%
dict2
# Out:
# {'Guardian Hamani': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 08:42:00': 1,
#                            '2020-07-13 09:00:00': 2,
#                            '2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 1,
#                            '2020-07-13 10:30:00': 3,
#                            '2020-07-13 10:48:00': 1,
#                            '2020-07-13 11:06:00': 4,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 1,
#                            '2020-07-13 13:12:00': 3,
#                            '2020-07-13 13:30:00': 1,
#                            '2020-07-13 13:48:00': 1,
#                            '2020-07-13 14:06:00': 7,
#                            '2020-07-13 14:24:00': 2,
#                            '2020-07-13 14:42:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 08:42:00': 1,
#                            '2020-07-13 09:00:00': 2,
#                            '2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 1,
#                            '2020-07-13 10:30:00': 3,
#                            '2020-07-13 10:48:00': 1,
#                            '2020-07-13 11:06:00': 4,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 1,
#                            '2020-07-13 13:12:00': 3,
#                            '2020-07-13 13:30:00': 1,
#                            '2020-07-13 13:48:00': 1,
#                            '2020-07-13 14:06:00': 7,
#                            '2020-07-13 14:24:00': 2,
#                            '2020-07-13 14:42:00': 1})}),
#  'Telegraph Hamani': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 2,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 1,
#                            '2020-07-13 11:24:00': 2,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 7,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 7,
#                            '2020-07-13 14:06:00': 8,
#                            '2020-07-13 14:24:00': 3,
#                            '2020-07-13 14:42:00': 6}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 2,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 1,
#                            '2020-07-13 11:24:00': 2,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 7,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 7,
#                            '2020-07-13 14:06:00': 8,
#                            '2020-07-13 14:24:00': 3,
#                            '2020-07-13 14:42:00': 6})}),
#  'Dolly Dkwueme': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 3,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 2,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 2,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 10,
#                            '2020-07-13 14:06:00': 5,
#                            '2020-07-13 14:24:00': 11}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 2,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 2,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 10,
#                            '2020-07-13 14:06:00': 5,
#                            '2020-07-13 14:24:00': 11}),
#               'websites': defaultdict(dict, {'2020-07-13 09:36:00': 2})}),
#  'Chinwe Jelanee': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 13:12:00': 1,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 6,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 13:12:00': 1,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 6,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 1})}),
#  'Blue Three': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 1,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 5,
#                            '2020-07-13 13:48:00': 8,
#                            '2020-07-13 14:06:00': 8,
#                            '2020-07-13 14:24:00': 16,
#                            '2020-07-13 14:42:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 1,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 5,
#                            '2020-07-13 13:48:00': 8,
#                            '2020-07-13 14:06:00': 8,
#                            '2020-07-13 14:24:00': 16,
#                            '2020-07-13 14:42:00': 1})}),
#  'Blue Four': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 10:12:00': 5,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 10,
#                            '2020-07-13 13:48:00': 13,
#                            '2020-07-13 14:06:00': 6,
#                            '2020-07-13 14:24:00': 5}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 10:12:00': 5,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 10,
#                            '2020-07-13 13:48:00': 13,
#                            '2020-07-13 14:06:00': 6,
#                            '2020-07-13 14:24:00': 5})}),
#  'Blue Two': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 5}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 5})}),
#  'Blue Five': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 1,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 12,
#                            '2020-07-13 13:48:00': 7,
#                            '2020-07-13 14:06:00': 16,
#                            '2020-07-13 14:24:00': 11,
#                            '2020-07-13 14:42:00': 16}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 1,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 12,
#                            '2020-07-13 13:48:00': 7,
#                            '2020-07-13 14:06:00': 16,
#                            '2020-07-13 14:24:00': 11,
#                            '2020-07-13 14:42:00': 16})}),
#  'Joy Okoye': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict, {'2020-07-13 13:48:00': 1}),
#               'microblog': defaultdict(dict, {'2020-07-13 13:48:00': 1})}),
#  'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:00:00': 5,
#                            '2020-07-13 09:18:00': 0,
#                            '2020-07-13 09:36:00': 0,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 3,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 5,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 1}),
#               'mail': defaultdict(dict,
#                           {'2020-07-13 09:00:00': 5,
#                            '2020-07-13 09:18:00': 0,
#                            '2020-07-13 09:36:00': 0,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 3,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 5,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 1})}),
#  'Debare Oni': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 13:30:00': 2,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 13:30:00': 2,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 1})}),
#  'Blue Six': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 2}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 14:24:00': 1,
#                            '2020-07-13 14:42:00': 2})}),
#  'Blue One': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 2,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 2,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 1,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1}),
#               'mail': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 1,
#                            '2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 2,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 1,
#                            '2020-07-13 12:54:00': 1,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 1,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 1}),
#               'microblog': defaultdict(dict, {'2020-07-13 12:54:00': 1})}),
#  'Hamani Heat': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 1,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 2,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 1}),
#               'gosocial': defaultdict(dict, {'2020-07-13 10:12:00': 1}),
#               'microblog': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 2,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 1})}),
#  'Benjamin Pepple': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict,
#                           {'2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 1}),
#               'mail': defaultdict(dict,
#                           {'2020-07-13 09:36:00': 1,
#                            '2020-07-13 09:54:00': 1,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 1})}),
#  'Adaego Eze': defaultdict(<function __main__.<lambda>()>,
#              {'All': defaultdict(dict, {'2020-07-13 09:36:00': 2}),
#               'mail': defaultdict(dict, {'2020-07-13 09:36:00': 2})})}

# %%
merged3.head()
# Out:
#                  date             name    channel interaction  \
# 0 2020-07-13 08:45:36  Guardian Hamani  microblog      repost
# 1 2020-07-13 09:00:51  Guardian Hamani  microblog       reply
# 2 2020-07-13 09:34:47  Guardian Hamani  microblog        like
# 3 2020-07-13 11:14:42  Guardian Hamani  microblog       reply
# 4 2020-07-13 10:18:06  Guardian Hamani  microblog       reply
#
#                                                 Text             from  \
# 0                                                     Guardian Hamani
# 1  The Government is in bed with the oil companie...  Guardian Hamani
# 2                                                     Guardian Hamani
# 3  The Government is corrupt and will never admit...   Chinwe Jelanee
# 4  Voting is crucial for change, please help our ...  Guardian Hamani
#
#             to                              image_url        type  Frequency  \
# 0   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 1   Aretta Obi  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 2  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 3  Dayo Isreal  /assets/styles/32563/profiles/you.png  rolePlayer          1
# 4         APGA  /assets/styles/32563/profiles/you.png  rolePlayer          1
#
#                      email
# 0       editor@guardian.ha
# 1       editor@guardian.ha
# 2       editor@guardian.ha
# 3  chinwe.jelanee@yahoo.ha
# 4       editor@guardian.ha

# %%
#doing a similar analysis but by person - get a list of all from personas:

from_list=merged3["from"].to_list()
from_list_unique=[]
for item in from_list:
    if item not in from_list_unique:
        from_list_unique.append(item)

# %%
from_list_unique
# Out:
# ['Guardian Hamani',
#  'Chinwe Jelanee',
#  'Paul Atuegbu',
#  'Ralph lfegwu',
#  'Stanley Ojukwu',
#  'Ikemba Alani',
#  'PDP',
#  'FEND',
#  'Dolly Dkwueme',
#  'Dayo Isreal',
#  'Hamani Heat',
#  'Telegraph Hamani',
#  'Laika News',
#  'APGA',
#  'Police Reform HA',
#  'Olajide',
#  'Checkawa',
#  'Big Kwame',
#  'British Army',
#  'Ussain Thunder',
#  'BBC News',
#  'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1',
#  'Debare Oni',
#  'PoliceHA',
#  'Blue One',
#  'Benjamin Pepple',
#  'Adaego Eze']

# %%
dict4={}
for person in person_list_unique:
    frames=[]
    for from_p in from_list_unique:
        try:
            channel_1=merged3.loc[(merged3["name"]==f"{person}") &(merged3["from"]==f'{from_p}'), :]
            merged_time_all=channel_1.resample('0.3H', on='date').sum()
            merged_time_all["from"]=f"{from_p}"
            frames.append(merged_time_all)
        except:
            continue
   
    merged=pd.concat(frames)
    merged=merged.reset_index()
    merged['date']=merged['date'].astype(str)
    merged = merged.groupby(['from', "date"])
    merged1=pd.DataFrame(merged["Frequency"].sum())
    
    results1 = defaultdict(lambda: defaultdict(dict))
    for index, value in merged1.itertuples():
        for i, key in enumerate(index):
            if i == 0:
                nested = results1[key]
            elif i == len(index) - 1:
                nested[key] = value
        else:
            nested = nested[key]
    
    
    dict4.update({f'{person}':results1})

# %%
dict4
# Out:
# {'Guardian Hamani': defaultdict(<function __main__.<lambda>()>,
#              {'Chinwe Jelanee': defaultdict(dict,
#                           {'2020-07-13 09:00:00': 2,
#                            '2020-07-13 09:18:00': 0,
#                            '2020-07-13 09:36:00': 0,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 2}),
#               'Guardian Hamani': defaultdict(dict,
#                           {'2020-07-13 08:42:00': 2,
#                            '2020-07-13 09:00:00': 2,
#                            '2020-07-13 09:18:00': 2,
#                            '2020-07-13 09:36:00': 0,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 2,
#                            '2020-07-13 10:30:00': 6,
#                            '2020-07-13 10:48:00': 2,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 2,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 2,
#                            '2020-07-13 13:48:00': 2,
#                            '2020-07-13 14:06:00': 14,
#                            '2020-07-13 14:24:00': 4,
#                            '2020-07-13 14:42:00': 2}),
#               'Ikemba Alani': defaultdict(dict, {'2020-07-13 13:12:00': 2}),
#               'PDP': defaultdict(dict, {'2020-07-13 13:12:00': 2}),
#               'Paul Atuegbu': defaultdict(dict, {'2020-07-13 13:12:00': 2}),
#               'Ralph lfegwu': defaultdict(dict, {'2020-07-13 11:06:00': 4}),
#               'Stanley Ojukwu': defaultdict(dict,
#                           {'2020-07-13 09:36:00': 2,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 2})}),
#  'Telegraph Hamani': defaultdict(<function __main__.<lambda>()>,
#              {'APGA': defaultdict(dict, {'2020-07-13 14:42:00': 2}),
#               'Chinwe Jelanee': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 2,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 2,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 4}),
#               'Dayo Isreal': defaultdict(dict,
#                           {'2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 4,
#                            '2020-07-13 14:24:00': 2}),
#               'Dolly Dkwueme': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 2,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 4,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 2}),
#               'FEND': defaultdict(dict,
#                           {'2020-07-13 14:06:00': 2,
#                            '2020-07-13 14:24:00': 2,
#                            '2020-07-13 14:42:00': 2}),
#               'Hamani Heat': defaultdict(dict,
#                           {'2020-07-13 14:06:00': 2,
#                            '2020-07-13 14:24:00': 0,
#                            '2020-07-13 14:42:00': 2}),
#               'Laika News': defaultdict(dict,
#                           {'2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 4,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 2,
#                            '2020-07-13 14:24:00': 0,
#                            '2020-07-13 14:42:00': 2}),
#               'PDP': defaultdict(dict,
#                           {'2020-07-13 11:24:00': 4,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 8,
#                            '2020-07-13 14:06:00': 6,
#                            '2020-07-13 14:24:00': 0,
#                            '2020-07-13 14:42:00': 2}),
#               'Telegraph Hamani': defaultdict(dict,
#                           {'2020-07-13 12:36:00': 2,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 2,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 0,
#                            '2020-07-13 14:42:00': 2})}),
#  'Dolly Dkwueme': defaultdict(<function __main__.<lambda>()>,
#              {'Dolly Dkwueme': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 2,
#                            '2020-07-13 09:36:00': 6,
#                            '2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 4,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 4,
#                            '2020-07-13 12:54:00': 8,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 20,
#                            '2020-07-13 14:06:00': 10,
#                            '2020-07-13 14:24:00': 22})}),
#  'Chinwe Jelanee': defaultdict(<function __main__.<lambda>()>,
#              {'Chinwe Jelanee': defaultdict(dict,
#                           {'2020-07-13 13:12:00': 2,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 8,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 2}),
#               'Dolly Dkwueme': defaultdict(dict,
#                           {'2020-07-13 13:48:00': 4,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 0,
#                            '2020-07-13 14:42:00': 2})}),
#  'Blue Three': defaultdict(<function __main__.<lambda>()>,
#              {'Police Reform HA': defaultdict(dict,
#                           {'2020-07-13 12:36:00': 2,
#                            '2020-07-13 12:54:00': 2,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 10,
#                            '2020-07-13 13:48:00': 16,
#                            '2020-07-13 14:06:00': 16,
#                            '2020-07-13 14:24:00': 32,
#                            '2020-07-13 14:42:00': 2})}),
#  'Blue Four': defaultdict(<function __main__.<lambda>()>,
#              {'Checkawa': defaultdict(dict, {'2020-07-13 13:48:00': 2}),
#               'Olajide': defaultdict(dict,
#                           {'2020-07-13 10:12:00': 10,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 4,
#                            '2020-07-13 13:30:00': 20,
#                            '2020-07-13 13:48:00': 24,
#                            '2020-07-13 14:06:00': 12,
#                            '2020-07-13 14:24:00': 10})}),
#  'Blue Two': defaultdict(<function __main__.<lambda>()>,
#              {'Big Kwame': defaultdict(dict, {'2020-07-13 10:30:00': 6}),
#               'British Army': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 4})}),
#  'Blue Five': defaultdict(<function __main__.<lambda>()>,
#              {'Ussain Thunder': defaultdict(dict,
#                           {'2020-07-13 10:30:00': 2,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 24,
#                            '2020-07-13 13:48:00': 14,
#                            '2020-07-13 14:06:00': 32,
#                            '2020-07-13 14:24:00': 22,
#                            '2020-07-13 14:42:00': 32})}),
#  'Joy Okoye': defaultdict(<function __main__.<lambda>()>,
#              {'BBC News': defaultdict(dict, {'2020-07-13 13:48:00': 2})}),
#  'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(<function __main__.<lambda>()>,
#              {'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': defaultdict(dict,
#                           {'2020-07-13 09:00:00': 10,
#                            '2020-07-13 09:18:00': 0,
#                            '2020-07-13 09:36:00': 0,
#                            '2020-07-13 09:54:00': 0,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 6,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 0,
#                            '2020-07-13 13:12:00': 4,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 10,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 2,
#                            '2020-07-13 14:42:00': 2})}),
#  'Debare Oni': defaultdict(<function __main__.<lambda>()>,
#              {'Debare Oni': defaultdict(dict,
#                           {'2020-07-13 13:30:00': 4,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 2})}),
#  'Blue Six': defaultdict(<function __main__.<lambda>()>,
#              {'PoliceHA': defaultdict(dict,
#                           {'2020-07-13 14:24:00': 2,
#                            '2020-07-13 14:42:00': 4})}),
#  'Blue One': defaultdict(<function __main__.<lambda>()>,
#              {'Blue One': defaultdict(dict,
#                           {'2020-07-13 09:18:00': 2,
#                            '2020-07-13 09:36:00': 2,
#                            '2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 4,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 2,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 4,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 2,
#                            '2020-07-13 14:06:00': 0,
#                            '2020-07-13 14:24:00': 2})}),
#  'Hamani Heat': defaultdict(<function __main__.<lambda>()>,
#              {'Hamani Heat': defaultdict(dict,
#                           {'2020-07-13 09:54:00': 4,
#                            '2020-07-13 10:12:00': 2,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 4,
#                            '2020-07-13 13:12:00': 0,
#                            '2020-07-13 13:30:00': 0,
#                            '2020-07-13 13:48:00': 0,
#                            '2020-07-13 14:06:00': 2})}),
#  'Benjamin Pepple': defaultdict(<function __main__.<lambda>()>,
#              {'Benjamin Pepple': defaultdict(dict,
#                           {'2020-07-13 09:36:00': 2,
#                            '2020-07-13 09:54:00': 2,
#                            '2020-07-13 10:12:00': 0,
#                            '2020-07-13 10:30:00': 0,
#                            '2020-07-13 10:48:00': 0,
#                            '2020-07-13 11:06:00': 0,
#                            '2020-07-13 11:24:00': 0,
#                            '2020-07-13 11:42:00': 0,
#                            '2020-07-13 12:00:00': 0,
#                            '2020-07-13 12:18:00': 0,
#                            '2020-07-13 12:36:00': 0,
#                            '2020-07-13 12:54:00': 2})}),
#  'Adaego Eze': defaultdict(<function __main__.<lambda>()>,
#              {'Adaego Eze': defaultdict(dict, {'2020-07-13 09:36:00': 4})})}

# %%
json_list
# Out:
# [{'impersonations': {'Adaego Eze': ['Adaego Eze'],
#    'Benjamin Pepple': ['Benjamin Pepple'],
#    'Blue Five': ['Ussain Thunder'],
#    'Blue Four': ['Checkawa', 'Olajide'],
#    'Blue One': ['Blue One'],
#    'Blue Six': ['PoliceHA'],
#    'Blue Three': ['Police Reform HA'],
#    'Blue Two': ['Big Kwame', 'British Army'],
#    'Chinwe Jelanee': ['Chinwe Jelanee', 'Dolly Dkwueme'],
#    'Debare Oni': ['Debare Oni'],
#    'Dolly Dkwueme': ['Dolly Dkwueme'],
#    'Guardian Hamani': ['Chinwe Jelanee',
#     'Guardian Hamani',
#     'Ikemba Alani',
#     'PDP',
#     'Paul Atuegbu',
#     'Ralph lfegwu',
#     'Stanley Ojukwu'],
#    'Hamani Heat': ['Hamani Heat'],
#    'Joy Okoye': ['BBC News'],
#    'Telegraph Hamani': ['APGA',
#     'Chinwe Jelanee',
#     'Dayo Isreal',
#     'Dolly Dkwueme',
#     'FEND',
#     'Hamani Heat',
#     'Laika News',
#     'PDP',
#     'Telegraph Hamani'],
#    'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': ['Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1']}},
#  {'from': defaultdict(<function __main__.<lambda>()>,
#               {'Adaego Eze': defaultdict(dict,
#                            {'Adaego Eze': {'All': 2, 'mail': 2}}),
#                'Benjamin Pepple': defaultdict(dict,
#                            {'Benjamin Pepple': {'All': 3, 'mail': 3}}),
#                'Blue Five': defaultdict(dict,
#                            {'Ussain Thunder': {'All': 63, 'microblog': 63}}),
#                'Blue Four': defaultdict(dict,
#                            {'Checkawa': {'All': 1, 'microblog': 1},
#                             'Olajide': {'All': 40, 'microblog': 40}}),
#                'Blue One': defaultdict(dict,
#                            {'Blue One': {'All': 12,
#                              'mail': 11,
#                              'microblog': 1}}),
#                'Blue Six': defaultdict(dict,
#                            {'PoliceHA': {'All': 3, 'microblog': 3}}),
#                'Blue Three': defaultdict(dict,
#                            {'Police Reform HA': {'All': 40, 'microblog': 40}}),
#                'Blue Two': defaultdict(dict,
#                            {'Big Kwame': {'All': 3, 'microblog': 3},
#                             'British Army': {'All': 3, 'microblog': 3}}),
#                'Chinwe Jelanee': defaultdict(dict,
#                            {'Chinwe Jelanee': {'All': 6, 'microblog': 6},
#                             'Dolly Dkwueme': {'All': 3, 'microblog': 3}}),
#                'Debare Oni': defaultdict(dict,
#                            {'Debare Oni': {'All': 3, 'microblog': 3}}),
#                'Dolly Dkwueme': defaultdict(dict,
#                            {'Dolly Dkwueme': {'All': 39,
#                              'microblog': 37,
#                              'websites': 2}}),
#                'Guardian Hamani': defaultdict(dict,
#                            {'Chinwe Jelanee': {'All': 2, 'microblog': 2},
#                             'Guardian Hamani': {'All': 21, 'microblog': 21},
#                             'Ikemba Alani': {'All': 1, 'microblog': 1},
#                             'PDP': {'All': 1, 'microblog': 1},
#                             'Paul Atuegbu': {'All': 1, 'microblog': 1},
#                             'Ralph lfegwu': {'All': 2, 'microblog': 2},
#                             'Stanley Ojukwu': {'All': 2, 'microblog': 2}}),
#                'Hamani Heat': defaultdict(dict,
#                            {'Hamani Heat': {'All': 6,
#                              'gosocial': 1,
#                              'microblog': 5}}),
#                'Joy Okoye': defaultdict(dict,
#                            {'BBC News': {'All': 1, 'microblog': 1}}),
#                'Telegraph Hamani': defaultdict(dict,
#                            {'APGA': {'All': 1, 'microblog': 1},
#                             'Chinwe Jelanee': {'All': 4, 'microblog': 4},
#                             'Dayo Isreal': {'All': 4, 'microblog': 4},
#                             'Dolly Dkwueme': {'All': 5, 'microblog': 5},
#                             'FEND': {'All': 3, 'microblog': 3},
#                             'Hamani Heat': {'All': 2, 'microblog': 2},
#                             'Laika News': {'All': 6, 'microblog': 6},
#                             'PDP': {'All': 10, 'microblog': 10},
#                             'Telegraph Hamani': {'All': 6, 'microblog': 6}}),
#                'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(dict,
#                            {'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': {'All': 17,
#                              'mail': 17}})})}]

# %%
total_to_channel= merged3.groupby(['name','to','channel'])
total_to_channel=pd.DataFrame(total_to_channel["Frequency"].count())
total_to_channel
# Out:
#                                                                Frequency
# name                                 to               channel
# Adaego Eze                           Blue One         All              1
#                                                       mail             1
#                                      Joy Okoye        All              1
#                                                       mail             1
# Benjamin Pepple                      Blue One         All              2
# ...                                                                  ...
# Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1) Olajide          mail             2
#                                      Police Reform HA All              3
#                                                       mail             3
#                                      Ussain Thunder   All              2
#                                                       mail             2
#
# [281 rows x 1 columns]

# %%
results5 = defaultdict(lambda: defaultdict(dict))

for index, value in total_to_channel.itertuples():
    for i, key in enumerate(index):
        if i == 0:
            nested = results5[key]
        elif i == len(index) - 1:
            nested[key] = value
        else:
            nested = nested[key]

# %%
results6={"to":results5}
results6
# Out:
# {'to': defaultdict(<function __main__.<lambda>()>,
#              {'Adaego Eze': defaultdict(dict,
#                           {'Blue One': {'All': 1, 'mail': 1},
#                            'Joy Okoye': {'All': 1, 'mail': 1}}),
#               'Benjamin Pepple': defaultdict(dict,
#                           {'Blue One': {'All': 2, 'mail': 2},
#                            'Joy Okoye': {'All': 1, 'mail': 1}}),
#               'Blue Five': defaultdict(dict,
#                           {'British Army': {'All': 7, 'microblog': 7},
#                            'Checkawa': {'All': 6, 'microblog': 6},
#                            'Gary': {'All': 1, 'microblog': 1},
#                            'HamaniInfoAbuja': {'All': 1, 'microblog': 1},
#                            'HumAngle_': {'All': 1, 'microblog': 1},
#                            'Ifama Chyke': {'All': 1, 'microblog': 1},
#                            'Independent Hamani': {'All': 1, 'microblog': 1},
#                            'Laika News': {'All': 1, 'microblog': 1},
#                            'Olajide': {'All': 4, 'microblog': 4},
#                            'OrderPaper': {'All': 2, 'microblog': 2},
#                            'Police Reform HA': {'All': 32, 'microblog': 32},
#                            'The Eagle Online': {'All': 1, 'microblog': 1},
#                            'The Wanted Emcees': {'All': 1, 'microblog': 1},
#                            'ThisNews': {'All': 2, 'microblog': 2},
#                            'Ussain Thunder': {'All': 2, 'microblog': 2}}),
#               'Blue Four': defaultdict(dict,
#                           {'Adaeze Chioma': {'All': 2, 'microblog': 2},
#                            'Ambi': {'All': 1, 'microblog': 1},
#                            'BBC News': {'All': 1, 'microblog': 1},
#                            'British Army': {'All': 6, 'microblog': 6},
#                            'Checkawa': {'All': 5, 'microblog': 5},
#                            'Chinwe Jelanee': {'All': 2, 'microblog': 2},
#                            'CrimeFighters': {'All': 1, 'microblog': 1},
#                            'Dolly Dkwueme': {'All': 1, 'microblog': 1},
#                            'Hamani Heat': {'All': 1, 'microblog': 1},
#                            'Laika News': {'All': 1, 'microblog': 1},
#                            'Olajide': {'All': 1, 'microblog': 1},
#                            'Orisa Kazah': {'All': 2, 'microblog': 2},
#                            'Police Reform HA': {'All': 12, 'microblog': 12},
#                            'The Wanted Emcees': {'All': 1, 'microblog': 1},
#                            'Ussain Thunder': {'All': 2, 'microblog': 2},
#                            'malia obama': {'All': 2, 'microblog': 2}}),
#               'Blue One': defaultdict(dict,
#                           {'Adaego Eze': {'All': 2, 'mail': 2},
#                            'Amara Chibuzo': {'All': 1, 'microblog': 1},
#                            'Benjamin Pepple': {'All': 3, 'mail': 3},
#                            'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': {'All': 6,
#                             'mail': 6}}),
#               'Blue Six': defaultdict(dict,
#                           {'Chidi Jelany': {'All': 1, 'microblog': 1},
#                            'Udo Mazi': {'All': 1, 'microblog': 1},
#                            'malia obama': {'All': 1, 'microblog': 1}}),
#               'Blue Three': defaultdict(dict,
#                           {'Ambi': {'All': 3, 'microblog': 3},
#                            'BBC News': {'All': 2, 'microblog': 2},
#                            'Big Kwame': {'All': 1, 'microblog': 1},
#                            'British Army': {'All': 7, 'microblog': 7},
#                            'Chancellor Exchequer': {'All': 1, 'microblog': 1},
#                            'Checkawa': {'All': 4, 'microblog': 4},
#                            'Chidi Jelany': {'All': 1, 'microblog': 1},
#                            'Dolly Dkwueme': {'All': 3, 'microblog': 3},
#                            'Dotun Oladipo': {'All': 1, 'microblog': 1},
#                            'HumAngle_': {'All': 1, 'microblog': 1},
#                            'Madu Onuorah': {'All': 1, 'microblog': 1},
#                            'Musbau rasak': {'All': 1, 'microblog': 1},
#                            'Olajide': {'All': 2, 'microblog': 2},
#                            'Olisa Okparro': {'All': 1, 'microblog': 1},
#                            'OrderPaper': {'All': 1, 'microblog': 1},
#                            'Police Reform HA': {'All': 2, 'microblog': 2},
#                            'PoliceHA': {'All': 1, 'microblog': 1},
#                            'RAT BLOOD RIZZY': {'All': 1, 'microblog': 1},
#                            'Santech Ha': {'All': 1, 'microblog': 1},
#                            'Shake and Bake': {'All': 1, 'microblog': 1},
#                            'The White Helmets': {'All': 1, 'microblog': 1},
#                            'TheNewsGuru': {'All': 1, 'microblog': 1},
#                            'Ussain Thunder': {'All': 2, 'microblog': 2}}),
#               'Blue Two': defaultdict(dict,
#                           {'British Army': {'All': 3, 'microblog': 3},
#                            'Dara Umar': {'All': 2, 'microblog': 2},
#                            'Onyeka Chononso': {'All': 1, 'microblog': 1}}),
#               'Chinwe Jelanee': defaultdict(dict,
#                           {'BBC News': {'All': 1, 'microblog': 1},
#                            'British Army': {'All': 2, 'microblog': 2},
#                            'Chinwe Jelanee': {'All': 1, 'microblog': 1},
#                            'Hamani Heat': {'All': 3, 'microblog': 3},
#                            'Police Reform HA': {'All': 1, 'microblog': 1},
#                            'Tamara': {'All': 1, 'microblog': 1}}),
#               'Debare Oni': defaultdict(dict,
#                           {'Big Kwame': {'All': 1, 'microblog': 1},
#                            'Police Reform HA': {'All': 2, 'microblog': 2}}),
#               'Dolly Dkwueme': defaultdict(dict,
#                           {'Amara Chibuzo': {'All': 2, 'microblog': 2},
#                            'BBC News': {'All': 7, 'microblog': 7},
#                            'British Army': {'All': 1, 'microblog': 1},
#                            'Dolly Dkwueme': {'All': 5,
#                             'microblog': 3,
#                             'websites': 2},
#                            'Gary': {'All': 2, 'microblog': 2},
#                            'Guardian Hamani': {'All': 8, 'microblog': 8},
#                            'Iamgarfield': {'All': 1, 'microblog': 1},
#                            'Koofrey Uchea': {'All': 1, 'microblog': 1},
#                            'Lorietha Causey': {'All': 2, 'microblog': 2},
#                            'Ogechi Obasea': {'All': 1, 'microblog': 1},
#                            'Olisa Okparro': {'All': 2, 'microblog': 2},
#                            'Tamara': {'All': 1, 'microblog': 1},
#                            'UPTown Hamani': {'All': 1, 'microblog': 1},
#                            'Udo Mazi': {'All': 1, 'microblog': 1},
#                            'Ultrascan MENA': {'All': 1, 'microblog': 1},
#                            'Uturu Today': {'All': 2, 'microblog': 2},
#                            'Yewande Ogun': {'All': 1, 'microblog': 1}}),
#               'Guardian Hamani': defaultdict(dict,
#                           {'APGA': {'All': 3, 'microblog': 3},
#                            'Alika Oni': {'All': 1, 'microblog': 1},
#                            'Aretta Obi': {'All': 2, 'microblog': 2},
#                            'Big Kwame': {'All': 1, 'microblog': 1},
#                            'British Army': {'All': 3, 'microblog': 3},
#                            'Chidi Jelany': {'All': 1, 'microblog': 1},
#                            'Daily Times Hamani': {'All': 1, 'microblog': 1},
#                            'Dayo Isreal': {'All': 2, 'microblog': 2},
#                            'Dolly Dkwueme': {'All': 2, 'microblog': 2},
#                            'Eshe Uchechey': {'All': 1, 'microblog': 1},
#                            'Guardian Hamani': {'All': 1, 'microblog': 1},
#                            'Police Reform HA': {'All': 8, 'microblog': 8},
#                            'Udo Mazi': {'All': 1, 'microblog': 1},
#                            'Ultrascan MENA': {'All': 1, 'microblog': 1},
#                            'Wendy  ABOLISH POLICE, ICE,  DHS B': {'All': 1,
#                             'microblog': 1},
#                            'malia obama': {'All': 1, 'microblog': 1}}),
#               'Hamani Heat': defaultdict(dict,
#                           {'Hamani Heat': {'All': 2, 'microblog': 2},
#                            'HumAngle_': {'All': 1, 'microblog': 1},
#                            'St. John Baptist Church': {'All': 1,
#                             'gosocial': 1},
#                            'Telegraph Hamani': {'All': 2, 'microblog': 2}}),
#               'Joy Okoye': defaultdict(dict,
#                           {'British Army': {'All': 1, 'microblog': 1}}),
#               'Telegraph Hamani': defaultdict(dict,
#                           {'4 ': {'All': 1, 'microblog': 1},
#                            'Angel Nduka-Nwosu': {'All': 1, 'microblog': 1},
#                            'BBC News': {'All': 2, 'microblog': 2},
#                            'British Army': {'All': 3, 'microblog': 3},
#                            'Checkawa': {'All': 1, 'microblog': 1},
#                            'Chidi Jelany': {'All': 1, 'microblog': 1},
#                            'Dayo Isreal': {'All': 1, 'microblog': 1},
#                            'Diane Post-Lester': {'All': 1, 'microblog': 1},
#                            'Dolly Dkwueme': {'All': 1, 'microblog': 1},
#                            'Guardian Hamani': {'All': 9, 'microblog': 9},
#                            'Iamgarfield': {'All': 1, 'microblog': 1},
#                            'Ikemba Alani': {'All': 1, 'microblog': 1},
#                            'Laika News': {'All': 1, 'microblog': 1},
#                            'Lorietha Causey': {'All': 1, 'microblog': 1},
#                            'Neo Pitso': {'All': 1, 'microblog': 1},
#                            'Onyeka Chononso': {'All': 1, 'microblog': 1},
#                            'PDP': {'All': 2, 'microblog': 2},
#                            'Police Reform HA': {'All': 2, 'microblog': 2},
#                            'Stanley Ojukwu': {'All': 1, 'microblog': 1},
#                            'Telegraph Hamani': {'All': 8, 'microblog': 8},
#                            'The Wanted Emcees': {'All': 1, 'microblog': 1}}),
#               'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(dict,
#                           {'Big Kwame': {'All': 3, 'mail': 3},
#                            'Blue One': {'All': 7, 'mail': 7},
#                            'Olajide': {'All': 2, 'mail': 2},
#                            'Police Reform HA': {'All': 3, 'mail': 3},
#                            'Ussain Thunder': {'All': 2, 'mail': 2}})})}

# %%
json_list.append(results6)

# %%
dict5={"time_list": time_list}
json_list.append(dict5)

# %%
json_list.append(dict2)

# %%
json_list
# Out:
# [{'impersonations': {'Adaego Eze': ['Adaego Eze'],
#    'Benjamin Pepple': ['Benjamin Pepple'],
#    'Blue Five': ['Ussain Thunder'],
#    'Blue Four': ['Checkawa', 'Olajide'],
#    'Blue One': ['Blue One'],
#    'Blue Six': ['PoliceHA'],
#    'Blue Three': ['Police Reform HA'],
#    'Blue Two': ['Big Kwame', 'British Army'],
#    'Chinwe Jelanee': ['Chinwe Jelanee', 'Dolly Dkwueme'],
#    'Debare Oni': ['Debare Oni'],
#    'Dolly Dkwueme': ['Dolly Dkwueme'],
#    'Guardian Hamani': ['Chinwe Jelanee',
#     'Guardian Hamani',
#     'Ikemba Alani',
#     'PDP',
#     'Paul Atuegbu',
#     'Ralph lfegwu',
#     'Stanley Ojukwu'],
#    'Hamani Heat': ['Hamani Heat'],
#    'Joy Okoye': ['BBC News'],
#    'Telegraph Hamani': ['APGA',
#     'Chinwe Jelanee',
#     'Dayo Isreal',
#     'Dolly Dkwueme',
#     'FEND',
#     'Hamani Heat',
#     'Laika News',
#     'PDP',
#     'Telegraph Hamani'],
#    'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': ['Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1']}},
#  {'from': defaultdict(<function __main__.<lambda>()>,
#               {'Adaego Eze': defaultdict(dict,
#                            {'Adaego Eze': {'All': 2, 'mail': 2}}),
#                'Benjamin Pepple': defaultdict(dict,
#                            {'Benjamin Pepple': {'All': 3, 'mail': 3}}),
#                'Blue Five': defaultdict(dict,
#                            {'Ussain Thunder': {'All': 63, 'microblog': 63}}),
#                'Blue Four': defaultdict(dict,
#                            {'Checkawa': {'All': 1, 'microblog': 1},
#                             'Olajide': {'All': 40, 'microblog': 40}}),
#                'Blue One': defaultdict(dict,
#                            {'Blue One': {'All': 12,
#                              'mail': 11,
#                              'microblog': 1}}),
#                'Blue Six': defaultdict(dict,
#                            {'PoliceHA': {'All': 3, 'microblog': 3}}),
#                'Blue Three': defaultdict(dict,
#                            {'Police Reform HA': {'All': 40, 'microblog': 40}}),
#                'Blue Two': defaultdict(dict,
#                            {'Big Kwame': {'All': 3, 'microblog': 3},
#                             'British Army': {'All': 3, 'microblog': 3}}),
#                'Chinwe Jelanee': defaultdict(dict,
#                            {'Chinwe Jelanee': {'All': 6, 'microblog': 6},
#                             'Dolly Dkwueme': {'All': 3, 'microblog': 3}}),
#                'Debare Oni': defaultdict(dict,
#                            {'Debare Oni': {'All': 3, 'microblog': 3}}),
#                'Dolly Dkwueme': defaultdict(dict,
#                            {'Dolly Dkwueme': {'All': 39,
#                              'microblog': 37,
#                              'websites': 2}}),
#                'Guardian Hamani': defaultdict(dict,
#                            {'Chinwe Jelanee': {'All': 2, 'microblog': 2},
#                             'Guardian Hamani': {'All': 21, 'microblog': 21},
#                             'Ikemba Alani': {'All': 1, 'microblog': 1},
#                             'PDP': {'All': 1, 'microblog': 1},
#                             'Paul Atuegbu': {'All': 1, 'microblog': 1},
#                             'Ralph lfegwu': {'All': 2, 'microblog': 2},
#                             'Stanley Ojukwu': {'All': 2, 'microblog': 2}}),
#                'Hamani Heat': defaultdict(dict,
#                            {'Hamani Heat': {'All': 6,
#                              'gosocial': 1,
#                              'microblog': 5}}),
#                'Joy Okoye': defaultdict(dict,
#                            {'BBC News': {'All': 1, 'microblog': 1}}),
#                'Telegraph Hamani': defaultdict(dict,
#                            {'APGA': {'All': 1, 'microblog': 1},
#                             'Chinwe Jelanee': {'All': 4, 'microblog': 4},
#                             'Dayo Isreal': {'All': 4, 'microblog': 4},
#                             'Dolly Dkwueme': {'All': 5, 'microblog': 5},
#                             'FEND': {'All': 3, 'microblog': 3},
#                             'Hamani Heat': {'All': 2, 'microblog': 2},
#                             'Laika News': {'All': 6, 'microblog': 6},
#                             'PDP': {'All': 10, 'microblog': 10},
#                             'Telegraph Hamani': {'All': 6, 'microblog': 6}}),
#                'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(dict,
#                            {'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': {'All': 17,
#                              'mail': 17}})})},
#  {'to': defaultdict(<function __main__.<lambda>()>,
#               {'Adaego Eze': defaultdict(dict,
#                            {'Blue One': {'All': 1, 'mail': 1},
#                             'Joy Okoye': {'All': 1, 'mail': 1}}),
#                'Benjamin Pepple': defaultdict(dict,
#                            {'Blue One': {'All': 2, 'mail': 2},
#                             'Joy Okoye': {'All': 1, 'mail': 1}}),
#                'Blue Five': defaultdict(dict,
#                            {'British Army': {'All': 7, 'microblog': 7},
#                             'Checkawa': {'All': 6, 'microblog': 6},
#                             'Gary': {'All': 1, 'microblog': 1},
#                             'HamaniInfoAbuja': {'All': 1, 'microblog': 1},
#                             'HumAngle_': {'All': 1, 'microblog': 1},
#                             'Ifama Chyke': {'All': 1, 'microblog': 1},
#                             'Independent Hamani': {'All': 1, 'microblog': 1},
#                             'Laika News': {'All': 1, 'microblog': 1},
#                             'Olajide': {'All': 4, 'microblog': 4},
#                             'OrderPaper': {'All': 2, 'microblog': 2},
#                             'Police Reform HA': {'All': 32, 'microblog': 32},
#                             'The Eagle Online': {'All': 1, 'microblog': 1},
#                             'The Wanted Emcees': {'All': 1, 'microblog': 1},
#                             'ThisNews': {'All': 2, 'microblog': 2},
#                             'Ussain Thunder': {'All': 2, 'microblog': 2}}),
#                'Blue Four': defaultdict(dict,
#                            {'Adaeze Chioma': {'All': 2, 'microblog': 2},
#                             'Ambi': {'All': 1, 'microblog': 1},
#                             'BBC News': {'All': 1, 'microblog': 1},
#                             'British Army': {'All': 6, 'microblog': 6},
#                             'Checkawa': {'All': 5, 'microblog': 5},
#                             'Chinwe Jelanee': {'All': 2, 'microblog': 2},
#                             'CrimeFighters': {'All': 1, 'microblog': 1},
#                             'Dolly Dkwueme': {'All': 1, 'microblog': 1},
#                             'Hamani Heat': {'All': 1, 'microblog': 1},
#                             'Laika News': {'All': 1, 'microblog': 1},
#                             'Olajide': {'All': 1, 'microblog': 1},
#                             'Orisa Kazah': {'All': 2, 'microblog': 2},
#                             'Police Reform HA': {'All': 12, 'microblog': 12},
#                             'The Wanted Emcees': {'All': 1, 'microblog': 1},
#                             'Ussain Thunder': {'All': 2, 'microblog': 2},
#                             'malia obama': {'All': 2, 'microblog': 2}}),
#                'Blue One': defaultdict(dict,
#                            {'Adaego Eze': {'All': 2, 'mail': 2},
#                             'Amara Chibuzo': {'All': 1, 'microblog': 1},
#                             'Benjamin Pepple': {'All': 3, 'mail': 3},
#                             'Write, Tom Lt Col SJFHQ-JFHQ-J6-SO1': {'All': 6,
#                              'mail': 6}}),
#                'Blue Six': defaultdict(dict,
#                            {'Chidi Jelany': {'All': 1, 'microblog': 1},
#                             'Udo Mazi': {'All': 1, 'microblog': 1},
#                             'malia obama': {'All': 1, 'microblog': 1}}),
#                'Blue Three': defaultdict(dict,
#                            {'Ambi': {'All': 3, 'microblog': 3},
#                             'BBC News': {'All': 2, 'microblog': 2},
#                             'Big Kwame': {'All': 1, 'microblog': 1},
#                             'British Army': {'All': 7, 'microblog': 7},
#                             'Chancellor Exchequer': {'All': 1, 'microblog': 1},
#                             'Checkawa': {'All': 4, 'microblog': 4},
#                             'Chidi Jelany': {'All': 1, 'microblog': 1},
#                             'Dolly Dkwueme': {'All': 3, 'microblog': 3},
#                             'Dotun Oladipo': {'All': 1, 'microblog': 1},
#                             'HumAngle_': {'All': 1, 'microblog': 1},
#                             'Madu Onuorah': {'All': 1, 'microblog': 1},
#                             'Musbau rasak': {'All': 1, 'microblog': 1},
#                             'Olajide': {'All': 2, 'microblog': 2},
#                             'Olisa Okparro': {'All': 1, 'microblog': 1},
#                             'OrderPaper': {'All': 1, 'microblog': 1},
#                             'Police Reform HA': {'All': 2, 'microblog': 2},
#                             'PoliceHA': {'All': 1, 'microblog': 1},
#                             'RAT BLOOD RIZZY': {'All': 1, 'microblog': 1},
#                             'Santech Ha': {'All': 1, 'microblog': 1},
#                             'Shake and Bake': {'All': 1, 'microblog': 1},
#                             'The White Helmets': {'All': 1, 'microblog': 1},
#                             'TheNewsGuru': {'All': 1, 'microblog': 1},
#                             'Ussain Thunder': {'All': 2, 'microblog': 2}}),
#                'Blue Two': defaultdict(dict,
#                            {'British Army': {'All': 3, 'microblog': 3},
#                             'Dara Umar': {'All': 2, 'microblog': 2},
#                             'Onyeka Chononso': {'All': 1, 'microblog': 1}}),
#                'Chinwe Jelanee': defaultdict(dict,
#                            {'BBC News': {'All': 1, 'microblog': 1},
#                             'British Army': {'All': 2, 'microblog': 2},
#                             'Chinwe Jelanee': {'All': 1, 'microblog': 1},
#                             'Hamani Heat': {'All': 3, 'microblog': 3},
#                             'Police Reform HA': {'All': 1, 'microblog': 1},
#                             'Tamara': {'All': 1, 'microblog': 1}}),
#                'Debare Oni': defaultdict(dict,
#                            {'Big Kwame': {'All': 1, 'microblog': 1},
#                             'Police Reform HA': {'All': 2, 'microblog': 2}}),
#                'Dolly Dkwueme': defaultdict(dict,
#                            {'Amara Chibuzo': {'All': 2, 'microblog': 2},
#                             'BBC News': {'All': 7, 'microblog': 7},
#                             'British Army': {'All': 1, 'microblog': 1},
#                             'Dolly Dkwueme': {'All': 5,
#                              'microblog': 3,
#                              'websites': 2},
#                             'Gary': {'All': 2, 'microblog': 2},
#                             'Guardian Hamani': {'All': 8, 'microblog': 8},
#                             'Iamgarfield': {'All': 1, 'microblog': 1},
#                             'Koofrey Uchea': {'All': 1, 'microblog': 1},
#                             'Lorietha Causey': {'All': 2, 'microblog': 2},
#                             'Ogechi Obasea': {'All': 1, 'microblog': 1},
#                             'Olisa Okparro': {'All': 2, 'microblog': 2},
#                             'Tamara': {'All': 1, 'microblog': 1},
#                             'UPTown Hamani': {'All': 1, 'microblog': 1},
#                             'Udo Mazi': {'All': 1, 'microblog': 1},
#                             'Ultrascan MENA': {'All': 1, 'microblog': 1},
#                             'Uturu Today': {'All': 2, 'microblog': 2},
#                             'Yewande Ogun': {'All': 1, 'microblog': 1}}),
#                'Guardian Hamani': defaultdict(dict,
#                            {'APGA': {'All': 3, 'microblog': 3},
#                             'Alika Oni': {'All': 1, 'microblog': 1},
#                             'Aretta Obi': {'All': 2, 'microblog': 2},
#                             'Big Kwame': {'All': 1, 'microblog': 1},
#                             'British Army': {'All': 3, 'microblog': 3},
#                             'Chidi Jelany': {'All': 1, 'microblog': 1},
#                             'Daily Times Hamani': {'All': 1, 'microblog': 1},
#                             'Dayo Isreal': {'All': 2, 'microblog': 2},
#                             'Dolly Dkwueme': {'All': 2, 'microblog': 2},
#                             'Eshe Uchechey': {'All': 1, 'microblog': 1},
#                             'Guardian Hamani': {'All': 1, 'microblog': 1},
#                             'Police Reform HA': {'All': 8, 'microblog': 8},
#                             'Udo Mazi': {'All': 1, 'microblog': 1},
#                             'Ultrascan MENA': {'All': 1, 'microblog': 1},
#                             'Wendy  ABOLISH POLICE, ICE,  DHS B': {'All': 1,
#                              'microblog': 1},
#                             'malia obama': {'All': 1, 'microblog': 1}}),
#                'Hamani Heat': defaultdict(dict,
#                            {'Hamani Heat': {'All': 2, 'microblog': 2},
#                             'HumAngle_': {'All': 1, 'microblog': 1},
#                             'St. John Baptist Church': {'All': 1,
#                              'gosocial': 1},
#                             'Telegraph Hamani': {'All': 2, 'microblog': 2}}),
#                'Joy Okoye': defaultdict(dict,
#                            {'British Army': {'All': 1, 'microblog': 1}}),
#                'Telegraph Hamani': defaultdict(dict,
#                            {'4 ': {'All': 1, 'microblog': 1},
#                             'Angel Nduka-Nwosu': {'All': 1, 'microblog': 1},
#                             'BBC News': {'All': 2, 'microblog': 2},
#                             'British Army': {'All': 3, 'microblog': 3},
#                             'Checkawa': {'All': 1, 'microblog': 1},
#                             'Chidi Jelany': {'All': 1, 'microblog': 1},
#                             'Dayo Isreal': {'All': 1, 'microblog': 1},
#                             'Diane Post-Lester': {'All': 1, 'microblog': 1},
#                             'Dolly Dkwueme': {'All': 1, 'microblog': 1},
#                             'Guardian Hamani': {'All': 9, 'microblog': 9},
#                             'Iamgarfield': {'All': 1, 'microblog': 1},
#                             'Ikemba Alani': {'All': 1, 'microblog': 1},
#                             'Laika News': {'All': 1, 'microblog': 1},
#                             'Lorietha Causey': {'All': 1, 'microblog': 1},
#                             'Neo Pitso': {'All': 1, 'microblog': 1},
#                             'Onyeka Chononso': {'All': 1, 'microblog': 1},
#                             'PDP': {'All': 2, 'microblog': 2},
#                             'Police Reform HA': {'All': 2, 'microblog': 2},
#                             'Stanley Ojukwu': {'All': 1, 'microblog': 1},
#                             'Telegraph Hamani': {'All': 8, 'microblog': 8},
#                             'The Wanted Emcees': {'All': 1, 'microblog': 1}}),
#                'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(dict,
#                            {'Big Kwame': {'All': 3, 'mail': 3},
#                             'Blue One': {'All': 7, 'mail': 7},
#                             'Olajide': {'All': 2, 'mail': 2},
#                             'Police Reform HA': {'All': 3, 'mail': 3},
#                             'Ussain Thunder': {'All': 2, 'mail': 2}})})},
#  {'time_list': ['2020-07-13 08:42:00',
#    '2020-07-13 09:00:00',
#    '2020-07-13 09:18:00',
#    '2020-07-13 09:36:00',
#    '2020-07-13 09:54:00',
#    '2020-07-13 10:12:00',
#    '2020-07-13 10:30:00',
#    '2020-07-13 10:48:00',
#    '2020-07-13 11:06:00',
#    '2020-07-13 11:24:00',
#    '2020-07-13 11:42:00',
#    '2020-07-13 12:00:00',
#    '2020-07-13 12:18:00',
#    '2020-07-13 12:36:00',
#    '2020-07-13 12:54:00',
#    '2020-07-13 13:12:00',
#    '2020-07-13 13:30:00',
#    '2020-07-13 13:48:00',
#    '2020-07-13 14:06:00',
#    '2020-07-13 14:24:00',
#    '2020-07-13 14:42:00']},
#  {'Guardian Hamani': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 08:42:00': 1,
#                             '2020-07-13 09:00:00': 2,
#                             '2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 0,
#                             '2020-07-13 10:12:00': 1,
#                             '2020-07-13 10:30:00': 3,
#                             '2020-07-13 10:48:00': 1,
#                             '2020-07-13 11:06:00': 4,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 1,
#                             '2020-07-13 13:12:00': 3,
#                             '2020-07-13 13:30:00': 1,
#                             '2020-07-13 13:48:00': 1,
#                             '2020-07-13 14:06:00': 7,
#                             '2020-07-13 14:24:00': 2,
#                             '2020-07-13 14:42:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 08:42:00': 1,
#                             '2020-07-13 09:00:00': 2,
#                             '2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 0,
#                             '2020-07-13 10:12:00': 1,
#                             '2020-07-13 10:30:00': 3,
#                             '2020-07-13 10:48:00': 1,
#                             '2020-07-13 11:06:00': 4,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 1,
#                             '2020-07-13 13:12:00': 3,
#                             '2020-07-13 13:30:00': 1,
#                             '2020-07-13 13:48:00': 1,
#                             '2020-07-13 14:06:00': 7,
#                             '2020-07-13 14:24:00': 2,
#                             '2020-07-13 14:42:00': 1})}),
#   'Telegraph Hamani': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 10:30:00': 2,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 1,
#                             '2020-07-13 11:24:00': 2,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 4,
#                             '2020-07-13 13:12:00': 7,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 7,
#                             '2020-07-13 14:06:00': 8,
#                             '2020-07-13 14:24:00': 3,
#                             '2020-07-13 14:42:00': 6}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 10:30:00': 2,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 1,
#                             '2020-07-13 11:24:00': 2,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 4,
#                             '2020-07-13 13:12:00': 7,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 7,
#                             '2020-07-13 14:06:00': 8,
#                             '2020-07-13 14:24:00': 3,
#                             '2020-07-13 14:42:00': 6})}),
#   'Dolly Dkwueme': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 3,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 2,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 2,
#                             '2020-07-13 12:54:00': 4,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 10,
#                             '2020-07-13 14:06:00': 5,
#                             '2020-07-13 14:24:00': 11}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 2,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 2,
#                             '2020-07-13 12:54:00': 4,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 10,
#                             '2020-07-13 14:06:00': 5,
#                             '2020-07-13 14:24:00': 11}),
#                'websites': defaultdict(dict, {'2020-07-13 09:36:00': 2})}),
#   'Chinwe Jelanee': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 13:12:00': 1,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 6,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 13:12:00': 1,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 6,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 1})}),
#   'Blue Three': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 1,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 5,
#                             '2020-07-13 13:48:00': 8,
#                             '2020-07-13 14:06:00': 8,
#                             '2020-07-13 14:24:00': 16,
#                             '2020-07-13 14:42:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 1,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 5,
#                             '2020-07-13 13:48:00': 8,
#                             '2020-07-13 14:06:00': 8,
#                             '2020-07-13 14:24:00': 16,
#                             '2020-07-13 14:42:00': 1})}),
#   'Blue Four': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 10:12:00': 5,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 10,
#                             '2020-07-13 13:48:00': 13,
#                             '2020-07-13 14:06:00': 6,
#                             '2020-07-13 14:24:00': 5}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 10:12:00': 5,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 10,
#                             '2020-07-13 13:48:00': 13,
#                             '2020-07-13 14:06:00': 6,
#                             '2020-07-13 14:24:00': 5})}),
#   'Blue Two': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 5}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 5})}),
#   'Blue Five': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 10:30:00': 1,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 12,
#                             '2020-07-13 13:48:00': 7,
#                             '2020-07-13 14:06:00': 16,
#                             '2020-07-13 14:24:00': 11,
#                             '2020-07-13 14:42:00': 16}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 10:30:00': 1,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 12,
#                             '2020-07-13 13:48:00': 7,
#                             '2020-07-13 14:06:00': 16,
#                             '2020-07-13 14:24:00': 11,
#                             '2020-07-13 14:42:00': 16})}),
#   'Joy Okoye': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict, {'2020-07-13 13:48:00': 1}),
#                'microblog': defaultdict(dict, {'2020-07-13 13:48:00': 1})}),
#   'Write Tom Lt Col (SJFHQ-JFHQ-J6-SO1)': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:00:00': 5,
#                             '2020-07-13 09:18:00': 0,
#                             '2020-07-13 09:36:00': 0,
#                             '2020-07-13 09:54:00': 0,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 3,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 5,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 1}),
#                'mail': defaultdict(dict,
#                            {'2020-07-13 09:00:00': 5,
#                             '2020-07-13 09:18:00': 0,
#                             '2020-07-13 09:36:00': 0,
#                             '2020-07-13 09:54:00': 0,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 3,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 0,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 5,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 1})}),
#   'Debare Oni': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 13:30:00': 2,
#                             '2020-07-13 13:48:00': 0,
#                             '2020-07-13 14:06:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 13:30:00': 2,
#                             '2020-07-13 13:48:00': 0,
#                             '2020-07-13 14:06:00': 1})}),
#   'Blue Six': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 2}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 14:24:00': 1,
#                             '2020-07-13 14:42:00': 2})}),
#   'Blue One': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 2,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 2,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 1,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1}),
#                'mail': defaultdict(dict,
#                            {'2020-07-13 09:18:00': 1,
#                             '2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 2,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 1,
#                             '2020-07-13 12:54:00': 1,
#                             '2020-07-13 13:12:00': 2,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 1,
#                             '2020-07-13 14:06:00': 0,
#                             '2020-07-13 14:24:00': 1}),
#                'microblog': defaultdict(dict, {'2020-07-13 12:54:00': 1})}),
#   'Hamani Heat': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:54:00': 2,
#                             '2020-07-13 10:12:00': 1,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 2,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 0,
#                             '2020-07-13 14:06:00': 1}),
#                'gosocial': defaultdict(dict, {'2020-07-13 10:12:00': 1}),
#                'microblog': defaultdict(dict,
#                            {'2020-07-13 09:54:00': 2,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 2,
#                             '2020-07-13 13:12:00': 0,
#                             '2020-07-13 13:30:00': 0,
#                             '2020-07-13 13:48:00': 0,
#                             '2020-07-13 14:06:00': 1})}),
#   'Benjamin Pepple': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict,
#                            {'2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 1}),
#                'mail': defaultdict(dict,
#                            {'2020-07-13 09:36:00': 1,
#                             '2020-07-13 09:54:00': 1,
#                             '2020-07-13 10:12:00': 0,
#                             '2020-07-13 10:30:00': 0,
#                             '2020-07-13 10:48:00': 0,
#                             '2020-07-13 11:06:00': 0,
#                             '2020-07-13 11:24:00': 0,
#                             '2020-07-13 11:42:00': 0,
#                             '2020-07-13 12:00:00': 0,
#                             '2020-07-13 12:18:00': 0,
#                             '2020-07-13 12:36:00': 0,
#                             '2020-07-13 12:54:00': 1})}),
#   'Adaego Eze': defaultdict(<function __main__.<lambda>()>,
#               {'All': defaultdict(dict, {'2020-07-13 09:36:00': 2}),
#                'mail': defaultdict(dict, {'2020-07-13 09:36:00': 2})})}]

# %%
with open('player_data.json', 'w') as fp:
    json.dump(json_list, fp)

# %%
with open('dropdown_work/player_data.json', 'w') as fp:
    json.dump(json_list, fp)
